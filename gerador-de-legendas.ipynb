# %% [markdown]
# <a href="https://colab.research.google.com/github/dksifoua/Neural-Image-Caption-Generator/blob/master/Neural%20Image%20Caption%20Generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Requirements

# %%
# !nvidia-smi
# Out:
# /bin/bash: nvidia-smi: command not found

# %%
# !pip uninstall typing-extensions --yes
# !pip cache purge
# !pip install typing-extensions

# %%
# !pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /opt/conda/lib/python3.10/site-packages (23.2.1)
# Collecting pip
#   Obtaining dependency information for pip from https://files.pythonhosted.org/packages/47/6a/453160888fab7c6a432a6e25f8afe6256d0d9f2cbd25971021da6491d899/pip-23.3.1-py3-none-any.whl.metadata
#   Downloading pip-23.3.1-py3-none-any.whl.metadata (3.5 kB)
# Downloading pip-23.3.1-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 22.2 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 23.2.1
#     Uninstalling pip-23.2.1:
#       Successfully uninstalled pip-23.2.1
# Successfully installed pip-23.3.1

# %%
# !pip uninstall torchtext --yes
# Out:
# Found existing installation: torchtext 0.15.1+cpu
# Uninstalling torchtext-0.15.1+cpu:
#   Successfully uninstalled torchtext-0.15.1+cpu

# %%
# !pip uninstall torchvision --yes
# Out:
# Found existing installation: torchvision 0.15.1+cpu
# Uninstalling torchvision-0.15.1+cpu:
#   Successfully uninstalled torchvision-0.15.1+cpu

# %%
#!pip install super-gradients

# %%
#!pip install pytorch-quantization==2.1.2 --extra-index-url https://pypi.ngc.nvidia.com &> /dev/null

# %%
# !pip uninstall joblib --yes
# !pip install joblib==0.13.2
# Out:
# Found existing installation: joblib 1.3.2
# Uninstalling joblib-1.3.2:
#   Successfully uninstalled joblib-1.3.2
# Collecting joblib==0.13.2
#   Downloading joblib-0.13.2-py2.py3-none-any.whl (278 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.9/278.9 kB 5.1 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: joblib
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cesium 0.12.1 requires joblib>=0.14.1, but you have joblib 0.13.2 which is incompatible.
# fitter 1.6.0 requires joblib<2.0.0,>=1.3.1, but you have joblib 0.13.2 which is incompatible.
# gplearn 0.4.2 requires joblib>=1.0.0, but you have joblib 0.13.2 which is incompatible.
# imbalanced-learn 0.11.0 requires joblib>=1.1.1, but you have joblib 0.13.2 which is incompatible.
# librosa 0.10.1 requires joblib>=0.14, but you have joblib 0.13.2 which is incompatible.
# nilearn 0.10.2 requires joblib>=1.0.0, but you have joblib 0.13.2 which is incompatible.
# phik 0.12.3 requires joblib>=0.14.1, but you have joblib 0.13.2 which is incompatible.
# scikit-learn 1.2.2 requires joblib>=1.1.1, but you have joblib 0.13.2 which is incompatible.
# scikit-surprise 1.1.3 requires joblib>=1.0.0, but you have joblib 0.13.2 which is incompatible.
# ydata-profiling 4.5.1 requires numpy<1.24,>=1.16.0, but you have numpy 1.24.3 which is incompatible.
# Successfully installed joblib-0.13.2

# %%
# !pip install --force-reinstall --no-deps joblib==0.13.2
# Out:
# Collecting joblib==0.13.2
#   Using cached joblib-0.13.2-py2.py3-none-any.whl (278 kB)
# Installing collected packages: joblib
#   Attempting uninstall: joblib
#     Found existing installation: joblib 0.13.2
#     Uninstalling joblib-0.13.2:
#       Successfully uninstalled joblib-0.13.2
# Successfully installed joblib-0.13.2

# %%
#!pip install --upgrade pip
# !pip install --upgrade setuptools
# !sudo apt-get install build-essential
# !pip install numpy==1.17.0

# !pip install numpy==1.17.0
# Out:
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (68.1.2)
# Collecting setuptools
#   Downloading setuptools-69.0.2-py3-none-any.whl.metadata (6.3 kB)
# Downloading setuptools-69.0.2-py3-none-any.whl (819 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 819.5/819.5 kB 8.8 MB/s eta 0:00:00ta 0:00:01
# Installing collected packages: setuptools
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 68.1.2
#     Uninstalling setuptools-68.1.2:
#       Successfully uninstalled setuptools-68.1.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# libpysal 4.9.2 requires packaging>=22, but you have packaging 21.3 which is incompatible.
# libpysal 4.9.2 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# momepy 0.6.0 requires shapely>=2, but you have shapely 1.8.5.post1 which is incompatible.
# pymc3 3.11.5 requires numpy<1.22.2,>=1.15.0, but you have numpy 1.24.3 which is incompatible.
# pymc3 3.11.5 requires scipy<1.8.0,>=1.7.3, but you have scipy 1.11.3 which is incompatible.
# tensorflowjs 4.13.0 requires packaging~=23.1, but you have packaging 21.3 which is incompatible.
# Successfully installed setuptools-69.0.2
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# build-essential is already the newest version (12.8ubuntu1.1).
# 0 upgraded, 0 newly installed, 0 to remove and 41 not upgraded.
# Collecting numpy==1.17.0
#   Downloading numpy-1.17.0.zip (6.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 44.5 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: numpy
#   Building wheel for numpy (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [2945 lines of output]
#       Running from numpy source directory.
#       blas_opt_info:
#       blas_mkl_info:
#       customize UnixCCompiler
#         FOUND:
#           libraries = ['mkl_rt', 'pthread']
#           library_dirs = ['/opt/conda/lib']
#           define_macros = [('SCIPY_MKL_H', None), ('HAVE_CBLAS', None)]
#           include_dirs = ['/usr/local/include', '/usr/include', '/opt/conda/include']
#
#         FOUND:
#           libraries = ['mkl_rt', 'pthread']
#           library_dirs = ['/opt/conda/lib']
#           define_macros = [('SCIPY_MKL_H', None), ('HAVE_CBLAS', None)]
#           include_dirs = ['/usr/local/include', '/usr/include', '/opt/conda/include']
#
#       /bin/sh: 1: svnversion: not found
#       non-existing path in 'numpy/distutils': 'site.cfg'
#       lapack_opt_info:
#       lapack_mkl_info:
#       customize UnixCCompiler
#         FOUND:
#           libraries = ['mkl_rt', 'pthread']
#           library_dirs = ['/opt/conda/lib']
#           define_macros = [('SCIPY_MKL_H', None), ('HAVE_CBLAS', None)]
#           include_dirs = ['/usr/local/include', '/usr/include', '/opt/conda/include']
#
#         FOUND:
#           libraries = ['mkl_rt', 'pthread']
#           library_dirs = ['/opt/conda/lib']
#           define_macros = [('SCIPY_MKL_H', None), ('HAVE_CBLAS', None)]
#           include_dirs = ['/usr/local/include', '/usr/include', '/opt/conda/include']
#
#       non-existing path in 'numpy/random': 'src/splitmix64/splitmix.h'
#       /opt/conda/lib/python3.10/site-packages/setuptools/_distutils/dist.py:265: UserWarning: Unknown distribution option: 'define_macros'
#         warnings.warn(msg)
#       running bdist_wheel
#       running build
#       running config_cc
#       unifing config_cc, config, build_clib, build_ext, build commands --compiler options
#       running config_fc
#       unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
#       running build_src
#       build_src
#       building py_modules sources
#       creating build
#       creating build/src.linux-x86_64-3.1
#       creating build/src.linux-x86_64-3.1/numpy
#       creating build/src.linux-x86_64-3.1/numpy/distutils
#       building library "npymath" sources
#       get_default_fcompiler: matching types: '['gnu95', 'intel', 'lahey', 'pg', 'absoft', 'nag', 'vast', 'compaq', 'intele', 'intelem', 'gnu', 'g95', 'pathf95', 'nagfor']'
#       customize Gnu95FCompiler
#       Could not locate executable gfortran
#       Could not locate executable f95
#       customize IntelFCompiler
#       Could not locate executable ifort
#       Could not locate executable ifc
#       customize LaheyFCompiler
#       Could not locate executable lf95
#       customize PGroupFCompiler
#       Could not locate executable pgfortran
#       customize AbsoftFCompiler
#       Could not locate executable f90
#       Could not locate executable f77
#       customize NAGFCompiler
#       customize VastFCompiler
#       customize CompaqFCompiler
#       Could not locate executable fort
#       customize IntelItaniumFCompiler
#       Could not locate executable efort
#       Could not locate executable efc
#       customize IntelEM64TFCompiler
#       customize GnuFCompiler
#       Could not locate executable g77
#       customize G95FCompiler
#       Could not locate executable g95
#       customize PathScaleFCompiler
#       Could not locate executable pathf95
#       customize NAGFORCompiler
#       Could not locate executable nagfor
#       don't know how to compile Fortran code on platform 'posix'
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       gcc -pthread -B /opt/conda/compiler_compat _configtest.o -o _configtest
#       success!
#       removing: _configtest.c _configtest.o _configtest.o.d _configtest
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       _configtest.c:1:5: warning: conflicting types for built-in function ‘exp’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#           1 | int exp (void);
#             |     ^~~
#       _configtest.c:1:1: note: ‘exp’ is declared in header ‘<math.h>’
#         +++ |+#include <math.h>
#           1 | int exp (void);
#       gcc -pthread -B /opt/conda/compiler_compat _configtest.o -o _configtest
#       /opt/conda/compiler_compat/ld: _configtest.o: in function `main':
#       _configtest.c:(.text.startup+0x9): undefined reference to `exp'
#       collect2: error: ld returned 1 exit status
#       failure.
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       _configtest.c:1:5: warning: conflicting types for built-in function ‘exp’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#           1 | int exp (void);
#             |     ^~~
#       _configtest.c:1:1: note: ‘exp’ is declared in header ‘<math.h>’
#         +++ |+#include <math.h>
#           1 | int exp (void);
#       gcc -pthread -B /opt/conda/compiler_compat _configtest.o -lm -o _configtest
#       success!
#       removing: _configtest.c _configtest.o _configtest.o.d _configtest
#       creating build/src.linux-x86_64-3.1/numpy/core
#       creating build/src.linux-x86_64-3.1/numpy/core/src
#       creating build/src.linux-x86_64-3.1/numpy/core/src/npymath
#       conv_template:> build/src.linux-x86_64-3.1/numpy/core/src/npymath/npy_math_internal.h
#         adding 'build/src.linux-x86_64-3.1/numpy/core/src/npymath' to include_dirs.
#       conv_template:> build/src.linux-x86_64-3.1/numpy/core/src/npymath/ieee754.c
#       conv_template:> build/src.linux-x86_64-3.1/numpy/core/src/npymath/npy_math_complex.c
#       None - nothing done with h_files = ['build/src.linux-x86_64-3.1/numpy/core/src/npymath/npy_math_internal.h']
#       building library "npysort" sources
#       creating build/src.linux-x86_64-3.1/numpy/core/src/common
#       conv_template:> build/src.linux-x86_64-3.1/numpy/core/src/common/npy_sort.h
#         adding 'build/src.linux-x86_64-3.1/numpy/core/src/common' to include_dirs.
#       creating build/src.linux-x86_64-3.1/numpy/core/src/npysort
#       conv_template:> build/src.linux-x86_64-3.1/numpy/core/src/npysort/quicksort.c
#       conv_template:> build/src.linux-x86_64-3.1/numpy/core/src/npysort/mergesort.c
#       conv_template:> build/src.linux-x86_64-3.1/numpy/core/src/npysort/timsort.c
#       conv_template:> build/src.linux-x86_64-3.1/numpy/core/src/npysort/heapsort.c
#       conv_template:> build/src.linux-x86_64-3.1/numpy/core/src/npysort/radixsort.c
#       conv_template:> build/src.linux-x86_64-3.1/numpy/core/src/common/npy_partition.h
#       conv_template:> build/src.linux-x86_64-3.1/numpy/core/src/npysort/selection.c
#       conv_template:> build/src.linux-x86_64-3.1/numpy/core/src/common/npy_binsearch.h
#       conv_template:> build/src.linux-x86_64-3.1/numpy/core/src/npysort/binsearch.c
#       None - nothing done with h_files = ['build/src.linux-x86_64-3.1/numpy/core/src/common/npy_sort.h', 'build/src.linux-x86_64-3.1/numpy/core/src/common/npy_partition.h', 'build/src.linux-x86_64-3.1/numpy/core/src/common/npy_binsearch.h']
#       building extension "numpy.core._dummy" sources
#       Generating build/src.linux-x86_64-3.1/numpy/core/include/numpy/config.h
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       success!
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       success!
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       _configtest.c:1:10: fatal error: sys/endian.h: No such file or directory
#           1 | #include <sys/endian.h>
#             |          ^~~~~~~~~~~~~~
#       compilation terminated.
#       failure.
#       removing: _configtest.c _configtest.o
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       success!
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       success!
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       success!
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       success!
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       _configtest.c: In function ‘main’:
#       _configtest.c:5:16: warning: variable ‘test_array’ set but not used [-Wunused-but-set-variable]
#           5 |     static int test_array [1 - 2 * !(((long) (sizeof (npy_check_sizeof_type))) >= 0)];
#             |                ^~~~~~~~~~
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       _configtest.c: In function ‘main’:
#       _configtest.c:5:16: warning: variable ‘test_array’ set but not used [-Wunused-but-set-variable]
#           5 |     static int test_array [1 - 2 * !(((long) (sizeof (npy_check_sizeof_type))) == 4)];
#             |                ^~~~~~~~~~
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       _configtest.c: In function ‘main’:
#       _configtest.c:5:16: warning: variable ‘test_array’ set but not used [-Wunused-but-set-variable]
#           5 |     static int test_array [1 - 2 * !(((long) (sizeof (npy_check_sizeof_type))) >= 0)];
#             |                ^~~~~~~~~~
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       _configtest.c: In function ‘main’:
#       _configtest.c:5:16: warning: variable ‘test_array’ set but not used [-Wunused-but-set-variable]
#           5 |     static int test_array [1 - 2 * !(((long) (sizeof (npy_check_sizeof_type))) == 8)];
#             |                ^~~~~~~~~~
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       success!
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       _configtest.c: In function ‘main’:
#       _configtest.c:5:16: warning: variable ‘test_array’ set but not used [-Wunused-but-set-variable]
#           5 |     static int test_array [1 - 2 * !(((long) (sizeof (npy_check_sizeof_type))) >= 0)];
#             |                ^~~~~~~~~~
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       _configtest.c: In function ‘main’:
#       _configtest.c:5:16: warning: variable ‘test_array’ set but not used [-Wunused-but-set-variable]
#           5 |     static int test_array [1 - 2 * !(((long) (sizeof (npy_check_sizeof_type))) == 8)];
#             |                ^~~~~~~~~~
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       _configtest.c: In function ‘main’:
#       _configtest.c:5:16: warning: variable ‘test_array’ set but not used [-Wunused-but-set-variable]
#           5 |     static int test_array [1 - 2 * !(((long) (sizeof (npy_check_sizeof_type))) >= 0)];
#             |                ^~~~~~~~~~
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       _configtest.c: In function ‘main’:
#       _configtest.c:5:16: warning: variable ‘test_array’ set but not used [-Wunused-but-set-variable]
#           5 |     static int test_array [1 - 2 * !(((long) (sizeof (npy_check_sizeof_type))) == 16)];
#             |                ^~~~~~~~~~
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       _configtest.c: In function ‘main’:
#       _configtest.c:7:12: error: ‘SIZEOF_LONGDOUBLE’ undeclared (first use in this function); did you mean ‘SIZEOF_LONG_DOUBLE’?
#           7 |     (void) SIZEOF_LONGDOUBLE;
#             |            ^~~~~~~~~~~~~~~~~
#             |            SIZEOF_LONG_DOUBLE
#       _configtest.c:7:12: note: each undeclared identifier is reported only once for each function it appears in
#       failure.
#       removing: _configtest.c _configtest.o
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       _configtest.c: In function ‘main’:
#       _configtest.c:5:16: warning: variable ‘test_array’ set but not used [-Wunused-but-set-variable]
#           5 |     static int test_array [1 - 2 * !(((long) (sizeof (npy_check_sizeof_type))) >= 0)];
#             |                ^~~~~~~~~~
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       _configtest.c: In function ‘main’:
#       _configtest.c:5:16: warning: variable ‘test_array’ set but not used [-Wunused-but-set-variable]
#           5 |     static int test_array [1 - 2 * !(((long) (sizeof (npy_check_sizeof_type))) == 16)];
#             |                ^~~~~~~~~~
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       _configtest.c: In function ‘main’:
#       _configtest.c:5:16: warning: variable ‘test_array’ set but not used [-Wunused-but-set-variable]
#           5 |     static int test_array [1 - 2 * !(((long) (sizeof (npy_check_sizeof_type))) >= 0)];
#             |                ^~~~~~~~~~
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       _configtest.c: In function ‘main’:
#       _configtest.c:5:16: warning: variable ‘test_array’ set but not used [-Wunused-but-set-variable]
#           5 |     static int test_array [1 - 2 * !(((long) (sizeof (npy_check_sizeof_type))) == 32)];
#             |                ^~~~~~~~~~
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       _configtest.c: In function ‘main’:
#       _configtest.c:7:16: warning: variable ‘test_array’ set but not used [-Wunused-but-set-variable]
#           7 |     static int test_array [1 - 2 * !(((long) (sizeof (npy_check_sizeof_type))) >= 0)];
#             |                ^~~~~~~~~~
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       _configtest.c: In function ‘main’:
#       _configtest.c:7:16: warning: variable ‘test_array’ set but not used [-Wunused-but-set-variable]
#           7 |     static int test_array [1 - 2 * !(((long) (sizeof (npy_check_sizeof_type))) == 8)];
#             |                ^~~~~~~~~~
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       _configtest.c: In function ‘main’:
#       _configtest.c:7:16: warning: variable ‘test_array’ set but not used [-Wunused-but-set-variable]
#           7 |     static int test_array [1 - 2 * !(((long) (sizeof (npy_check_sizeof_type))) >= 0)];
#             |                ^~~~~~~~~~
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       _configtest.c: In function ‘main’:
#       _configtest.c:7:16: warning: variable ‘test_array’ set but not used [-Wunused-but-set-variable]
#           7 |     static int test_array [1 - 2 * !(((long) (sizeof (npy_check_sizeof_type))) == 8)];
#             |                ^~~~~~~~~~
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       success!
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       _configtest.c: In function ‘main’:
#       _configtest.c:7:16: warning: variable ‘test_array’ set but not used [-Wunused-but-set-variable]
#           7 |     static int test_array [1 - 2 * !(((long) (sizeof (npy_check_sizeof_type))) >= 0)];
#             |                ^~~~~~~~~~
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       _configtest.c: In function ‘main’:
#       _configtest.c:7:16: warning: variable ‘test_array’ set but not used [-Wunused-but-set-variable]
#           7 |     static int test_array [1 - 2 * !(((long) (sizeof (npy_check_sizeof_type))) == 8)];
#             |                ^~~~~~~~~~
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       _configtest.c: In function ‘main’:
#       _configtest.c:5:16: warning: variable ‘test_array’ set but not used [-Wunused-but-set-variable]
#           5 |     static int test_array [1 - 2 * !(((long) (sizeof (npy_check_sizeof_type))) >= 0)];
#             |                ^~~~~~~~~~
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       _configtest.c: In function ‘main’:
#       _configtest.c:5:16: warning: variable ‘test_array’ set but not used [-Wunused-but-set-variable]
#           5 |     static int test_array [1 - 2 * !(((long) (sizeof (npy_check_sizeof_type))) == 8)];
#             |                ^~~~~~~~~~
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       success!
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       _configtest.c:1:5: warning: conflicting types for built-in function ‘exp’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#           1 | int exp (void);
#             |     ^~~
#       _configtest.c:1:1: note: ‘exp’ is declared in header ‘<math.h>’
#         +++ |+#include <math.h>
#           1 | int exp (void);
#       gcc -pthread -B /opt/conda/compiler_compat _configtest.o -o _configtest
#       /opt/conda/compiler_compat/ld: _configtest.o: in function `main':
#       _configtest.c:(.text.startup+0x9): undefined reference to `exp'
#       collect2: error: ld returned 1 exit status
#       failure.
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       _configtest.c:1:5: warning: conflicting types for built-in function ‘exp’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#           1 | int exp (void);
#             |     ^~~
#       _configtest.c:1:1: note: ‘exp’ is declared in header ‘<math.h>’
#         +++ |+#include <math.h>
#           1 | int exp (void);
#       gcc -pthread -B /opt/conda/compiler_compat _configtest.o -lm -o _configtest
#       success!
#       removing: _configtest.c _configtest.o _configtest.o.d _configtest
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       _configtest.c:1:5: warning: conflicting types for built-in function ‘sin’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#           1 | int sin (void);
#             |     ^~~
#       _configtest.c:1:1: note: ‘sin’ is declared in header ‘<math.h>’
#         +++ |+#include <math.h>
#           1 | int sin (void);
#       _configtest.c:2:5: warning: conflicting types for built-in function ‘cos’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#           2 | int cos (void);
#             |     ^~~
#       _configtest.c:2:5: note: ‘cos’ is declared in header ‘<math.h>’
#       _configtest.c:3:5: warning: conflicting types for built-in function ‘tan’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#           3 | int tan (void);
#             |     ^~~
#       _configtest.c:3:5: note: ‘tan’ is declared in header ‘<math.h>’
#       _configtest.c:4:5: warning: conflicting types for built-in function ‘sinh’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#           4 | int sinh (void);
#             |     ^~~~
#       _configtest.c:4:5: note: ‘sinh’ is declared in header ‘<math.h>’
#       _configtest.c:5:5: warning: conflicting types for built-in function ‘cosh’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#           5 | int cosh (void);
#             |     ^~~~
#       _configtest.c:5:5: note: ‘cosh’ is declared in header ‘<math.h>’
#       _configtest.c:6:5: warning: conflicting types for built-in function ‘tanh’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#           6 | int tanh (void);
#             |     ^~~~
#       _configtest.c:6:5: note: ‘tanh’ is declared in header ‘<math.h>’
#       _configtest.c:7:5: warning: conflicting types for built-in function ‘fabs’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#           7 | int fabs (void);
#             |     ^~~~
#       _configtest.c:7:5: note: ‘fabs’ is declared in header ‘<math.h>’
#       _configtest.c:8:5: warning: conflicting types for built-in function ‘floor’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#           8 | int floor (void);
#             |     ^~~~~
#       _configtest.c:8:5: note: ‘floor’ is declared in header ‘<math.h>’
#       _configtest.c:9:5: warning: conflicting types for built-in function ‘ceil’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#           9 | int ceil (void);
#             |     ^~~~
#       _configtest.c:9:5: note: ‘ceil’ is declared in header ‘<math.h>’
#       _configtest.c:10:5: warning: conflicting types for built-in function ‘sqrt’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#          10 | int sqrt (void);
#             |     ^~~~
#       _configtest.c:10:5: note: ‘sqrt’ is declared in header ‘<math.h>’
#       _configtest.c:11:5: warning: conflicting types for built-in function ‘log10’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#          11 | int log10 (void);
#             |     ^~~~~
#       _configtest.c:11:5: note: ‘log10’ is declared in header ‘<math.h>’
#       _configtest.c:12:5: warning: conflicting types for built-in function ‘log’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#          12 | int log (void);
#             |     ^~~
#       _configtest.c:12:5: note: ‘log’ is declared in header ‘<math.h>’
#       _configtest.c:13:5: warning: conflicting types for built-in function ‘exp’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#          13 | int exp (void);
#             |     ^~~
#       _configtest.c:13:5: note: ‘exp’ is declared in header ‘<math.h>’
#       _configtest.c:14:5: warning: conflicting types for built-in function ‘asin’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#          14 | int asin (void);
#             |     ^~~~
#       _configtest.c:14:5: note: ‘asin’ is declared in header ‘<math.h>’
#       _configtest.c:15:5: warning: conflicting types for built-in function ‘acos’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#          15 | int acos (void);
#             |     ^~~~
#       _configtest.c:15:5: note: ‘acos’ is declared in header ‘<math.h>’
#       _configtest.c:16:5: warning: conflicting types for built-in function ‘atan’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#          16 | int atan (void);
#             |     ^~~~
#       _configtest.c:16:5: note: ‘atan’ is declared in header ‘<math.h>’
#       _configtest.c:17:5: warning: conflicting types for built-in function ‘fmod’; expected ‘double(double,  double)’ [-Wbuiltin-declaration-mismatch]
#          17 | int fmod (void);
#             |     ^~~~
#       _configtest.c:17:5: note: ‘fmod’ is declared in header ‘<math.h>’
#       _configtest.c:18:5: warning: conflicting types for built-in function ‘modf’; expected ‘double(double,  double *)’ [-Wbuiltin-declaration-mismatch]
#          18 | int modf (void);
#             |     ^~~~
#       _configtest.c:18:5: note: ‘modf’ is declared in header ‘<math.h>’
#       _configtest.c:19:5: warning: conflicting types for built-in function ‘frexp’; expected ‘double(double,  int *)’ [-Wbuiltin-declaration-mismatch]
#          19 | int frexp (void);
#             |     ^~~~~
#       _configtest.c:19:5: note: ‘frexp’ is declared in header ‘<math.h>’
#       _configtest.c:20:5: warning: conflicting types for built-in function ‘ldexp’; expected ‘double(double,  int)’ [-Wbuiltin-declaration-mismatch]
#          20 | int ldexp (void);
#             |     ^~~~~
#       _configtest.c:20:5: note: ‘ldexp’ is declared in header ‘<math.h>’
#       gcc -pthread -B /opt/conda/compiler_compat _configtest.o -lm -o _configtest
#       success!
#       removing: _configtest.c _configtest.o _configtest.o.d _configtest
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       success!
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       success!
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       success!
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       success!
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       success!
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       success!
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       success!
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       success!
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       success!
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       _configtest.c:1:5: warning: conflicting types for built-in function ‘rint’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#           1 | int rint (void);
#             |     ^~~~
#       _configtest.c:1:1: note: ‘rint’ is declared in header ‘<math.h>’
#         +++ |+#include <math.h>
#           1 | int rint (void);
#       _configtest.c:2:5: warning: conflicting types for built-in function ‘trunc’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#           2 | int trunc (void);
#             |     ^~~~~
#       _configtest.c:2:5: note: ‘trunc’ is declared in header ‘<math.h>’
#       _configtest.c:3:5: warning: conflicting types for built-in function ‘exp2’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#           3 | int exp2 (void);
#             |     ^~~~
#       _configtest.c:3:5: note: ‘exp2’ is declared in header ‘<math.h>’
#       _configtest.c:4:5: warning: conflicting types for built-in function ‘log2’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#           4 | int log2 (void);
#             |     ^~~~
#       _configtest.c:4:5: note: ‘log2’ is declared in header ‘<math.h>’
#       _configtest.c:5:5: warning: conflicting types for built-in function ‘atan2’; expected ‘double(double,  double)’ [-Wbuiltin-declaration-mismatch]
#           5 | int atan2 (void);
#             |     ^~~~~
#       _configtest.c:5:5: note: ‘atan2’ is declared in header ‘<math.h>’
#       _configtest.c:6:5: warning: conflicting types for built-in function ‘pow’; expected ‘double(double,  double)’ [-Wbuiltin-declaration-mismatch]
#           6 | int pow (void);
#             |     ^~~
#       _configtest.c:6:5: note: ‘pow’ is declared in header ‘<math.h>’
#       _configtest.c:7:5: warning: conflicting types for built-in function ‘nextafter’; expected ‘double(double,  double)’ [-Wbuiltin-declaration-mismatch]
#           7 | int nextafter (void);
#             |     ^~~~~~~~~
#       _configtest.c:7:5: note: ‘nextafter’ is declared in header ‘<math.h>’
#       _configtest.c:10:5: warning: conflicting types for built-in function ‘cbrt’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#          10 | int cbrt (void);
#             |     ^~~~
#       _configtest.c:10:5: note: ‘cbrt’ is declared in header ‘<math.h>’
# ...
#                        from numpy/core/src/multiarray/scalartypes.c.src:3:
#       /opt/conda/include/python3.10/pyhash.h:10:23: note: declared here
#          10 | PyAPI_FUNC(Py_hash_t) _Py_HashDouble(PyObject *, double);
#             |                       ^~~~~~~~~~~~~~
#       numpy/core/src/multiarray/scalartypes.c.src: In function ‘longdouble_arrtype_hash’:
#       numpy/core/src/multiarray/scalartypes.c.src:3311:27: error: incompatible type for argument 1 of ‘_Py_HashDouble’
#        3311 |     return _Py_HashDouble((double) ((Py@name@ScalarObject *)obj)->obval);
#             |                           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#             |                           |
#             |                           double
#       In file included from /opt/conda/include/python3.10/Python.h:77,
#                        from numpy/core/src/multiarray/scalartypes.c.src:3:
#       /opt/conda/include/python3.10/pyhash.h:10:38: note: expected ‘PyObject *’ {aka ‘struct _object *’} but argument is of type ‘double’
#          10 | PyAPI_FUNC(Py_hash_t) _Py_HashDouble(PyObject *, double);
#             |                                      ^~~~~~~~~~
#       numpy/core/src/multiarray/scalartypes.c.src:3311:12: error: too few arguments to function ‘_Py_HashDouble’
#        3311 |     return _Py_HashDouble((double) ((Py@name@ScalarObject *)obj)->obval);
#             |            ^~~~~~~~~~~~~~
#       In file included from /opt/conda/include/python3.10/Python.h:77,
#                        from numpy/core/src/multiarray/scalartypes.c.src:3:
#       /opt/conda/include/python3.10/pyhash.h:10:23: note: declared here
#          10 | PyAPI_FUNC(Py_hash_t) _Py_HashDouble(PyObject *, double);
#             |                       ^~~~~~~~~~~~~~
#       numpy/core/src/multiarray/scalartypes.c.src: In function ‘clongdouble_arrtype_hash’:
#       numpy/core/src/multiarray/scalartypes.c.src:3319:31: error: incompatible type for argument 1 of ‘_Py_HashDouble’
#        3319 |     hashreal = _Py_HashDouble((double)
#             |                               ^~~~~~~~
#             |                               |
#             |                               double
#        3320 |             (((PyC@name@ScalarObject *)obj)->obval).real);
#             |             ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       In file included from /opt/conda/include/python3.10/Python.h:77,
#                        from numpy/core/src/multiarray/scalartypes.c.src:3:
#       /opt/conda/include/python3.10/pyhash.h:10:38: note: expected ‘PyObject *’ {aka ‘struct _object *’} but argument is of type ‘double’
#          10 | PyAPI_FUNC(Py_hash_t) _Py_HashDouble(PyObject *, double);
#             |                                      ^~~~~~~~~~
#       numpy/core/src/multiarray/scalartypes.c.src:3319:16: error: too few arguments to function ‘_Py_HashDouble’
#        3319 |     hashreal = _Py_HashDouble((double)
#             |                ^~~~~~~~~~~~~~
#       In file included from /opt/conda/include/python3.10/Python.h:77,
#                        from numpy/core/src/multiarray/scalartypes.c.src:3:
#       /opt/conda/include/python3.10/pyhash.h:10:23: note: declared here
#          10 | PyAPI_FUNC(Py_hash_t) _Py_HashDouble(PyObject *, double);
#             |                       ^~~~~~~~~~~~~~
#       numpy/core/src/multiarray/scalartypes.c.src:3325:31: error: incompatible type for argument 1 of ‘_Py_HashDouble’
#        3325 |     hashimag = _Py_HashDouble((double)
#             |                               ^~~~~~~~
#             |                               |
#             |                               double
#        3326 |             (((PyC@name@ScalarObject *)obj)->obval).imag);
#             |             ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       In file included from /opt/conda/include/python3.10/Python.h:77,
#                        from numpy/core/src/multiarray/scalartypes.c.src:3:
#       /opt/conda/include/python3.10/pyhash.h:10:38: note: expected ‘PyObject *’ {aka ‘struct _object *’} but argument is of type ‘double’
#          10 | PyAPI_FUNC(Py_hash_t) _Py_HashDouble(PyObject *, double);
#             |                                      ^~~~~~~~~~
#       numpy/core/src/multiarray/scalartypes.c.src:3325:16: error: too few arguments to function ‘_Py_HashDouble’
#        3325 |     hashimag = _Py_HashDouble((double)
#             |                ^~~~~~~~~~~~~~
#       In file included from /opt/conda/include/python3.10/Python.h:77,
#                        from numpy/core/src/multiarray/scalartypes.c.src:3:
#       /opt/conda/include/python3.10/pyhash.h:10:23: note: declared here
#          10 | PyAPI_FUNC(Py_hash_t) _Py_HashDouble(PyObject *, double);
#             |                       ^~~~~~~~~~~~~~
#       numpy/core/src/multiarray/scalartypes.c.src: In function ‘half_arrtype_hash’:
#       numpy/core/src/multiarray/scalartypes.c.src:3341:27: error: incompatible type for argument 1 of ‘_Py_HashDouble’
#        3341 |     return _Py_HashDouble(npy_half_to_double(((PyHalfScalarObject *)obj)->obval));
#             |                           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#             |                           |
#             |                           double
#       In file included from /opt/conda/include/python3.10/Python.h:77,
#                        from numpy/core/src/multiarray/scalartypes.c.src:3:
#       /opt/conda/include/python3.10/pyhash.h:10:38: note: expected ‘PyObject *’ {aka ‘struct _object *’} but argument is of type ‘double’
#          10 | PyAPI_FUNC(Py_hash_t) _Py_HashDouble(PyObject *, double);
#             |                                      ^~~~~~~~~~
#       numpy/core/src/multiarray/scalartypes.c.src:3341:12: error: too few arguments to function ‘_Py_HashDouble’
#        3341 |     return _Py_HashDouble(npy_half_to_double(((PyHalfScalarObject *)obj)->obval));
#             |            ^~~~~~~~~~~~~~
#       In file included from /opt/conda/include/python3.10/Python.h:77,
#                        from numpy/core/src/multiarray/scalartypes.c.src:3:
#       /opt/conda/include/python3.10/pyhash.h:10:23: note: declared here
#          10 | PyAPI_FUNC(Py_hash_t) _Py_HashDouble(PyObject *, double);
#             |                       ^~~~~~~~~~~~~~
#       numpy/core/src/multiarray/scalartypes.c.src: In function ‘longdouble_arrtype_hash’:
#       numpy/core/src/multiarray/scalartypes.c.src:3312:1: warning: control reaches end of non-void function [-Wreturn-type]
#        3312 | }
#             | ^
#       numpy/core/src/multiarray/scalartypes.c.src: In function ‘float_arrtype_hash’:
#       numpy/core/src/multiarray/scalartypes.c.src:3312:1: warning: control reaches end of non-void function [-Wreturn-type]
#        3312 | }
#             | ^
#       numpy/core/src/multiarray/scalartypes.c.src: In function ‘half_arrtype_hash’:
#       numpy/core/src/multiarray/scalartypes.c.src:3342:1: warning: control reaches end of non-void function [-Wreturn-type]
#        3342 | }
#             | ^
#       gcc: numpy/core/src/multiarray/vdot.c
#       gcc: numpy/core/src/multiarray/nditer_pywrap.c
#       gcc: numpy/core/src/multiarray/refcount.c
#       gcc: numpy/core/src/umath/umathmodule.c
#       gcc: numpy/core/src/umath/reduction.c
#       gcc: numpy/core/src/multiarray/sequence.c
#       gcc: numpy/core/src/multiarray/shape.c
#       gcc: build/src.linux-x86_64-3.1/numpy/core/src/umath/loops.c
#       gcc: build/src.linux-x86_64-3.1/numpy/core/src/umath/clip.c
#       gcc: numpy/core/src/multiarray/scalarapi.c
#       numpy/core/src/umath/loops.c.src: In function ‘PyUFunc_On_Om’:
#       numpy/core/src/umath/loops.c.src:506:9: warning: ‘PyEval_CallObjectWithKeywords’ is deprecated [-Wdeprecated-declarations]
#         506 |         result = PyEval_CallObject(tocall, arglist);
#             |         ^~~~~~
#       In file included from /opt/conda/include/python3.10/Python.h:130,
#                        from numpy/core/src/umath/loops.c.src:7:
#       /opt/conda/include/python3.10/ceval.h:17:43: note: declared here
#          17 | Py_DEPRECATED(3.9) PyAPI_FUNC(PyObject *) PyEval_CallObjectWithKeywords(
#             |                                           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       numpy/core/src/multiarray/scalarapi.c: In function ‘scalar_value’:
#       numpy/core/src/multiarray/scalarapi.c:74:13: warning: ‘PyUnicode_AsUnicode’ is deprecated [-Wdeprecated-declarations]
#          74 |             return (void *)PyUnicode_AS_DATA(scalar);
#             |             ^~~~~~
#       In file included from /opt/conda/include/python3.10/unicodeobject.h:1046,
#                        from /opt/conda/include/python3.10/Python.h:83,
#                        from numpy/core/src/multiarray/scalarapi.c:2:
#       /opt/conda/include/python3.10/cpython/unicodeobject.h:580:45: note: declared here
#         580 | Py_DEPRECATED(3.3) PyAPI_FUNC(Py_UNICODE *) PyUnicode_AsUnicode(
#             |                                             ^~~~~~~~~~~~~~~~~~~
#       numpy/core/src/multiarray/scalarapi.c:135:13: warning: ‘PyUnicode_AsUnicode’ is deprecated [-Wdeprecated-declarations]
#         135 |             return (void *)PyUnicode_AS_DATA(scalar);
#             |             ^~~~~~
#       In file included from /opt/conda/include/python3.10/unicodeobject.h:1046,
#                        from /opt/conda/include/python3.10/Python.h:83,
#                        from numpy/core/src/multiarray/scalarapi.c:2:
#       /opt/conda/include/python3.10/cpython/unicodeobject.h:580:45: note: declared here
#         580 | Py_DEPRECATED(3.3) PyAPI_FUNC(Py_UNICODE *) PyUnicode_AsUnicode(
#             |                                             ^~~~~~~~~~~~~~~~~~~
#       numpy/core/src/multiarray/scalarapi.c: In function ‘PyArray_DescrFromScalar’:
#       numpy/core/src/multiarray/scalarapi.c:574:13: warning: ‘_PyUnicode_get_wstr_length’ is deprecated [-Wdeprecated-declarations]
#         574 |             descr->elsize = PyUnicode_GET_DATA_SIZE(sc);
#             |             ^~~~~
#       In file included from /opt/conda/include/python3.10/unicodeobject.h:1046,
#                        from /opt/conda/include/python3.10/Python.h:83,
#                        from numpy/core/src/multiarray/scalarapi.c:2:
#       /opt/conda/include/python3.10/cpython/unicodeobject.h:446:26: note: declared here
#         446 | static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#             |                          ^~~~~~~~~~~~~~~~~~~~~~~~~~
#       numpy/core/src/multiarray/scalarapi.c:574:13: warning: ‘PyUnicode_AsUnicode’ is deprecated [-Wdeprecated-declarations]
#         574 |             descr->elsize = PyUnicode_GET_DATA_SIZE(sc);
#             |             ^~~~~
#       In file included from /opt/conda/include/python3.10/unicodeobject.h:1046,
#                        from /opt/conda/include/python3.10/Python.h:83,
#                        from numpy/core/src/multiarray/scalarapi.c:2:
#       /opt/conda/include/python3.10/cpython/unicodeobject.h:580:45: note: declared here
#         580 | Py_DEPRECATED(3.3) PyAPI_FUNC(Py_UNICODE *) PyUnicode_AsUnicode(
#             |                                             ^~~~~~~~~~~~~~~~~~~
#       numpy/core/src/multiarray/scalarapi.c:574:13: warning: ‘_PyUnicode_get_wstr_length’ is deprecated [-Wdeprecated-declarations]
#         574 |             descr->elsize = PyUnicode_GET_DATA_SIZE(sc);
#             |             ^~~~~
#       In file included from /opt/conda/include/python3.10/unicodeobject.h:1046,
#                        from /opt/conda/include/python3.10/Python.h:83,
#                        from numpy/core/src/multiarray/scalarapi.c:2:
#       /opt/conda/include/python3.10/cpython/unicodeobject.h:446:26: note: declared here
#         446 | static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#             |                          ^~~~~~~~~~~~~~~~~~~~~~~~~~
#       gcc: numpy/core/src/umath/ufunc_type_resolution.c
#       gcc: numpy/core/src/umath/ufunc_object.c
#       gcc: numpy/core/src/umath/override.c
#       gcc: numpy/core/src/npymath/npy_math.c
#       gcc: build/src.linux-x86_64-3.1/numpy/core/src/npymath/ieee754.c
#       gcc: build/src.linux-x86_64-3.1/numpy/core/src/npymath/npy_math_complex.c
#       gcc: numpy/core/src/npymath/halffloat.c
#       gcc: numpy/core/src/common/array_assign.c
#       gcc: numpy/core/src/umath/extobj.c
#       gcc: numpy/core/src/common/mem_overlap.c
#       gcc: numpy/core/src/umath/cpuid.c
#       gcc: build/src.linux-x86_64-3.1/numpy/core/src/umath/scalarmath.c
#       gcc: numpy/core/src/common/npy_longdouble.c
#       gcc: numpy/core/src/common/ucsnarrow.c
#       numpy/core/src/common/ucsnarrow.c: In function ‘PyUnicode_FromUCS4’:
#       numpy/core/src/common/ucsnarrow.c:139:9: warning: ‘PyUnicode_FromUnicode’ is deprecated [-Wdeprecated-declarations]
#         139 |         ret = (PyUnicodeObject *)PyUnicode_FromUnicode((Py_UNICODE*)buf,
#             |         ^~~
#       In file included from /opt/conda/include/python3.10/unicodeobject.h:1046,
#                        from /opt/conda/include/python3.10/Python.h:83,
#                        from numpy/core/src/common/ucsnarrow.c:4:
#       /opt/conda/include/python3.10/cpython/unicodeobject.h:551:42: note: declared here
#         551 | Py_DEPRECATED(3.3) PyAPI_FUNC(PyObject*) PyUnicode_FromUnicode(
#             |                                          ^~~~~~~~~~~~~~~~~~~~~
#       gcc: numpy/core/src/common/ufunc_override.c
#       gcc: numpy/core/src/common/numpyos.c
#       gcc: numpy/core/src/common/cblasfuncs.c
#       gcc: numpy/core/src/common/python_xerbla.c
#       gcc: numpy/core/src/multiarray/mapping.c
#       gcc: numpy/core/src/multiarray/methods.c
#       gcc: build/src.linux-x86_64-3.1/numpy/core/src/umath/matmul.c
#       error: Command "gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC -DNPY_INTERNAL_BUILD=1 -DHAVE_NPY_CONFIG_H=1 -D_FILE_OFFSET_BITS=64 -D_LARGEFILE_SOURCE=1 -D_LARGEFILE64_SOURCE=1 -DSCIPY_MKL_H -DHAVE_CBLAS -I/usr/local/include -I/usr/include -I/opt/conda/include -Ibuild/src.linux-x86_64-3.1/numpy/core/src/umath -Ibuild/src.linux-x86_64-3.1/numpy/core/src/npymath -Ibuild/src.linux-x86_64-3.1/numpy/core/src/common -Inumpy/core/include -Ibuild/src.linux-x86_64-3.1/numpy/core/include/numpy -Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -Ibuild/src.linux-x86_64-3.1/numpy/core/src/common -Ibuild/src.linux-x86_64-3.1/numpy/core/src/npymath -Ibuild/src.linux-x86_64-3.1/numpy/core/src/common -Ibuild/src.linux-x86_64-3.1/numpy/core/src/npymath -c build/src.linux-x86_64-3.1/numpy/core/src/multiarray/scalartypes.c -o build/temp.linux-x86_64-cpython-310/build/src.linux-x86_64-3.1/numpy/core/src/multiarray/scalartypes.o -MMD -MF build/temp.linux-x86_64-cpython-310/build/src.linux-x86_64-3.1/numpy/core/src/multiarray/scalartypes.o.d" failed with exit status 1
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for numpy
#   Running setup.py clean for numpy
#   error: subprocess-exited-with-error
#
#   × python setup.py clean did not run successfully.
#   │ exit code: 1
#   ╰─> [10 lines of output]
#       Running from numpy source directory.
#
#       `setup.py clean` is not supported, use one of the following instead:
#
#         - `git clean -xdf` (cleans all files)
#         - `git clean -Xdf` (cleans all versioned files, doesn't touch
#                             files that aren't checked into the git repo)
#
#       Add `--force` to your command to use it anyway if you must (unsupported).
#
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed cleaning build dir for numpy
# Failed to build numpy
# ERROR: Could not build wheels for numpy, which is required to install pyproject.toml-based projects

# %%
# !pip uninstall --force-reinstall torchtext==0.6.0
# Out:
# Usage:
#   pip uninstall [options] <package> ...
#   pip uninstall [options] -r <requirements file> ...
#
# no such option: --force-reinstall

# %%
# !pip install Pillow==7.1.0
# Out:
# Collecting Pillow==7.1.0
#   Downloading Pillow-7.1.0.tar.gz (38.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.9/38.9 MB 3.5 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: Pillow
#   Building wheel for Pillow (setup.py) ... done
#   Created wheel for Pillow: filename=Pillow-7.1.0-cp310-cp310-linux_x86_64.whl size=536543 sha256=7ec16bd4881951cbf2e20077435023d362e1698723bb0b8119d07b70c6240e32
#   Stored in directory: /root/.cache/pip/wheels/37/40/91/598125061a07ea328c64ae966fb88ed98966142bcdd4e9b66e
# Successfully built Pillow
# Installing collected packages: Pillow
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 10.1.0
#     Uninstalling Pillow-10.1.0:
#       Successfully uninstalled Pillow-10.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# easyocr 1.7.1 requires torchvision>=0.5, which is not installed.
# fastai 2.7.13 requires torchvision>=0.11, which is not installed.
# fastai 2.7.13 requires pillow>=9.0.0, but you have pillow 7.1.0 which is incompatible.
# imageio 2.31.1 requires pillow>=8.3.2, but you have pillow 7.1.0 which is incompatible.
# phik 0.12.3 requires joblib>=0.14.1, but you have joblib 0.13.2 which is incompatible.
# pytesseract 0.3.10 requires Pillow>=8.0.0, but you have pillow 7.1.0 which is incompatible.
# scikit-image 0.21.0 requires pillow>=9.0.1, but you have pillow 7.1.0 which is incompatible.
# ydata-profiling 4.5.1 requires numpy<1.24,>=1.16.0, but you have numpy 1.24.3 which is incompatible.
# Successfully installed Pillow-7.1.0

# %%
# !pip install torchvision>=0.11
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# fastai 2.7.13 requires pillow>=9.0.0, but you have pillow 7.1.0 which is incompatible.
# torchaudio 2.0.1+cpu requires torch==2.0.0, but you have torch 2.1.1 which is incompatible.
# torchdata 0.6.0 requires torch==2.0.0, but you have torch 2.1.1 which is incompatible.

# %%
# !pip install pillow>=9.0.1

# %%
# !pip install easyocr==1.7.1
# Out:
# Requirement already satisfied: easyocr==1.7.1 in /opt/conda/lib/python3.10/site-packages (1.7.1)
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (from easyocr==1.7.1) (2.1.1)
# Requirement already satisfied: torchvision>=0.5 in /opt/conda/lib/python3.10/site-packages (from easyocr==1.7.1) (0.16.1)
# Requirement already satisfied: opencv-python-headless in /opt/conda/lib/python3.10/site-packages (from easyocr==1.7.1) (4.8.1.78)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from easyocr==1.7.1) (1.11.3)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from easyocr==1.7.1) (1.24.3)
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.10/site-packages (from easyocr==1.7.1) (7.1.0)
# Requirement already satisfied: scikit-image in /opt/conda/lib/python3.10/site-packages (from easyocr==1.7.1) (0.21.0)
# Requirement already satisfied: python-bidi in /opt/conda/lib/python3.10/site-packages (from easyocr==1.7.1) (0.4.2)
# Requirement already satisfied: PyYAML in /opt/conda/lib/python3.10/site-packages (from easyocr==1.7.1) (6.0.1)
# Requirement already satisfied: Shapely in /opt/conda/lib/python3.10/site-packages (from easyocr==1.7.1) (1.8.5.post1)
# Requirement already satisfied: pyclipper in /opt/conda/lib/python3.10/site-packages (from easyocr==1.7.1) (1.3.0.post5)
# Requirement already satisfied: ninja in /opt/conda/lib/python3.10/site-packages (from easyocr==1.7.1) (1.11.1.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from torchvision>=0.5->easyocr==1.7.1) (2.31.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch->easyocr==1.7.1) (3.12.2)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch->easyocr==1.7.1) (4.5.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch->easyocr==1.7.1) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch->easyocr==1.7.1) (3.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch->easyocr==1.7.1) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch->easyocr==1.7.1) (2023.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch->easyocr==1.7.1) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch->easyocr==1.7.1) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch->easyocr==1.7.1) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /opt/conda/lib/python3.10/site-packages (from torch->easyocr==1.7.1) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /opt/conda/lib/python3.10/site-packages (from torch->easyocr==1.7.1) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /opt/conda/lib/python3.10/site-packages (from torch->easyocr==1.7.1) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /opt/conda/lib/python3.10/site-packages (from torch->easyocr==1.7.1) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /opt/conda/lib/python3.10/site-packages (from torch->easyocr==1.7.1) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /opt/conda/lib/python3.10/site-packages (from torch->easyocr==1.7.1) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in /opt/conda/lib/python3.10/site-packages (from torch->easyocr==1.7.1) (2.18.1)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch->easyocr==1.7.1) (12.1.105)
# Requirement already satisfied: triton==2.1.0 in /opt/conda/lib/python3.10/site-packages (from torch->easyocr==1.7.1) (2.1.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /opt/conda/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->easyocr==1.7.1) (12.3.101)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from python-bidi->easyocr==1.7.1) (1.16.0)
# Collecting Pillow (from easyocr==1.7.1)
#   Downloading Pillow-10.1.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (9.5 kB)
# Requirement already satisfied: imageio>=2.27 in /opt/conda/lib/python3.10/site-packages (from scikit-image->easyocr==1.7.1) (2.31.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /opt/conda/lib/python3.10/site-packages (from scikit-image->easyocr==1.7.1) (2023.8.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-image->easyocr==1.7.1) (1.4.1)
# Requirement already satisfied: packaging>=21 in /opt/conda/lib/python3.10/site-packages (from scikit-image->easyocr==1.7.1) (21.3)
# Requirement already satisfied: lazy_loader>=0.2 in /opt/conda/lib/python3.10/site-packages (from scikit-image->easyocr==1.7.1) (0.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=21->scikit-image->easyocr==1.7.1) (3.0.9)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch->easyocr==1.7.1) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision>=0.5->easyocr==1.7.1) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision>=0.5->easyocr==1.7.1) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision>=0.5->easyocr==1.7.1) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision>=0.5->easyocr==1.7.1) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch->easyocr==1.7.1) (1.3.0)
# Downloading Pillow-10.1.0-cp310-cp310-manylinux_2_28_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 28.3 MB/s eta 0:00:0000:0100:01
# Installing collected packages: Pillow
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 7.1.0
#     Uninstalling Pillow-7.1.0:
#       Successfully uninstalled Pillow-7.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# phik 0.12.3 requires joblib>=0.14.1, but you have joblib 0.13.2 which is incompatible.
# ydata-profiling 4.5.1 requires numpy<1.24,>=1.16.0, but you have numpy 1.24.3 which is incompatible.
# Successfully installed Pillow-10.1.0

# %%
# !pip install spacy==2.2.4
# Out:
# Collecting spacy==2.2.4
#   Downloading spacy-2.2.4.tar.gz (6.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 5.7 MB/s eta 0:00:0000:0100:01m
#   Installing build dependencies ... error
#   error: subprocess-exited-with-error
#
#   × pip subprocess to install build dependencies did not run successfully.
#   │ exit code: 1
#   ╰─> [407 lines of output]
#       Collecting setuptools
#         Using cached setuptools-69.0.2-py3-none-any.whl.metadata (6.3 kB)
#       Collecting wheel
#         Downloading wheel-0.42.0-py3-none-any.whl.metadata (2.2 kB)
#       Collecting cython>=0.25
#         Downloading Cython-3.0.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.2 kB)
#       Collecting cymem<2.1.0,>=2.0.2
#         Downloading cymem-2.0.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.4 kB)
#       Collecting preshed<3.1.0,>=3.0.2
#         Downloading preshed-3.0.9-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.2 kB)
#       Collecting murmurhash<1.1.0,>=0.28.0
#         Downloading murmurhash-1.0.10-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.0 kB)
#       Collecting thinc==7.4.0
#         Downloading thinc-7.4.0.tar.gz (1.3 MB)
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/1.3 MB ? eta -:--:--
#            ━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.1/1.3 MB 4.1 MB/s eta 0:00:01
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━ 1.2/1.3 MB 16.9 MB/s eta 0:00:01
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 13.3 MB/s eta 0:00:00
#         Preparing metadata (setup.py): started
#         Preparing metadata (setup.py): finished with status 'done'
#       Collecting blis<0.5.0,>=0.4.0 (from thinc==7.4.0)
#         Downloading blis-0.4.1.tar.gz (1.8 MB)
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/1.8 MB ? eta -:--:--
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 1.8/1.8 MB 153.4 MB/s eta 0:00:01
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 50.5 MB/s eta 0:00:00
#         Preparing metadata (setup.py): started
#         Preparing metadata (setup.py): finished with status 'done'
#       Collecting wasabi<1.1.0,>=0.0.9 (from thinc==7.4.0)
#         Downloading wasabi-0.10.1-py3-none-any.whl (26 kB)
#       Collecting srsly<1.1.0,>=0.0.6 (from thinc==7.4.0)
#         Downloading srsly-1.0.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
#       Collecting catalogue<1.1.0,>=0.0.7 (from thinc==7.4.0)
#         Downloading catalogue-1.0.2-py2.py3-none-any.whl (16 kB)
#       Collecting numpy>=1.7.0 (from thinc==7.4.0)
#         Downloading numpy-1.26.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/61.2 kB ? eta -:--:--
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 3.5 MB/s eta 0:00:00
#       Collecting plac<1.2.0,>=0.9.6 (from thinc==7.4.0)
#         Downloading plac-1.1.3-py2.py3-none-any.whl (20 kB)
#       Collecting tqdm<5.0.0,>=4.10.0 (from thinc==7.4.0)
#         Downloading tqdm-4.66.1-py3-none-any.whl.metadata (57 kB)
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/57.6 kB ? eta -:--:--
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 3.6 MB/s eta 0:00:00
#       Using cached setuptools-69.0.2-py3-none-any.whl (819 kB)
#       Downloading wheel-0.42.0-py3-none-any.whl (65 kB)
#          ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/65.4 kB ? eta -:--:--
#          ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.4/65.4 kB 3.6 MB/s eta 0:00:00
#       Downloading Cython-3.0.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#          ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/3.6 MB ? eta -:--:--
#          ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 3.6/3.6 MB 162.3 MB/s eta 0:00:01
#          ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 74.6 MB/s eta 0:00:00
#       Downloading cymem-2.0.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (46 kB)
#          ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/46.1 kB ? eta -:--:--
#          ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.1/46.1 kB 2.2 MB/s eta 0:00:00
#       Downloading preshed-3.0.9-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (156 kB)
#          ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/156.9 kB ? eta -:--:--
#          ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.9/156.9 kB 9.0 MB/s eta 0:00:00
#       Downloading murmurhash-1.0.10-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29 kB)
#       Downloading numpy-1.26.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#          ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/18.2 MB ? eta -:--:--
#          ━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/18.2 MB 142.9 MB/s eta 0:00:01
#          ━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━ 9.9/18.2 MB 143.2 MB/s eta 0:00:01
#          ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━ 15.5/18.2 MB 155.0 MB/s eta 0:00:01
#          ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 18.2/18.2 MB 161.5 MB/s eta 0:00:01
#          ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 18.2/18.2 MB 161.5 MB/s eta 0:00:01
#          ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 81.4 MB/s eta 0:00:00
#       Downloading srsly-1.0.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (369 kB)
#          ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/369.2 kB ? eta -:--:--
#          ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 369.2/369.2 kB 19.3 MB/s eta 0:00:00
#       Downloading tqdm-4.66.1-py3-none-any.whl (78 kB)
#          ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/78.3 kB ? eta -:--:--
#          ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 4.1 MB/s eta 0:00:00
#       Building wheels for collected packages: thinc, blis
#         Building wheel for thinc (setup.py): started
#         Building wheel for thinc (setup.py): finished with status 'error'
#         error: subprocess-exited-with-error
#
#         × python setup.py bdist_wheel did not run successfully.
#         │ exit code: 1
#         ╰─> [308 lines of output]
#             /opt/conda/lib/python3.10/site-packages/setuptools/__init__.py:80: _DeprecatedInstaller: setuptools.installer and fetch_build_eggs are deprecated.
#             !!
#
#                     ********************************************************************************
#                     Requirements should be satisfied by a PEP 517 installer.
#                     If you are using pip, you can try `pip install --use-pep517`.
#                     ********************************************************************************
#
#             !!
#               dist.fetch_build_eggs(dist.setup_requires)
#             cc1plus: warning: command line option ‘-Wno-strict-prototypes’ is valid for C/ObjC but not for C++
#             cc1plus: warning: command line option ‘-Wno-strict-prototypes’ is valid for C/ObjC but not for C++
#             cc1plus: warning: command line option ‘-Wno-strict-prototypes’ is valid for C/ObjC but not for C++
#             cc1plus: warning: command line option ‘-Wno-strict-prototypes’ is valid for C/ObjC but not for C++
#             thinc/linear/avgtron.cpp: In function ‘int __pyx_f_5thinc_6linear_7avgtron_18AveragedPerceptron_update_weight_ftrl(__pyx_obj_5thinc_6linear_7avgtron_AveragedPerceptron*, __pyx_t_5thinc_8typedefs_feat_t, __pyx_t_5thinc_8typedefs_class_t, __pyx_t_5thinc_8typedefs_weight_t, int)’:
#             thinc/linear/avgtron.cpp:7404:48: warning: taking address of packed member of ‘__pyx_t_5thinc_7structs_SparseArrayC’ may result in an unaligned pointer value [-Waddress-of-packed-member]
#              7404 |   __pyx_f_5thinc_6linear_7avgtron_adam_update((&(__pyx_v_feat->curr[__pyx_v_i]).val), (&(__pyx_v_feat->mom1[__pyx_v_i]).val), (&(__pyx_v_feat->mom2[__pyx_v_i]).val), __pyx_v_self->time, (__pyx_v_feat->times[__pyx_v_i]).val, __pyx_v_grad, __pyx_v_self->learn_rate, __pyx_v_self->momentum);
#                   |                                               ~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#             thinc/linear/avgtron.cpp:7404:88: warning: taking address of packed member of ‘__pyx_t_5thinc_7structs_SparseArrayC’ may result in an unaligned pointer value [-Waddress-of-packed-member]
#              7404 |   __pyx_f_5thinc_6linear_7avgtron_adam_update((&(__pyx_v_feat->curr[__pyx_v_i]).val), (&(__pyx_v_feat->mom1[__pyx_v_i]).val), (&(__pyx_v_feat->mom2[__pyx_v_i]).val), __pyx_v_self->time, (__pyx_v_feat->times[__pyx_v_i]).val, __pyx_v_grad, __pyx_v_self->learn_rate, __pyx_v_self->momentum);
#                   |                                                                                       ~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#             thinc/linear/avgtron.cpp:7404:128: warning: taking address of packed member of ‘__pyx_t_5thinc_7structs_SparseArrayC’ may result in an unaligned pointer value [-Waddress-of-packed-member]
#              7404 |   __pyx_f_5thinc_6linear_7avgtron_adam_update((&(__pyx_v_feat->curr[__pyx_v_i]).val), (&(__pyx_v_feat->mom1[__pyx_v_i]).val), (&(__pyx_v_feat->mom2[__pyx_v_i]).val), __pyx_v_self->time, (__pyx_v_feat->times[__pyx_v_i]).val, __pyx_v_grad, __pyx_v_self->learn_rate, __pyx_v_self->momentum);
#                   |                                                                                                                               ~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#             In file included from /opt/conda/include/python3.10/Python.h:74,
#                              from thinc/linear/avgtron.cpp:4:
#             thinc/linear/avgtron.cpp: In function ‘void __pyx_tp_dealloc_5thinc_6linear_7avgtron_AveragedPerceptron(PyObject*)’:
#             /opt/conda/include/python3.10/object.h:133:58: error: lvalue required as increment operand
#               133 | #define Py_REFCNT(ob) _Py_REFCNT(_PyObject_CAST_CONST(ob))
#                   |                                                          ^
#             thinc/linear/avgtron.cpp:14044:7: note: in expansion of macro ‘Py_REFCNT’
#             14044 |     ++Py_REFCNT(o);
#                   |       ^~~~~~~~~
#             /opt/conda/include/python3.10/object.h:133:58: error: lvalue required as decrement operand
#               133 | #define Py_REFCNT(ob) _Py_REFCNT(_PyObject_CAST_CONST(ob))
#                   |                                                          ^
#             thinc/linear/avgtron.cpp:14046:7: note: in expansion of macro ‘Py_REFCNT’
#             14046 |     --Py_REFCNT(o);
#                   |       ^~~~~~~~~
#             In file included from /opt/conda/include/python3.10/unicodeobject.h:1046,
#                              from /opt/conda/include/python3.10/Python.h:83,
#                              from thinc/linear/avgtron.cpp:4:
#             thinc/linear/avgtron.cpp: In function ‘int __Pyx_ParseOptionalKeywords(PyObject*, PyObject***, PyObject*, PyObject**, Py_ssize_t, const char*)’:
#             /opt/conda/include/python3.10/cpython/unicodeobject.h:451:75: warning: ‘Py_ssize_t _PyUnicode_get_wstr_length(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#               451 | #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#                   |                                                                           ^
#             /opt/conda/include/python3.10/cpython/unicodeobject.h:261:7: note: in expansion of macro ‘PyUnicode_WSTR_LENGTH’
#               261 |       PyUnicode_WSTR_LENGTH(op) :                    \
#                   |       ^~~~~~~~~~~~~~~~~~~~~
#             thinc/linear/avgtron.cpp:15133:22: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#             15133 |                     (PyUnicode_GET_SIZE(**name) != PyUnicode_GET_SIZE(key)) ? 1 :
#                   |                      ^~~~~~~~~~~~~~~~~~
#             /opt/conda/include/python3.10/cpython/unicodeobject.h:446:26: note: declared here
#               446 | static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#                   |                          ^~~~~~~~~~~~~~~~~~~~~~~~~~
#             /opt/conda/include/python3.10/cpython/unicodeobject.h:451:75: warning: ‘Py_ssize_t _PyUnicode_get_wstr_length(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#               451 | #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#                   |                                                                           ^
#             /opt/conda/include/python3.10/cpython/unicodeobject.h:261:7: note: in expansion of macro ‘PyUnicode_WSTR_LENGTH’
#               261 |       PyUnicode_WSTR_LENGTH(op) :                    \
#                   |       ^~~~~~~~~~~~~~~~~~~~~
#             thinc/linear/avgtron.cpp:15133:22: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#             15133 |                     (PyUnicode_GET_SIZE(**name) != PyUnicode_GET_SIZE(key)) ? 1 :
#                   |                      ^~~~~~~~~~~~~~~~~~
#             /opt/conda/include/python3.10/cpython/unicodeobject.h:446:26: note: declared here
#               446 | static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#                   |                          ^~~~~~~~~~~~~~~~~~~~~~~~~~
#             /opt/conda/include/python3.10/cpython/unicodeobject.h:262:52: warning: ‘Py_UNICODE* PyUnicode_AsUnicode(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#               262 |       ((void)PyUnicode_AsUnicode(_PyObject_CAST(op)),\
#                   |                                                    ^
#             thinc/linear/avgtron.cpp:15133:22: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#             15133 |                     (PyUnicode_GET_SIZE(**name) != PyUnicode_GET_SIZE(key)) ? 1 :
#                   |                      ^~~~~~~~~~~~~~~~~~
#             /opt/conda/include/python3.10/cpython/unicodeobject.h:580:45: note: declared here
#               580 | Py_DEPRECATED(3.3) PyAPI_FUNC(Py_UNICODE *) PyUnicode_AsUnicode(
#                   |                                             ^~~~~~~~~~~~~~~~~~~
#             /opt/conda/include/python3.10/cpython/unicodeobject.h:262:52: warning: ‘Py_UNICODE* PyUnicode_AsUnicode(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#               262 |       ((void)PyUnicode_AsUnicode(_PyObject_CAST(op)),\
#                   |                                                    ^
#             thinc/linear/avgtron.cpp:15133:22: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#             15133 |                     (PyUnicode_GET_SIZE(**name) != PyUnicode_GET_SIZE(key)) ? 1 :
#                   |                      ^~~~~~~~~~~~~~~~~~
#             /opt/conda/include/python3.10/cpython/unicodeobject.h:580:45: note: declared here
#               580 | Py_DEPRECATED(3.3) PyAPI_FUNC(Py_UNICODE *) PyUnicode_AsUnicode(
#                   |                                             ^~~~~~~~~~~~~~~~~~~
#             /opt/conda/include/python3.10/cpython/unicodeobject.h:451:75: warning: ‘Py_ssize_t _PyUnicode_get_wstr_length(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#               451 | #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#                   |                                                                           ^
#             /opt/conda/include/python3.10/cpython/unicodeobject.h:264:8: note: in expansion of macro ‘PyUnicode_WSTR_LENGTH’
#               264 |        PyUnicode_WSTR_LENGTH(op)))
#                   |        ^~~~~~~~~~~~~~~~~~~~~
#             thinc/linear/avgtron.cpp:15133:22: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#             15133 |                     (PyUnicode_GET_SIZE(**name) != PyUnicode_GET_SIZE(key)) ? 1 :
#                   |                      ^~~~~~~~~~~~~~~~~~
#             /opt/conda/include/python3.10/cpython/unicodeobject.h:446:26: note: declared here
#               446 | static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#                   |                          ^~~~~~~~~~~~~~~~~~~~~~~~~~
#             /opt/conda/include/python3.10/cpython/unicodeobject.h:451:75: warning: ‘Py_ssize_t _PyUnicode_get_wstr_length(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#               451 | #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#                   |                                                                           ^
#             /opt/conda/include/python3.10/cpython/unicodeobject.h:264:8: note: in expansion of macro ‘PyUnicode_WSTR_LENGTH’
#               264 |        PyUnicode_WSTR_LENGTH(op)))
#                   |        ^~~~~~~~~~~~~~~~~~~~~
#             thinc/linear/avgtron.cpp:15133:22: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#             15133 |                     (PyUnicode_GET_SIZE(**name) != PyUnicode_GET_SIZE(key)) ? 1 :
#                   |                      ^~~~~~~~~~~~~~~~~~
#             /opt/conda/include/python3.10/cpython/unicodeobject.h:446:26: note: declared here
#               446 | static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#                   |                          ^~~~~~~~~~~~~~~~~~~~~~~~~~
#             /opt/conda/include/python3.10/cpython/unicodeobject.h:451:75: warning: ‘Py_ssize_t _PyUnicode_get_wstr_length(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#               451 | #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#                   |                                                                           ^
#             /opt/conda/include/python3.10/cpython/unicodeobject.h:261:7: note: in expansion of macro ‘PyUnicode_WSTR_LENGTH’
#               261 |       PyUnicode_WSTR_LENGTH(op) :                    \
#                   |       ^~~~~~~~~~~~~~~~~~~~~
#             thinc/linear/avgtron.cpp:15133:52: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#             15133 |                     (PyUnicode_GET_SIZE(**name) != PyUnicode_GET_SIZE(key)) ? 1 :
#                   |                                                    ^~~~~~~~~~~~~~~~~~
#             /opt/conda/include/python3.10/cpython/unicodeobject.h:446:26: note: declared here
#               446 | static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#                   |                          ^~~~~~~~~~~~~~~~~~~~~~~~~~
#             /opt/conda/include/python3.10/cpython/unicodeobject.h:451:75: warning: ‘Py_ssize_t _PyUnicode_get_wstr_length(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#               451 | #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#                   |                                                                           ^
#             /opt/conda/include/python3.10/cpython/unicodeobject.h:261:7: note: in expansion of macro ‘PyUnicode_WSTR_LENGTH’
#               261 |       PyUnicode_WSTR_LENGTH(op) :                    \
#                   |       ^~~~~~~~~~~~~~~~~~~~~
#             thinc/linear/avgtron.cpp:15133:52: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#             15133 |                     (PyUnicode_GET_SIZE(**name) != PyUnicode_GET_SIZE(key)) ? 1 :
#                   |                                                    ^~~~~~~~~~~~~~~~~~
#             /opt/conda/include/python3.10/cpython/unicodeobject.h:446:26: note: declared here
#               446 | static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#                   |                          ^~~~~~~~~~~~~~~~~~~~~~~~~~
#             /opt/conda/include/python3.10/cpython/unicodeobject.h:262:52: warning: ‘Py_UNICODE* PyUnicode_AsUnicode(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#               262 |       ((void)PyUnicode_AsUnicode(_PyObject_CAST(op)),\
#                   |                                                    ^
#             thinc/linear/avgtron.cpp:15133:52: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#             15133 |                     (PyUnicode_GET_SIZE(**name) != PyUnicode_GET_SIZE(key)) ? 1 :
#                   |                                                    ^~~~~~~~~~~~~~~~~~
#             /opt/conda/include/python3.10/cpython/unicodeobject.h:580:45: note: declared here
#               580 | Py_DEPRECATED(3.3) PyAPI_FUNC(Py_UNICODE *) PyUnicode_AsUnicode(
#                   |                                             ^~~~~~~~~~~~~~~~~~~
#             /opt/conda/include/python3.10/cpython/unicodeobject.h:262:52: warning: ‘Py_UNICODE* PyUnicode_AsUnicode(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#               262 |       ((void)PyUnicode_AsUnicode(_PyObject_CAST(op)),\
#                   |                                                    ^
#             thinc/linear/avgtron.cpp:15133:52: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#             15133 |                     (PyUnicode_GET_SIZE(**name) != PyUnicode_GET_SIZE(key)) ? 1 :
#                   |                                                    ^~~~~~~~~~~~~~~~~~
#             /opt/conda/include/python3.10/cpython/unicodeobject.h:580:45: note: declared here
#               580 | Py_DEPRECATED(3.3) PyAPI_FUNC(Py_UNICODE *) PyUnicode_AsUnicode(
#                   |                                             ^~~~~~~~~~~~~~~~~~~
#             /opt/conda/include/python3.10/cpython/unicodeobject.h:451:75: warning: ‘Py_ssize_t _PyUnicode_get_wstr_length(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#               451 | #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#                   |                                                                           ^
#             /opt/conda/include/python3.10/cpython/unicodeobject.h:264:8: note: in expansion of macro ‘PyUnicode_WSTR_LENGTH’
#               264 |        PyUnicode_WSTR_LENGTH(op)))
#                   |        ^~~~~~~~~~~~~~~~~~~~~
#             thinc/linear/avgtron.cpp:15133:52: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#             15133 |                     (PyUnicode_GET_SIZE(**name) != PyUnicode_GET_SIZE(key)) ? 1 :
#                   |                                                    ^~~~~~~~~~~~~~~~~~
#             /opt/conda/include/python3.10/cpython/unicodeobject.h:446:26: note: declared here
#               446 | static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#                   |                          ^~~~~~~~~~~~~~~~~~~~~~~~~~
#             /opt/conda/include/python3.10/cpython/unicodeobject.h:451:75: warning: ‘Py_ssize_t _PyUnicode_get_wstr_length(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#               451 | #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#                   |                                                                           ^
#             /opt/conda/include/python3.10/cpython/unicodeobject.h:264:8: note: in expansion of macro ‘PyUnicode_WSTR_LENGTH’
#               264 |        PyUnicode_WSTR_LENGTH(op)))
#                   |        ^~~~~~~~~~~~~~~~~~~~~
#             thinc/linear/avgtron.cpp:15133:52: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#             15133 |                     (PyUnicode_GET_SIZE(**name) != PyUnicode_GET_SIZE(key)) ? 1 :
#                   |                                                    ^~~~~~~~~~~~~~~~~~
#             /opt/conda/include/python3.10/cpython/unicodeobject.h:446:26: note: declared here
#               446 | static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#                   |                          ^~~~~~~~~~~~~~~~~~~~~~~~~~
#             /opt/conda/include/python3.10/cpython/unicodeobject.h:451:75: warning: ‘Py_ssize_t _PyUnicode_get_wstr_length(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#               451 | #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#                   |                                                                           ^
#             /opt/conda/include/python3.10/cpython/unicodeobject.h:261:7: note: in expansion of macro ‘PyUnicode_WSTR_LENGTH’
#               261 |       PyUnicode_WSTR_LENGTH(op) :                    \
#                   |       ^~~~~~~~~~~~~~~~~~~~~
#             thinc/linear/avgtron.cpp:15149:26: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#             15149 |                         (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#                   |                          ^~~~~~~~~~~~~~~~~~
#             /opt/conda/include/python3.10/cpython/unicodeobject.h:446:26: note: declared here
#               446 | static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#                   |                          ^~~~~~~~~~~~~~~~~~~~~~~~~~
#             /opt/conda/include/python3.10/cpython/unicodeobject.h:451:75: warning: ‘Py_ssize_t _PyUnicode_get_wstr_length(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#               451 | #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#                   |                                                                           ^
#             /opt/conda/include/python3.10/cpython/unicodeobject.h:261:7: note: in expansion of macro ‘PyUnicode_WSTR_LENGTH’
#               261 |       PyUnicode_WSTR_LENGTH(op) :                    \
#                   |       ^~~~~~~~~~~~~~~~~~~~~
#             thinc/linear/avgtron.cpp:15149:26: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#             15149 |                         (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#                   |                          ^~~~~~~~~~~~~~~~~~
#             /opt/conda/include/python3.10/cpython/unicodeobject.h:446:26: note: declared here
#               446 | static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#                   |                          ^~~~~~~~~~~~~~~~~~~~~~~~~~
#             /opt/conda/include/python3.10/cpython/unicodeobject.h:262:52: warning: ‘Py_UNICODE* PyUnicode_AsUnicode(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#               262 |       ((void)PyUnicode_AsUnicode(_PyObject_CAST(op)),\
#                   |                                                    ^
#             thinc/linear/avgtron.cpp:15149:26: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#             15149 |                         (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#                   |                          ^~~~~~~~~~~~~~~~~~
#             /opt/conda/include/python3.10/cpython/unicodeobject.h:580:45: note: declared here
#               580 | Py_DEPRECATED(3.3) PyAPI_FUNC(Py_UNICODE *) PyUnicode_AsUnicode(
#                   |                                             ^~~~~~~~~~~~~~~~~~~
#             /opt/conda/include/python3.10/cpython/unicodeobject.h:262:52: warning: ‘Py_UNICODE* PyUnicode_AsUnicode(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#               262 |       ((void)PyUnicode_AsUnicode(_PyObject_CAST(op)),\
#                   |                                                    ^
#             thinc/linear/avgtron.cpp:15149:26: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#             15149 |                         (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#                   |                          ^~~~~~~~~~~~~~~~~~
#             /opt/conda/include/python3.10/cpython/unicodeobject.h:580:45: note: declared here
#               580 | Py_DEPRECATED(3.3) PyAPI_FUNC(Py_UNICODE *) PyUnicode_AsUnicode(
#                   |                                             ^~~~~~~~~~~~~~~~~~~
#             /opt/conda/include/python3.10/cpython/unicodeobject.h:451:75: warning: ‘Py_ssize_t _PyUnicode_get_wstr_length(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#               451 | #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#                   |                                                                           ^
#             /opt/conda/include/python3.10/cpython/unicodeobject.h:264:8: note: in expansion of macro ‘PyUnicode_WSTR_LENGTH’
#               264 |        PyUnicode_WSTR_LENGTH(op)))
#                   |        ^~~~~~~~~~~~~~~~~~~~~
#             thinc/linear/avgtron.cpp:15149:26: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#             15149 |                         (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#                   |                          ^~~~~~~~~~~~~~~~~~
#             /opt/conda/include/python3.10/cpython/unicodeobject.h:446:26: note: declared here
#               446 | static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#                   |                          ^~~~~~~~~~~~~~~~~~~~~~~~~~
#             /opt/conda/include/python3.10/cpython/unicodeobject.h:451:75: warning: ‘Py_ssize_t _PyUnicode_get_wstr_length(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#               451 | #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#                   |                                                                           ^
#             /opt/conda/include/python3.10/cpython/unicodeobject.h:264:8: note: in expansion of macro ‘PyUnicode_WSTR_LENGTH’
#               264 |        PyUnicode_WSTR_LENGTH(op)))
#                   |        ^~~~~~~~~~~~~~~~~~~~~
#             thinc/linear/avgtron.cpp:15149:26: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#             15149 |                         (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#                   |                          ^~~~~~~~~~~~~~~~~~
#             /opt/conda/include/python3.10/cpython/unicodeobject.h:446:26: note: declared here
#               446 | static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#                   |                          ^~~~~~~~~~~~~~~~~~~~~~~~~~
#             /opt/conda/include/python3.10/cpython/unicodeobject.h:451:75: warning: ‘Py_ssize_t _PyUnicode_get_wstr_length(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#               451 | #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#                   |                                                                           ^
#             /opt/conda/include/python3.10/cpython/unicodeobject.h:261:7: note: in expansion of macro ‘PyUnicode_WSTR_LENGTH’
#               261 |       PyUnicode_WSTR_LENGTH(op) :                    \
#                   |       ^~~~~~~~~~~~~~~~~~~~~
#             thinc/linear/avgtron.cpp:15149:59: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#             15149 |                         (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#                   |                                                           ^~~~~~~~~~~~~~~~~~
#             /opt/conda/include/python3.10/cpython/unicodeobject.h:446:26: note: declared here
#               446 | static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#                   |                          ^~~~~~~~~~~~~~~~~~~~~~~~~~
#             /opt/conda/include/python3.10/cpython/unicodeobject.h:451:75: warning: ‘Py_ssize_t _PyUnicode_get_wstr_length(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#               451 | #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#                   |                                                                           ^
#             /opt/conda/include/python3.10/cpython/unicodeobject.h:261:7: note: in expansion of macro ‘PyUnicode_WSTR_LENGTH’
#               261 |       PyUnicode_WSTR_LENGTH(op) :                    \
#                   |       ^~~~~~~~~~~~~~~~~~~~~
#             thinc/linear/avgtron.cpp:15149:59: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#             15149 |                         (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#                   |                                                           ^~~~~~~~~~~~~~~~~~
#             /opt/conda/include/python3.10/cpython/unicodeobject.h:446:26: note: declared here
#               446 | static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#                   |                          ^~~~~~~~~~~~~~~~~~~~~~~~~~
#             /opt/conda/include/python3.10/cpython/unicodeobject.h:262:52: warning: ‘Py_UNICODE* PyUnicode_AsUnicode(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#               262 |       ((void)PyUnicode_AsUnicode(_PyObject_CAST(op)),\
#                   |                                                    ^
#             thinc/linear/avgtron.cpp:15149:59: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#             15149 |                         (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#                   |                                                           ^~~~~~~~~~~~~~~~~~
#             /opt/conda/include/python3.10/cpython/unicodeobject.h:580:45: note: declared here
#               580 | Py_DEPRECATED(3.3) PyAPI_FUNC(Py_UNICODE *) PyUnicode_AsUnicode(
#                   |                                             ^~~~~~~~~~~~~~~~~~~
#             /opt/conda/include/python3.10/cpython/unicodeobject.h:262:52: warning: ‘Py_UNICODE* PyUnicode_AsUnicode(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#               262 |       ((void)PyUnicode_AsUnicode(_PyObject_CAST(op)),\
#                   |                                                    ^
#             thinc/linear/avgtron.cpp:15149:59: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#             15149 |                         (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#                   |                                                           ^~~~~~~~~~~~~~~~~~
#             /opt/conda/include/python3.10/cpython/unicodeobject.h:580:45: note: declared here
#               580 | Py_DEPRECATED(3.3) PyAPI_FUNC(Py_UNICODE *) PyUnicode_AsUnicode(
#                   |                                             ^~~~~~~~~~~~~~~~~~~
#             /opt/conda/include/python3.10/cpython/unicodeobject.h:451:75: warning: ‘Py_ssize_t _PyUnicode_get_wstr_length(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#               451 | #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#                   |                                                                           ^
#             /opt/conda/include/python3.10/cpython/unicodeobject.h:264:8: note: in expansion of macro ‘PyUnicode_WSTR_LENGTH’
#               264 |        PyUnicode_WSTR_LENGTH(op)))
#                   |        ^~~~~~~~~~~~~~~~~~~~~
#             thinc/linear/avgtron.cpp:15149:59: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#             15149 |                         (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#                   |                                                           ^~~~~~~~~~~~~~~~~~
#             /opt/conda/include/python3.10/cpython/unicodeobject.h:446:26: note: declared here
#               446 | static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#                   |                          ^~~~~~~~~~~~~~~~~~~~~~~~~~
#             /opt/conda/include/python3.10/cpython/unicodeobject.h:451:75: warning: ‘Py_ssize_t _PyUnicode_get_wstr_length(PyObject*)’ is deprecated [-Wdeprecated-declarations]
#               451 | #define PyUnicode_WSTR_LENGTH(op) _PyUnicode_get_wstr_length((PyObject*)op)
#                   |                                                                           ^
#             /opt/conda/include/python3.10/cpython/unicodeobject.h:264:8: note: in expansion of macro ‘PyUnicode_WSTR_LENGTH’
#               264 |        PyUnicode_WSTR_LENGTH(op)))
#                   |        ^~~~~~~~~~~~~~~~~~~~~
#             thinc/linear/avgtron.cpp:15149:59: note: in expansion of macro ‘PyUnicode_GET_SIZE’
#             15149 |                         (PyUnicode_GET_SIZE(**argname) != PyUnicode_GET_SIZE(key)) ? 1 :
#                   |                                                           ^~~~~~~~~~~~~~~~~~
#             /opt/conda/include/python3.10/cpython/unicodeobject.h:446:26: note: declared here
#               446 | static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#                   |                          ^~~~~~~~~~~~~~~~~~~~~~~~~~
#             error: command '/usr/bin/gcc' failed with exit code 1
#             [end of output]
#
#         note: This error originates from a subprocess, and is likely not a problem with pip.
#         ERROR: Failed building wheel for thinc
#         Running setup.py clean for thinc
#         Building wheel for blis (setup.py): started
#         Building wheel for blis (setup.py): still running...
#         Building wheel for blis (setup.py): still running...
#         Building wheel for blis (setup.py): still running...
#         Building wheel for blis (setup.py): still running...
#         Building wheel for blis (setup.py): still running...
#         Building wheel for blis (setup.py): still running...
#         Building wheel for blis (setup.py): finished with status 'done'
#         Created wheel for blis: filename=blis-0.4.1-cp310-cp310-linux_x86_64.whl size=5581457 sha256=14382c26d30088eb026b17bf2393052bf264e3d48b5ec79987380278de5c0123
#         Stored in directory: /root/.cache/pip/wheels/69/64/36/675cf1e854b0dcdf3ddf5ffc6275f6665707d86d72de0f150e
#       Successfully built blis
#       Failed to build thinc
#       ERROR: Could not build wheels for thinc, which is required to install pyproject.toml-based projects
#
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# × pip subprocess to install build dependencies did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %%
# !pip install torch==1.11.0
# Out:
# Collecting torch==1.11.0
#   Downloading torch-1.11.0-cp310-cp310-manylinux1_x86_64.whl (750.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 750.6/750.6 MB 1.1 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch==1.11.0) (4.5.0)
# Installing collected packages: torch
#   Attempting uninstall: torch
#     Found existing installation: torch 2.1.1
#     Uninstalling torch-2.1.1:
#       Successfully uninstalled torch-2.1.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pytorch-lightning 2.1.1 requires torch>=1.12.0, but you have torch 1.11.0 which is incompatible.
# torchaudio 2.0.1+cpu requires torch==2.0.0, but you have torch 1.11.0 which is incompatible.
# torchdata 0.6.0 requires torch==2.0.0, but you have torch 1.11.0 which is incompatible.
# torchvision 0.16.1 requires torch==2.1.1, but you have torch 1.11.0 which is incompatible.
# Successfully installed torch-1.11.0

# %%
# !pip install torchtext==0.6.0
# Out:
# Collecting torchtext==0.6.0
#   Downloading torchtext-0.6.0-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.2/64.2 kB 112.1 kB/s eta 0:00:00 0:00:01
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from torchtext==0.6.0) (4.66.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from torchtext==0.6.0) (2.31.0)
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (from torchtext==0.6.0) (1.11.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from torchtext==0.6.0) (1.24.3)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from torchtext==0.6.0) (1.16.0)
# Requirement already satisfied: sentencepiece in /opt/conda/lib/python3.10/site-packages (from torchtext==0.6.0) (0.1.99)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->torchtext==0.6.0) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->torchtext==0.6.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->torchtext==0.6.0) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->torchtext==0.6.0) (2023.7.22)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch->torchtext==0.6.0) (4.5.0)
# Installing collected packages: torchtext
# Successfully installed torchtext-0.6.0

# %%
# !pip install torchvision==0.12.0
# Out:
# Collecting torchvision==0.12.0
#   Downloading torchvision-0.12.0-cp310-cp310-manylinux1_x86_64.whl (21.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 5.3 MB/s eta 0:00:0000:0100:01m
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torchvision==0.12.0) (4.5.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from torchvision==0.12.0) (1.24.3)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from torchvision==0.12.0) (2.31.0)
# Requirement already satisfied: torch==1.11.0 in /opt/conda/lib/python3.10/site-packages (from torchvision==0.12.0) (1.11.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/conda/lib/python3.10/site-packages (from torchvision==0.12.0) (10.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision==0.12.0) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision==0.12.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision==0.12.0) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision==0.12.0) (2023.7.22)
# Installing collected packages: torchvision
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.16.1
#     Uninstalling torchvision-0.16.1:
#       Successfully uninstalled torchvision-0.16.1
# Successfully installed torchvision-0.12.0

# %%
# !pip install tqdm==4.46.1
# Out:
# Collecting tqdm==4.46.1
#   Downloading tqdm-4.46.1-py2.py3-none-any.whl (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 1.4 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: tqdm
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.66.1
#     Uninstalling tqdm-4.66.1:
#       Successfully uninstalled tqdm-4.66.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# beatrix-jupyterlab 2023.814.150030 requires jupyter-server~=1.16, but you have jupyter-server 2.10.0 which is incompatible.
# beatrix-jupyterlab 2023.814.150030 requires jupyterlab~=3.4, but you have jupyterlab 4.0.5 which is incompatible.
# datasets 2.1.0 requires tqdm>=4.62.1, but you have tqdm 4.46.1 which is incompatible.
# fitter 1.6.0 requires joblib<2.0.0,>=1.3.1, but you have joblib 0.13.2 which is incompatible.
# fitter 1.6.0 requires tqdm<5.0.0,>=4.65.1, but you have tqdm 4.46.1 which is incompatible.
# momepy 0.6.0 requires shapely>=2, but you have shapely 1.8.5.post1 which is incompatible.
# panel 1.3.1 requires tqdm>=4.48.0, but you have tqdm 4.46.1 which is incompatible.
# pytorch-lightning 2.1.1 requires torch>=1.12.0, but you have torch 1.11.0 which is incompatible.
# pytorch-lightning 2.1.1 requires tqdm>=4.57.0, but you have tqdm 4.46.1 which is incompatible.
# ydata-profiling 4.5.1 requires numpy<1.24,>=1.16.0, but you have numpy 1.24.3 which is incompatible.
# ydata-profiling 4.5.1 requires tqdm<5,>=4.48.2, but you have tqdm 4.46.1 which is incompatible.
# Successfully installed tqdm-4.46.1

# %%
#!pip uninstall numpy --yes

# %%
# !wget https://github.com/allinegsPY/Gerador-de-legenda/blob/main/requirements.txt

# %%
# !pip install --no-build-isolation numpy==1.17.0

# %%
# !pip install -r requirements.txt
# !python -m spacy download pt
# !python -m spacy download pt_core_news_lg

# %%
# !pip cache purge
# !pip install typing-extensions

# %%
# !pip install --force-reinstall typing-extensions

# %%
#!pip install --upgrade torch torchvision torchaudio

# %%
# !pip install jupyter-lsp==2.0.0
# Out:
# Collecting jupyter-lsp==2.0.0
#   Downloading jupyter_lsp-2.0.0-py3-none-any.whl (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 1.5 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: jupyter-server>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from jupyter-lsp==2.0.0) (2.10.0)
# Requirement already satisfied: anyio>=3.1.0 in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.1.2->jupyter-lsp==2.0.0) (3.7.1)
# Requirement already satisfied: argon2-cffi in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.1.2->jupyter-lsp==2.0.0) (21.3.0)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.1.2->jupyter-lsp==2.0.0) (3.1.2)
# Requirement already satisfied: jupyter-client>=7.4.4 in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.1.2->jupyter-lsp==2.0.0) (7.4.9)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.1.2->jupyter-lsp==2.0.0) (5.3.1)
# Requirement already satisfied: jupyter-events>=0.6.0 in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.1.2->jupyter-lsp==2.0.0) (0.7.0)
# Requirement already satisfied: jupyter-server-terminals in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.1.2->jupyter-lsp==2.0.0) (0.4.4)
# Requirement already satisfied: nbconvert>=6.4.4 in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.1.2->jupyter-lsp==2.0.0) (6.4.5)
# Requirement already satisfied: nbformat>=5.3.0 in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.1.2->jupyter-lsp==2.0.0) (5.9.2)
# Requirement already satisfied: overrides in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.1.2->jupyter-lsp==2.0.0) (6.5.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.1.2->jupyter-lsp==2.0.0) (21.3)
# Requirement already satisfied: prometheus-client in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.1.2->jupyter-lsp==2.0.0) (0.17.1)
# Requirement already satisfied: pyzmq>=24 in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.1.2->jupyter-lsp==2.0.0) (24.0.1)
# Requirement already satisfied: send2trash>=1.8.2 in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.1.2->jupyter-lsp==2.0.0) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.1.2->jupyter-lsp==2.0.0) (0.17.1)
# Requirement already satisfied: tornado>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.1.2->jupyter-lsp==2.0.0) (6.3.3)
# Requirement already satisfied: traitlets>=5.6.0 in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.1.2->jupyter-lsp==2.0.0) (5.9.0)
# Requirement already satisfied: websocket-client in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.1.2->jupyter-lsp==2.0.0) (1.6.2)
# Requirement already satisfied: idna>=2.8 in /opt/conda/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server>=1.1.2->jupyter-lsp==2.0.0) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server>=1.1.2->jupyter-lsp==2.0.0) (1.3.0)
# Requirement already satisfied: exceptiongroup in /opt/conda/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server>=1.1.2->jupyter-lsp==2.0.0) (1.1.3)
# Requirement already satisfied: entrypoints in /opt/conda/lib/python3.10/site-packages (from jupyter-client>=7.4.4->jupyter-server>=1.1.2->jupyter-lsp==2.0.0) (0.4)
# Requirement already satisfied: nest-asyncio>=1.5.4 in /opt/conda/lib/python3.10/site-packages (from jupyter-client>=7.4.4->jupyter-server>=1.1.2->jupyter-lsp==2.0.0) (1.5.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from jupyter-client>=7.4.4->jupyter-server>=1.1.2->jupyter-lsp==2.0.0) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in /opt/conda/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server>=1.1.2->jupyter-lsp==2.0.0) (4.0.0)
# Requirement already satisfied: jsonschema>=4.18.0 in /opt/conda/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server>=1.1.2->jupyter-lsp==2.0.0) (4.19.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /opt/conda/lib/python3.10/site-packages (from jupyter-events>=0.6.0->jupyter-server>=1.1.2->jupyter-lsp==2.0.0) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in /opt/conda/lib/python3.10/site-packages (from jupyter-events>=0.6.0->jupyter-server>=1.1.2->jupyter-lsp==2.0.0) (6.0.1)
# Requirement already satisfied: referencing in /opt/conda/lib/python3.10/site-packages (from jupyter-events>=0.6.0->jupyter-server>=1.1.2->jupyter-lsp==2.0.0) (0.30.2)
# Requirement already satisfied: rfc3339-validator in /opt/conda/lib/python3.10/site-packages (from jupyter-events>=0.6.0->jupyter-server>=1.1.2->jupyter-lsp==2.0.0) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /opt/conda/lib/python3.10/site-packages (from jupyter-events>=0.6.0->jupyter-server>=1.1.2->jupyter-lsp==2.0.0) (0.1.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /opt/conda/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server>=1.1.2->jupyter-lsp==2.0.0) (0.8.4)
# Requirement already satisfied: pygments>=2.4.1 in /opt/conda/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server>=1.1.2->jupyter-lsp==2.0.0) (2.16.1)
# Requirement already satisfied: jupyterlab-pygments in /opt/conda/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server>=1.1.2->jupyter-lsp==2.0.0) (0.2.2)
# Requirement already satisfied: bleach in /opt/conda/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server>=1.1.2->jupyter-lsp==2.0.0) (6.0.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/conda/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server>=1.1.2->jupyter-lsp==2.0.0) (1.5.0)
# Requirement already satisfied: testpath in /opt/conda/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server>=1.1.2->jupyter-lsp==2.0.0) (0.6.0)
# Requirement already satisfied: defusedxml in /opt/conda/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server>=1.1.2->jupyter-lsp==2.0.0) (0.7.1)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server>=1.1.2->jupyter-lsp==2.0.0) (4.12.2)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /opt/conda/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server>=1.1.2->jupyter-lsp==2.0.0) (0.5.13)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server>=1.1.2->jupyter-lsp==2.0.0) (2.1.3)
# Requirement already satisfied: fastjsonschema in /opt/conda/lib/python3.10/site-packages (from nbformat>=5.3.0->jupyter-server>=1.1.2->jupyter-lsp==2.0.0) (2.18.0)
# Requirement already satisfied: ptyprocess in /opt/conda/lib/python3.10/site-packages (from terminado>=0.8.3->jupyter-server>=1.1.2->jupyter-lsp==2.0.0) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /opt/conda/lib/python3.10/site-packages (from argon2-cffi->jupyter-server>=1.1.2->jupyter-lsp==2.0.0) (21.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->jupyter-server>=1.1.2->jupyter-lsp==2.0.0) (3.0.9)
# Requirement already satisfied: attrs>=22.2.0 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=4.18.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server>=1.1.2->jupyter-lsp==2.0.0) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=4.18.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server>=1.1.2->jupyter-lsp==2.0.0) (2023.7.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=4.18.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server>=1.1.2->jupyter-lsp==2.0.0) (0.9.2)
# Requirement already satisfied: fqdn in /opt/conda/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server>=1.1.2->jupyter-lsp==2.0.0) (1.5.1)
# Requirement already satisfied: isoduration in /opt/conda/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server>=1.1.2->jupyter-lsp==2.0.0) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /opt/conda/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server>=1.1.2->jupyter-lsp==2.0.0) (2.0)
# Requirement already satisfied: uri-template in /opt/conda/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server>=1.1.2->jupyter-lsp==2.0.0) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in /opt/conda/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server>=1.1.2->jupyter-lsp==2.0.0) (1.13)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->jupyter-client>=7.4.4->jupyter-server>=1.1.2->jupyter-lsp==2.0.0) (1.16.0)
# Requirement already satisfied: cffi>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server>=1.1.2->jupyter-lsp==2.0.0) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server>=1.1.2->jupyter-lsp==2.0.0) (2.3.2.post1)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.10/site-packages (from bleach->nbconvert>=6.4.4->jupyter-server>=1.1.2->jupyter-lsp==2.0.0) (0.5.1)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server>=1.1.2->jupyter-lsp==2.0.0) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in /opt/conda/lib/python3.10/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server>=1.1.2->jupyter-lsp==2.0.0) (1.2.3)
# Installing collected packages: jupyter-lsp
#   Attempting uninstall: jupyter-lsp
#     Found existing installation: jupyter-lsp 1.5.1
#     Uninstalling jupyter-lsp-1.5.1:
#       Successfully uninstalled jupyter-lsp-1.5.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jupyterlab-lsp 5.0.0 requires jupyterlab<5.0.0a0,>=4.0.6, but you have jupyterlab 4.0.5 which is incompatible.
# Successfully installed jupyter-lsp-2.0.0

# %%
# !pip install --force-reinstall --no-deps ipython==8.14.0

# %%
# !pip install ipython

# %%
# !pip install --upgrade torchtext

# %%
# !pip uninstall torchtext --yes
# !git clone https://github.com/pytorch/text.git
# !cd text
# !pip install .

# %%
# !pip install torch==1.11.0
# !pip install torchtext==0.12.0

# %%
# !pip install --upgrade Pillow
# Out:
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.10/site-packages (10.1.0)

# %%
import os
import re
import tqdm
import time
import random
import functools
import collections
import numpy as np
from PIL import Image
import multiprocessing
import matplotlib.pyplot as plt
# %matplotlib inline

import spacy

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.nn.utils.rnn import pack_padded_sequence

import torchvision
import torchtext
from torchtext.data import Example, Field, Dataset
from torchtext.data.metrics import bleu_score

# %%
import torchtext as tt
print(tt.__version__)
# Out:
# 0.6.0

# %%
SEED = 781
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = True

DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Device: {DEVICE}')

N_WORKERS = multiprocessing.cpu_count()
print(f'Number of CPUs: {N_WORKERS}')
# Out:
# Device: cpu
# Number of CPUs: 4

# %% [markdown]
# # 2. Download data

# %%
import os

# %%
# !pip install wget
# Out:
# Requirement already satisfied: wget in /opt/conda/lib/python3.10/site-packages (3.2)

# %%
# !rm ./data/*.png

# %%
import os
import wget
from zipfile import ZipFile

# Verifica se o diretório 'data' existe
if not os.path.exists('./data'):
    os.mkdir('./data')

# Lista de URLs e destinos
urls_destinations = [
    ("https://raw.githubusercontent.com/allinegsPY/Gerador-de-legenda/main/Monumentos.zip", "./data/Monumentos.zip"),
    ("https://raw.githubusercontent.com/allinegsPY/Gerador-de-legenda/main/Gerador-de-legenda_text.zip", "./data/Gerador-de-legenda_text.zip")
]

# Baixa e extrai os arquivos
for url, destination in urls_destinations:
    wget.download(url, out=destination)

    # Se o arquivo for um arquivo zip, extrai o conteúdo
    if destination.endswith('.zip'):
        with ZipFile(destination, 'r') as zip_ref:
            zip_ref.extractall('./data')

        # Remove o arquivo zip após a extração
        os.remove(destination)

# %%
# %%time
# if not os.path.exists('./data'):
#     !mkdir ./data

#     !wget --no-check-certificate \
#         https://raw.githubusercontent.com/allinegsPY/Gerador-de-legenda/main/Monumentos.zip \
#         -O ./data/Monumentos.zip
#     !unzip -q ./data/Monumentos.zip -d ./data
#     !rm -r ./data/Monumentos.zip

#     !wget --no-check-certificate \
#         https://raw.githubusercontent.com/allinegsPY/Gerador-de-legenda/main/Gerador-de-legenda_text.zip \
#         -O ./data/Gerador-de-legenda_text.zip
#     !unzip -q ./data/Gerador-de-legenda_text.zip -d ./data
#     !rm -r ./data/Gerador-de-legenda_text.zip

# %%
# %%time
# if not os.path.exists('./data'):
#     !mkdir ./data

#     !wget --no-check-certificate \
#         https://github.com/allinegsPY/Gerador-de-legenda/blob/main/Monumentos.zip \
#         -O ./data/Monumentos.zip
#     !unzip -q ./data/Monumentos.zip -d ./data
#     !rm -r ./data/Monumentos.zip

#     !wget --no-check-certificate \
#         https://github.com/allinegsPY/Gerador-de-legenda/blob/main/Gerador-de-legenda_text.zip \
#         -O ./data/Gerador-de-legenda_text.zip
#     !unzip -q ./data/Gerador-de-legenda_text.zip -d ./data
#     !rm -r ./data/Gerador-de-legenda_text.zip

# %% [markdown]
# # 3. Data Preparation
#
# ## 3.1. Text data

# %%
# !cat ./data/readme.txt
# Out:
# cat: ./data/readme.txt: No such file or directory

# %%
import collections

train_img_fn = [*map(str.strip, open('./data/Gerador-de-legenda.trainImages.txt').readlines())]
valid_img_fn = [*map(str.strip, open('./data/Gerador-de-legenda.devImages.txt').readlines())]
test_img_fn = [*map(str.strip, open('./data/Gerador-de-legenda.testImages.txt').readlines())]

img_captions = collections.defaultdict(lambda: [])
with open('./data/Gerador-de-legenda.token.txt') as file:
    for line in file.readlines():
        # Adicione uma verificação para o comprimento do resultado da divisão
        parts = line.strip().split('\t')
        if len(parts) != 2:
            print(f"{line}")
            continue

        img_fn, caption = parts
        img_captions[img_fn[:-2]].append(caption)

train_img_captions = dict(filter(lambda x: x[0] in train_img_fn, img_captions.items()))
valid_img_captions = dict(filter(lambda x: x[0] in valid_img_fn, img_captions.items()))
test_img_captions = dict(filter(lambda x: x[0] in test_img_fn, img_captions.items()))

print(f'Número de imagens: {len(img_captions):,}')
print(f'Número de imagens de treino: {len(train_img_captions):,}')
print(f'Número de imagens de validação: {len(valid_img_captions):,}')
print(f'Número de imagens de teste: {len(test_img_captions):,}')
# Out:
# Número de imagens: 180
# Número de imagens de treino: 143
# Número de imagens de validação: 19
# Número de imagens de teste: 18

# %%
# train_img_fn = [*map(str.strip, open('/kaggle/input/tcc2-caption-generator/Gerador-de-legenda.trainImages.txt').readlines())]
# valid_img_fn = [*map(str.strip, open('/kaggle/input/tcc2-caption-generator/Gerador-de-legenda.devImages.txt').readlines())]
# test_img_fn = [*map(str.strip, open('/kaggle/input/tcc2-caption-generator/Gerador-de-legenda.testImages.txt').readlines())]

# img_captions = collections.defaultdict(lambda: [])
# with open('/kaggle/input/tcc2-caption-generator/Gerador-de-legenda.token.txt') as file:
#     for line in file.readlines():
#         img_fn, caption = line.strip().split('\t')
#         img_captions[img_fn[:-2]].append(caption)

# train_img_captions = dict(filter(lambda x: x[0] in train_img_fn, img_captions.items()))
# valid_img_captions = dict(filter(lambda x: x[0] in valid_img_fn, img_captions.items()))
# test_img_captions = dict(filter(lambda x: x[0] in test_img_fn, img_captions.items()))

# print(f'Numero de imagens: {len(img_captions):,}')
# print(f'Numero de imagens de treino: {len(train_img_captions):,}')
# print(f'Numero de imagens de validacao: {len(valid_img_captions):,}')
# print(f'Numero de imagens de teste: {len(test_img_captions):,}')

# %%
# Special tokens
PAD_TOKEN = '<pad>'
SOS_TOKEN = '<sos>'
EOS_TOKEN = '<eos>'
UNK_TOKEN = '<unk>'

def clean(caption):
    # Remove non-alphabetical character
    caption = re.sub(r'[^a-zA-Z]', r' ', caption)
    # Remove one word character
    caption = re.sub(r'\b[a-zA-Z]\b', r' ', caption)
    # Remove multiple spaces
    caption = re.sub(r'\s+', r' ', caption)
    return caption.strip()

# %%
# Clean captions
# train_img_captions = dict(map(lambda x: (x[0], [*map(clean, x[1])]), train_img_captions.items()))
# valid_img_captions = dict(map(lambda x: (x[0], [*map(clean, x[1])]), valid_img_captions.items()))
# test_img_captions = dict(map(lambda x: (x[0], [*map(clean, x[1])]), test_img_captions.items()))

# Get the length of the longest caption
all_train_captions = [*functools.reduce(lambda x, y: x + y, train_img_captions.values())]
print('Comprimento máximo da legenda da imagem do treino:', max(map(len, map(str.split, all_train_captions))))
plt.hist([*map(len, map(str.split, all_train_captions))])
plt.grid()
plt.show()
# Out:
# Comprimento máximo da legenda da imagem do treino: 39

# %%
# !python -m spacy download pt_core_news_sm
# Out:
# Collecting pt-core-news-sm==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/pt_core_news_sm-3.7.0/pt_core_news_sm-3.7.0-py3-none-any.whl (13.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 44.7 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in /opt/conda/lib/python3.10/site-packages (from pt-core-news-sm==3.7.0) (3.7.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (8.2.1)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (6.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (4.46.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (1.10.12)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (3.1.2)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (69.0.2)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (21.3)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (1.24.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (3.0.9)
# Requirement already satisfied: typing-extensions>=4.2.0 in /opt/conda/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /opt/conda/lib/python3.10/site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /opt/conda/lib/python3.10/site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (0.1.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /opt/conda/lib/python3.10/site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (2.1.3)
# ✔ Download and installation successful
# You can now load the package via spacy.load('pt_core_news_sm')

# %%
MIN_COUNT = 5
MAX_LEN = 25
all_train_captions = [*functools.reduce(lambda x, y: x + y, train_img_captions.values())]
import spacy
nlp = spacy.load("pt_core_news_sm")
PT = Field(init_token=SOS_TOKEN,
           eos_token=EOS_TOKEN,
           fix_length=MAX_LEN,
           lower=True,
           tokenize=lambda text: [token.text for token in nlp(text)],
           include_lengths=True)
examples = [Example.fromlist(data=[caption], fields=[('legenda', PT)])
            for caption in tqdm.tqdm(all_train_captions)]
captions_data = Dataset(examples, fields={'legenda': PT})
PT.build_vocab(captions_data,
               min_freq=MIN_COUNT,
               specials=[SOS_TOKEN, UNK_TOKEN, EOS_TOKEN, PAD_TOKEN])
print(f'Comprimento do vocabulario: {len(PT.vocab):,}')
# Out:
# 100%|██████████| 715/715 [00:05<00:00, 122.34it/s]
# Comprimento do vocabulario: 261

# %%
def caption_transform(caption):
    if isinstance(caption, str):
        return PT.process([PT.preprocess(caption)])
    elif isinstance(caption, list):
        return PT.process([*map(PT.preprocess, caption)])
    else:
        raise NotImplementedError

# %% [markdown]
# ## 3.2. Image data

# %%
IMG_SHAPE = (256, 256)

img_transform = torchvision.transforms.Compose([
    torchvision.transforms.ToTensor(),
    torchvision.transforms.Lambda(lambda x: x / 255.),
    torchvision.transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                     std=[0.229, 0.224, 0.225])])

# %% [markdown]
# ## 3.3. Build datasets

# %%
class ImageCaptionDataset(torch.utils.data.Dataset):

    def __init__(self, data_path, img_captions, split_set, img_transform, caption_transform, img_shape=(256, 256)):
        assert split_set in {'TREINO', 'VALIDACAO', 'TESTE'}
        self.data_path = data_path
        self.img_captions = img_captions
        self.split_set = split_set
        self.img_transform = img_transform
        self.caption_transform = caption_transform
        self.img_shape = img_shape
        self.ids = list(sorted(self.img_captions.keys()))

    def __getitem__(self, index):
        img_id = self.ids[index]

        img = Image.open(os.path.join(self.data_path, img_id)).convert('RGB')
        img = self.img_transform(img.resize(self.img_shape))

        targets = self.img_captions[img_id]
        targets = self.caption_transform(targets)

        idx = np.random.randint(len(targets))
        target = (targets[0][:, idx], targets[1][idx])

        if self.split_set == 'TREINO':
            return img, target
        else:
            return img, target, targets

    def __len__(self):
        return len(self.ids)

# %%
#TESTE

class ImageCaptionDataset(torch.utils.data.Dataset):

    def __init__(self, data_path, img_captions, split_set, img_transform, caption_transform, img_shape=(256, 256)):
        assert split_set in {'TREINO', 'VALIDACAO', 'TESTE'}
        self.data_path = data_path
        self.img_captions = img_captions
        self.split_set = split_set
        self.img_transform = img_transform
        self.caption_transform = caption_transform
        self.img_shape = img_shape
        self.ids = list(sorted(self.img_captions.keys()))

    def __getitem__(self, index):
        img_id = self.ids[index]

        try:
            img = Image.open(os.path.join(self.data_path, img_id)).convert('RGB')
        except FileNotFoundError:
            print(f"Arquivo não encontrado: {img_id}. Pulando esta amostra.")
            # Retorna algo adequado ou apenas None para indicar a amostra ausente
            return None

        img = self.img_transform(img.resize(self.img_shape))

        targets = self.img_captions[img_id]
        targets = self.caption_transform(targets)

        idx = np.random.randint(len(targets))
        target = (targets[0][:, idx], targets[1][idx])

        if self.split_set == 'TREINO':
            return img, target
        else:
            return img, target, targets

    def __len__(self):
        return len(self.ids)

# %%
# !pip install --upgrade Pillow
# Out:
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.10/site-packages (10.0.1)
# Collecting Pillow
#   Using cached Pillow-10.1.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (9.5 kB)
# Using cached Pillow-10.1.0-cp310-cp310-manylinux_2_28_x86_64.whl (3.6 MB)
# Installing collected packages: Pillow
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 10.0.1
#     Uninstalling Pillow-10.0.1:
#       Successfully uninstalled Pillow-10.0.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# panel 1.3.1 requires tqdm>=4.48.0, but you have tqdm 4.46.1 which is incompatible.
# phik 0.12.3 requires joblib>=0.14.1, but you have joblib 0.13.2 which is incompatible.
# ydata-profiling 4.5.1 requires numpy<1.24,>=1.16.0, but you have numpy 1.24.3 which is incompatible.
# ydata-profiling 4.5.1 requires tqdm<5,>=4.48.2, but you have tqdm 4.46.1 which is incompatible.
# Successfully installed Pillow-10.1.0

# %%
train_dataset = ImageCaptionDataset(data_path='./data/Monumentos/',
                                    img_captions=train_img_captions,
                                    split_set='TREINO',
                                    img_transform=img_transform,
                                    caption_transform=caption_transform)
valid_dataset = ImageCaptionDataset(data_path='./data/Monumentos/',
                                    img_captions=valid_img_captions,
                                    split_set='VALIDACAO',
                                    img_transform=img_transform,
                                    caption_transform=caption_transform)

# %% [markdown]
# # 4. Modeling
#
# ## 4.1. Generate image features - ResNet Encoder

# %%
class ResNetEncoder(nn.Module):

    def __init__(self, hidden_size=2048):
        super(ResNetEncoder, self).__init__()
        resnet = torchvision.models.wide_resnet101_2(pretrained=True)
        modules = list(resnet.children())[:-2]
        self.hidden_size = hidden_size
        self.resnet = nn.Sequential(*modules)

    def fine_tuning_resnet(self, fine_tune):
        for p in self.resnet.parameters():
            p.requires_grad = False
        for c in list(self.resnet.children())[5:]:
            for p in c.parameters():
                p.requires_grad = fine_tune

    def forward(self, images):
        """
        :param
            images: Tensor[batch_size, 3, img_size, img_size]
        :return
            out: Tensor[batch_size, 8, 8, hidden_size]
        """
        out = self.resnet(images)
        out = out.permute(0, 2, 3, 1)
        return out

# %%
def test_encoder():
    encoder = ResNetEncoder()
    latent = encoder(torch.rand((10, 3, 256, 256)))
    assert latent.size() == torch.Size([10, 8, 8, 2048]), latent.size()

test_encoder()

# %% [markdown]
# ## 4.2. Badhanau Attention

# %%
class BahdanauAttention(nn.Module):

    def __init__(self, enc_hidden_size, dec_hidden_size, hidden_size):
        super(BahdanauAttention, self).__init__()
        self.W1 = nn.Linear(enc_hidden_size, hidden_size)
        self.W2 = nn.Linear(dec_hidden_size, hidden_size)
        self.V = nn.Linear(hidden_size, 1)

    def forward(self, features, h_state):
        """
        :param
            features:  Tensor[batch_size, num_pixels, enc_hidden_size]
            h_state: Tensor[batch_size, dec_hidden_size]
        :return
            context_vector: Tensor[batch_size, enc_hidden_size]
            attention_weights: Tensor[batch_size, num_pixels]
        """
        h_state = h_state.unsqueeze(1) # [batch_size, 1, dec_hidden_size]
        score = F.elu(self.W1(features) + self.W2(h_state)) # [batch_size, num_pixels, hidden_size]
        attention_weights = F.softmax(self.V(score), dim=1) # [batch_size, num_pixels, 1]
        context_vector = attention_weights * features # [batch_size, num_pixels, enc_hidden_size]
        context_vector = torch.sum(context_vector, dim=1) # [batch_size, enc_hidden_size]
        return context_vector, attention_weights.squeeze(2)

# %%
def test_attention():
    attention = BahdanauAttention(enc_hidden_size=2048, dec_hidden_size=512, hidden_size=512)
    context_vector, attention_weights = attention(torch.rand((10, 8*8, 2048)), torch.rand((10, 512)))
    assert context_vector.size() == torch.Size([10, 2048])
    assert attention_weights.size() == torch.Size([10, 8*8])

test_attention()

# %% [markdown]
# ## 4.3. Generate captions - LSTM Decoder

# %%
class DecoderWithBahdanauAttention(nn.Module):

    def __init__(self, enc_hidden_size, attn_hidden_size, hidden_size, embedding_size, vocab_size, dropout):
        super(DecoderWithBahdanauAttention, self).__init__()
        self.hidden_size = hidden_size
        self.vocab_size = vocab_size
        self.dropout = dropout
        self.embedding = nn.Embedding(vocab_size, embedding_size)
        self.dropout = nn.Dropout(p=dropout)
        self.lstm = nn.LSTM(embedding_size + enc_hidden_size, hidden_size)
        self.attention = BahdanauAttention(enc_hidden_size, hidden_size, attn_hidden_size)
        self.f_beta = nn.Linear(hidden_size, enc_hidden_size)
        self.fc = nn.Linear(hidden_size, vocab_size)

    def load_pretrained_embeddings(self, embeddings):
        self.embedding.weight = nn.Parameter(embeddings)

    def fine_tuning_embeddings(self, fine_tune=False):
        for p in self.embedding.parameters():
            p.requires_grad = fine_tune

    def forward(self, input_word_index, h_state, c_state, enc_outputs):
        """
        :param
            input_word_index: Tensor[batch_size,]
            h_state: Tensor[1, batch_size, hidden_size]
            c_state: Tensor[1, batch_size, hidden_size]
            enc_outputs: Tensor[batch_size, num_pixels, enc_hidden_size]
        :return
            logit: Tensor[batch_size, vocab_size]
            h_state: Tensor[1, batch_size, hidden_size]
            c_state: Tensor[1, batch_size, hidden_size]
            attention_weights: Tensor[batch_size, num_pixels]
        """
        embedded = self.embedding(input_word_index)  # [batch_size, embedding_size]
        context_vector, attention_weights = self.attention(enc_outputs, h_state.squeeze(0))
        # context_vector: Tensor[batch_size, enc_hidden_size]
        # attention_weights: Tensor[batch_size, num_pixels]

        gate = torch.sigmoid(self.f_beta(h_state))  # [1, batch_size, enc_hidden_size], Gating scalar
        context_vector = gate.squeeze(0) * context_vector # [batch_size, enc_hidden_size]

        x = torch.cat((embedded, context_vector), dim=1) # [batch_size, embedding_size + enc_hidden_size]
        output, (h_state, c_state) = self.lstm(x.unsqueeze(0), (h_state, c_state))
        # output: [1, batch_size, hidden_size]
        # h_state: [1, batch_size, hidden_size]
        # c_state: [1, batch_size, hidden_size]

        logit = self.fc(self.dropout(output)) # [1, batch_size, vocab_size]
        logit = logit.squeeze(0) # [batch_size, vocab_size]
        return logit, h_state, c_state, attention_weights

# %%
def test_decoder():
    decoder = DecoderWithBahdanauAttention(enc_hidden_size=2048,
                                           attn_hidden_size=512,
                                           hidden_size=512,
                                           embedding_size=512,
                                           vocab_size=1000,
                                           dropout=0.5)
    logit, h_state, c_state, attention_weights = decoder(torch.randint(low=0, high=1000, size=(10,)),
                                                         torch.rand((1, 10, 512)),
                                                         torch.rand((1, 10, 512)),
                                                         torch.rand((10, 14*14, 2048)))
    assert logit.size() == torch.Size([10, 1000])
    assert h_state.size() == torch.Size([1, 10, 512])
    assert c_state.size() == torch.Size([1, 10, 512])
    assert attention_weights.size() == torch.Size([10, 14*14])

test_decoder()

# %% [markdown]
# ## 4.4. Putting all together - AutoEncoder

# %%
class AutoEncoder(nn.Module):

    def __init__(self, encoder, decoder, device):
        super(AutoEncoder, self).__init__()
        self.encoder = encoder
        self.decoder = decoder
        self.init_h0 = nn.Linear(encoder.hidden_size, decoder.hidden_size)
        self.init_c0 = nn.Linear(encoder.hidden_size, decoder.hidden_size)
        self.device = device

    def forward(self, images, target_sequences, sequence_lengths, tf_ratio):
        """
        :param
            images: Tensor[batch_size, 3, img_size, img_size]
            target_sequences: Tensor[batch_size, seq_len]
            sequence_lengths: Tensor[batch_size,]
            tf_ratio: float
        :return
            logits: Tensor[max(decode_lengths), batch_size, vocab_size]
            logits: Tensor[batch_size, max(decode_lengths), num_pixels]
            sorted_target_sequences: Tensor[seq_len, batch_size]
            sorted_decode_lengths: list[seq_len]
            sorted_indices: list[batch_size]
        """
        batch_size = images.size(0)

        # Encoding
        image_features = self.encoder(images) # [batch_size, 14, 14, hidden_size]
        image_features = image_features.view(batch_size, -1, self.encoder.hidden_size) # [batch_size, num_pixels, enc_hidden_size]
        num_pixels = image_features.size(1)

        # Sort the batch by decreasing lengths
        sorted_sequence_lengths, sorted_indices = torch.sort(sequence_lengths, dim=0, descending=True)
        sorted_image_features = image_features[sorted_indices] # [batch_size, num_pixels, enc_hidden_size]
        sorted_target_sequences = target_sequences[sorted_indices] # [seq_len, batch_size]

        # Init hidden and memory states
        mean_image_features = sorted_image_features.mean(dim=1) # [batch_size, enc_hidden_size]
        h_state, c_state = self.init_h0(mean_image_features), self.init_c0(mean_image_features) # [batch_size, dec_hidden_size]
        h_state, c_state = h_state.unsqueeze(0), c_state.unsqueeze(0) # [1, batch_size, dec_hidden_size]

        # We won't decode at the <eos> position, since we've finished generating as soon as we generate <eos>
        # So, decoding lengths are actual lengths - 1
        sorted_decode_lengths = (sorted_sequence_lengths - 1).tolist()

        # Decoding
        logits = torch.zeros(max(sorted_decode_lengths), batch_size, self.decoder.vocab_size).to(self.device)
        alphas = torch.zeros(batch_size, max(sorted_decode_lengths), num_pixels).to(self.device)
        last = None
        for t in range(max(sorted_decode_lengths)):
            batch_size_t = sum([l > t for l in sorted_decode_lengths])

            if last is not None:
                if random.random() < tf_ratio:
                    in_ = last[:batch_size_t]
                else:
                    in_ = sorted_target_sequences[:batch_size_t, t]
            else:
                in_ = sorted_target_sequences[:batch_size_t, t]

            logit, h_state, c_state, attention_weights = self.decoder(in_,
                                                                      h_state[:, :batch_size_t, :],
                                                                      c_state[:, :batch_size_t, :],
                                                                      sorted_image_features[:batch_size_t, :, :])
            logits[t, :batch_size_t, :] = logit
            alphas[:batch_size_t, t, :] = attention_weights
            last = torch.argmax(F.softmax(logit, dim=1), dim=1) # [batch_size,]

        return logits, alphas, sorted_target_sequences, sorted_decode_lengths, sorted_indices

# %%
def test_autoencoder():
    encoder = ResNetEncoder()
    decoder = DecoderWithBahdanauAttention(enc_hidden_size=2048,
                                           attn_hidden_size=512,
                                           hidden_size=512,
                                           embedding_size=512,
                                           vocab_size=1000,
                                           dropout=0.5)
    autoencoder = AutoEncoder(encoder=encoder, decoder=decoder, device='cpu')
    logits, alphas, sorted_target_sequences, sorted_decode_lengths, sorted_indices = \
        autoencoder(torch.rand((10, 3, 256, 256)),
                    torch.randint(low=0, high=1000, size=(10, 25)),
                    torch.randint(low=5, high=26, size=(10,)), 0.5)
    assert logits.size() == torch.Size([max(sorted_decode_lengths), 10, 1000])
    assert alphas.size() == torch.Size([10, max(sorted_decode_lengths), 8*8])
    assert len(sorted_decode_lengths) == 10
    assert sorted_target_sequences.size() == torch.Size([10, 25])
    assert len(sorted_indices) == 10

test_autoencoder()

# %% [markdown]
# # 5. Training
#
# ## 5.1. Training routines

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

def init_embeddings(embeddings):
    bias = np.sqrt(3.0 / embeddings.size(1))
    torch.nn.init.uniform_(embeddings, -bias, bias)

def load_embeddings(nlp, field):
    embeddings = torch.FloatTensor(len(field.vocab), 300)
    init_embeddings(embeddings)
    for token, index in tqdm.tqdm(field.vocab.stoi.items()):
        token = nlp(token)
        if token.has_vector:
            embeddings[index] = torch.tensor(token.vector, dtype=torch.float32)
    return embeddings

def clip_gradient(optimizer, grad_clip):
    for group in optimizer.param_groups:
        for param in group['params']:
            if param.grad is not None:
                param.grad.data.clamp_(-grad_clip, grad_clip)

def save_checkpoint(model, optimizer, data_name, epoch, last_improv, bleu4, is_best):
    state = {
        'epoch': epoch,
        'bleu-4': bleu4,
        'last_improv': last_improv,
        'model': model.state_dict(),
        'optimizer': optimizer.state_dict()
    }
    if not os.path.exists('./checkpoint'):
        # !mkdir ./checkpoint
    torch.save(state, './checkpoint/' + data_name + '.pt')
    if is_best:
        torch.save(state, './checkpoint/' + 'BEST_' + data_name + '.pt')


class AvgMeter(object):

    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

def adjust_lr(optimizer, shrink_factor):
    print("\nTaxa de aprendizagem decrescente.")
    for param_group in optimizer.param_groups:
        param_group['lr'] = param_group['lr'] * shrink_factor
    print("A nova taxa de aprendizagem e %f\n" % (optimizer.param_groups[0]['lr'],))

def accuracy(outputs, target_sequences, k=5):
    batch_size = outputs.size(1)
    _, indices = outputs.topk(k, dim=1, largest=True, sorted=True)
    correct = indices.eq(target_sequences.view(-1, 1).expand_as(indices))
    correct_total = correct.view(-1).float().sum()  # 0D tensor
    return correct_total.item() * (100.0 / batch_size)

# %%
from torchtext.data import Field
from torchtext.data import Example
from torchtext.data import Dataset
from PIL import Image
from torch.nn.utils.rnn import pack_padded_sequence
from torchtext.data.metrics import bleu_score

def train_step(model, optimizer, criterion, loader, epoch, grad_clip, alpha_c, tf_ratio, device):
    loss_tracker, acc_tracker = AvgMeter(), AvgMeter()
    model.train()
    pbar = tqdm.tqdm(enumerate(loader), total=len(loader))
    for i, (images, (target_sequences, sequence_lengths)) in pbar:
        images = images.to(device)
        target_sequences = target_sequences.to(device)
        sequence_lengths = sequence_lengths.to(device)
        # Forward prop.
        logits, alphas, sorted_target_sequences, sorted_decode_lengths, sorted_indices = model(images, target_sequences, sequence_lengths, tf_ratio)
        # Since we decoded starting with <sos>, the targets are all words after <sos>, up to <eos>
        sorted_target_sequences = sorted_target_sequences[:, 1:]
        # Remove paddings
        logits = pack_padded_sequence(logits, sorted_decode_lengths).data
        sorted_target_sequences = pack_padded_sequence(sorted_target_sequences, sorted_decode_lengths, batch_first=True).data
        # Calculate loss
        loss = criterion(logits, sorted_target_sequences)
        # Add doubly stochastic attention regularization
        loss += alpha_c * ((1. - alphas.sum(dim=1)) ** 2).mean()
        # Back prop.
        optimizer.zero_grad()
        loss.backward()
        # Clip gradients
        if grad_clip is not None:
            clip_gradient(optimizer, grad_clip)
        # Update weights
        optimizer.step()
        # Track metrics
        loss_tracker.update(loss.item(), sum(sorted_decode_lengths))
        acc_tracker.update(accuracy(logits, sorted_target_sequences, 5), sum(sorted_decode_lengths))
        # Update progressbar description
        pbar.set_description(f'Epoch: {epoch + 1:03d} - loss: {loss_tracker.avg:.3f} - acc: {acc_tracker.avg:.3f}%')
    return loss_tracker.avg, acc_tracker.avg

# %%
from torchtext.data import Field
from torchtext.data import Example
from torchtext.data import Dataset
from PIL import Image
from torch.nn.utils.rnn import pack_padded_sequence
from torchtext.data.metrics import bleu_score

def validate(model, criterion, loader, field, epoch, alpha_c, device):
    references, hypotheses = [], []
    loss_tracker, acc_tracker = AvgMeter(), AvgMeter()
    model.eval()
    with torch.no_grad():
        pbar = tqdm.tqdm(enumerate(loader), total=len(loader))
        for i, (images, (target_sequences, sequence_lengths), (all_target_sequences, all_sequence_lengths)) in pbar:
            images = images.to(device)
            target_sequences = target_sequences.to(device)
            sequence_lengths = sequence_lengths.to(device)
            all_target_sequences = all_target_sequences.to(device)
            all_sequence_lengths = all_sequence_lengths.to(device)
            # Forward prop.
            logits, alphas, sorted_target_sequences, sorted_decode_lengths, sorted_indices = model(images, target_sequences, sequence_lengths, 0)
            # Since we decoded starting with <sos>, the targets are all words after <sos>, up to <eos>
            sorted_target_sequences = sorted_target_sequences[:, 1:]
            # Remove paddings
            logits_copy = logits.clone()
            logits = pack_padded_sequence(logits, sorted_decode_lengths).data
            sorted_target_sequences = pack_padded_sequence(sorted_target_sequences, sorted_decode_lengths, batch_first=True).data
            # Calculate loss
            loss = criterion(logits, sorted_target_sequences)
            # Add doubly stochastic attention regularization
            loss += alpha_c * ((1. - alphas.sum(dim=1)) ** 2).mean()
            # Track metrics
            loss_tracker.update(loss.item(), sum(sorted_decode_lengths))
            acc_tracker.update(accuracy(logits, sorted_target_sequences, 5), sum(sorted_decode_lengths))
            # Update references
            all_sorted_target_sequences = all_target_sequences[sorted_indices] # Because images were sorted in the decoder
            for j in range(all_sorted_target_sequences.size(0)):
                img_caps = all_sorted_target_sequences[j].t().tolist()
                # Remove <sos> and <pad> tokens
                img_caps = [*map(lambda c: [field.vocab.itos[w] for w in c
                                            if w not in (field.vocab.stoi[field.init_token],
                                                         field.vocab.stoi[field.pad_token])], img_caps)]
                references.append(img_caps)
            # Update hypotheses
            _, preds = torch.max(logits_copy, dim=2)
            preds, temp_preds = preds.t().tolist(), []
            for j, p in enumerate(preds):
                temp_preds.append([*map(lambda w: field.vocab.itos[w], preds[j][:sorted_decode_lengths[j]])]) # Remove padding
            hypotheses.extend(temp_preds)
            # Update progressbar description
            pbar.set_description(f'Epoch: {epoch + 1:03d} - val_loss: {loss_tracker.avg:.3f} - val_acc: {acc_tracker.avg:.3f}%')
        # Calculate BLEU-4 score
        bleu4 = bleu_score(hypotheses, references, max_n=4, weights=[0.25, 0.25, 0.25, 0.25])
    return loss_tracker.avg, acc_tracker.avg, bleu4

# %%
def train(model, optimizer, criterion, train_loader, valid_loader, field, alpha_c, start_epoch, n_epochs, grad_clip, tf_ratio, device, model_name, last_improv):
    history, best_bleu = {
        'acc': [],
        'loss': [],
        'val_acc': [],
        'val_loss': [],
        'bleu4': []
    }, 0.
    for epoch in range(start_epoch, n_epochs):
        # Stop training if no improvment since last 4 epochs
        if last_improv == 4:
            print('Training Finished - The model has stopped improving since last 4 epochs')
            break
        # Decay LR if no improvment
        if last_improv > 0:
            adjust_lr(optimizer, 0.8)
        # Train step
        loss, acc = train_step(model=model, optimizer=optimizer, criterion=criterion,
                               loader=train_loader, epoch=epoch, grad_clip=grad_clip,
                               alpha_c=alpha_c, tf_ratio=tf_ratio, device=device)
        # Validation step
        val_loss, val_acc, bleu4 = validate(model=model, criterion=criterion, loader=valid_loader,
                                            field=field, epoch=epoch, alpha_c=alpha_c, device=device)
        # Update history dict
        history['acc'].append(acc)
        history['loss'].append(loss)
        history['val_acc'].append(val_acc)
        history['val_loss'].append(val_loss)
        history['bleu4'].append(bleu4)
        # Print BLEU score
        text = f'BLEU-4: {bleu4*100:.3f}%'
        if best_bleu > bleu4:
            last_improv += 1
            text += f' - Last improvement since {last_improv} epoch(s)'
        else:
            best_bleu, last_improv = bleu4, 0
        print(text)
        # Save checkpoint
        save_checkpoint(model=model, optimizer=optimizer, data_name=model_name, epoch=epoch, last_improv=last_improv, bleu4=bleu4, is_best=bleu4 >= best_bleu)
    return history

# %% [markdown]
# ## 5.2. Training models

# %%
MODEL_NAME = 'Monumentos'
ENCODER_HIDDEN_SIZE = 2048
ATTENTION_SIZE = 512
DECODER_HIDDEN_SIZE = 512
EMBEDDING_SIZE = 300
DROPOUT = 0.15

# %%
n_epochs = 15
batch_size = 32
lr = 3e-5
grad_clip = 5.
alpha_c = 1.
tf_ratio = 0.

# %%
# !pip install spacy
# !python -m spacy download pt_core_news_lg
# Out:
# Requirement already satisfied: spacy in /opt/conda/lib/python3.10/site-packages (3.7.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /opt/conda/lib/python3.10/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/conda/lib/python3.10/site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/conda/lib/python3.10/site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in /opt/conda/lib/python3.10/site-packages (from spacy) (8.2.1)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /opt/conda/lib/python3.10/site-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /opt/conda/lib/python3.10/site-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /opt/conda/lib/python3.10/site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /opt/conda/lib/python3.10/site-packages (from spacy) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from spacy) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /opt/conda/lib/python3.10/site-packages (from spacy) (6.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/conda/lib/python3.10/site-packages (from spacy) (4.46.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /opt/conda/lib/python3.10/site-packages (from spacy) (1.10.12)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from spacy) (3.1.2)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from spacy) (69.0.2)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from spacy) (21.3)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /opt/conda/lib/python3.10/site-packages (from spacy) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /opt/conda/lib/python3.10/site-packages (from spacy) (1.24.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->spacy) (3.0.9)
# Requirement already satisfied: typing-extensions>=4.2.0 in /opt/conda/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /opt/conda/lib/python3.10/site-packages (from thinc<8.3.0,>=8.1.8->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /opt/conda/lib/python3.10/site-packages (from thinc<8.3.0,>=8.1.8->spacy) (0.1.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /opt/conda/lib/python3.10/site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from weasel<0.4.0,>=0.1.0->spacy) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->spacy) (2.1.3)
# Collecting pt-core-news-lg==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/pt_core_news_lg-3.7.0/pt_core_news_lg-3.7.0-py3-none-any.whl (568.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 568.2/568.2 MB 2.3 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in /opt/conda/lib/python3.10/site-packages (from pt-core-news-lg==3.7.0) (3.7.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (8.2.1)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (6.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (4.46.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (1.10.12)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (3.1.2)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (69.0.2)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (21.3)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (1.24.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (3.0.9)
# Requirement already satisfied: typing-extensions>=4.2.0 in /opt/conda/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /opt/conda/lib/python3.10/site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /opt/conda/lib/python3.10/site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (0.1.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /opt/conda/lib/python3.10/site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.1.3)
# ✔ Download and installation successful
# You can now load the package via spacy.load('pt_core_news_lg')

# %%
spacy_nlp = spacy.load('pt_core_news_lg')
embeddings = load_embeddings(nlp=spacy_nlp, field=PT)
# Out:
# 100%|██████████| 261/261 [00:01<00:00, 139.31it/s]

# %%
encoder = ResNetEncoder()
encoder.fine_tuning_resnet(fine_tune=True)
decoder = DecoderWithBahdanauAttention(enc_hidden_size=ENCODER_HIDDEN_SIZE,
                                       attn_hidden_size=ATTENTION_SIZE,
                                       hidden_size=DECODER_HIDDEN_SIZE,
                                       embedding_size=EMBEDDING_SIZE,
                                       vocab_size=len(PT.vocab),
                                       dropout=DROPOUT)
decoder.load_pretrained_embeddings(embeddings)
decoder.fine_tuning_embeddings(fine_tune=True)
autoencoder = AutoEncoder(encoder=encoder, decoder=decoder, device=DEVICE).to(DEVICE)
optimizer = optim.RMSprop(params=autoencoder.parameters(), lr=lr)
criterion = nn.CrossEntropyLoss()
print(f'Number of parameters of the model: {count_parameters(autoencoder):,}')
# Out:
# Number of parameters of the model: 134,728,418

# %%
# Define data loaders
train_loader = torch.utils.data.DataLoader(train_dataset,
                                           num_workers=N_WORKERS,
                                           batch_size=batch_size,
                                           shuffle=True,
                                           pin_memory=True)
valid_loader = torch.utils.data.DataLoader(valid_dataset,
                                           num_workers=N_WORKERS,
                                           batch_size=batch_size,
                                           shuffle=True,
                                           pin_memory=True)

# %%
train_dataset = ImageCaptionDataset(data_path='./data/Monumentos/',
                                    img_captions=train_img_captions,
                                    split_set='TREINO',
                                    img_transform=img_transform,
                                    caption_transform=caption_transform)
valid_dataset = ImageCaptionDataset(data_path='./data/Monumentos/',
                                    img_captions=valid_img_captions,
                                    split_set='VALIDACAO',
                                    img_transform=img_transform,
                                    caption_transform=caption_transform)

# %%
# !pip install --upgrade Pillow
# Out:
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.10/site-packages (10.1.0)

# %%
# !pip uninstall Pillow --yes
# Out:
# Found existing installation: Pillow 10.1.0
# Uninstalling Pillow-10.1.0:
#   Successfully uninstalled Pillow-10.1.0

# %%
# !pip install PIL
# Out:
# ERROR: Could not find a version that satisfies the requirement PIL (from versions: none)
# ERROR: No matching distribution found for PIL

# %%
# !pip install Pillow==10.0.1
# Out:
# Collecting Pillow==10.0.1
#   Using cached Pillow-10.0.1-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (9.5 kB)
# Using cached Pillow-10.0.1-cp310-cp310-manylinux_2_28_x86_64.whl (3.6 MB)
# Installing collected packages: Pillow
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# panel 1.3.1 requires tqdm>=4.48.0, but you have tqdm 4.46.1 which is incompatible.
# phik 0.12.3 requires joblib>=0.14.1, but you have joblib 0.13.2 which is incompatible.
# ydata-profiling 4.5.1 requires numpy<1.24,>=1.16.0, but you have numpy 1.24.3 which is incompatible.
# ydata-profiling 4.5.1 requires tqdm<5,>=4.48.2, but you have tqdm 4.46.1 which is incompatible.
# Successfully installed Pillow-10.0.1

# %%
# import shutil
# deletar = '/kaggle/working/data/Monumentos_256'
# shutil.rmtree(deletar)

# %%
from PIL import Image

history = train(model=autoencoder,
                optimizer=optimizer,
                criterion=criterion,
                train_loader=train_loader,
                valid_loader=valid_loader,
                field=PT,
                alpha_c=alpha_c,
                start_epoch=0,
                n_epochs=n_epochs,
                grad_clip=grad_clip,
                tf_ratio=tf_ratio,
                device=DEVICE,
                model_name=MODEL_NAME,
                last_improv=0)
# Out:
# Epoch: 001 - loss: 5.937 - acc: 42.421%: 100%|██████████| 5/5 [03:59<00:00, 47.80s/it]
# Epoch: 001 - val_loss: 5.568 - val_acc: 44.444%: 100%|██████████| 1/1 [00:11<00:00, 11.93s/it]
# BLEU-4: 15.746%
# Epoch: 002 - loss: 5.550 - acc: 64.688%: 100%|██████████| 5/5 [03:59<00:00, 47.89s/it]
# Epoch: 002 - val_loss: 4.892 - val_acc: 48.276%: 100%|██████████| 1/1 [00:11<00:00, 11.50s/it]
# BLEU-4: 9.703% - Last improvement since 1 epoch(s)
#
# Taxa de aprendizagem decrescente.
# A nova taxa de aprendizagem e 0.000024
# Epoch: 003 - loss: 4.873 - acc: 65.703%: 100%|██████████| 5/5 [03:55<00:00, 47.13s/it]
# Epoch: 003 - val_loss: 4.801 - val_acc: 45.211%: 100%|██████████| 1/1 [00:11<00:00, 11.33s/it]
# BLEU-4: 15.739% - Last improvement since 2 epoch(s)
#
# Taxa de aprendizagem decrescente.
# A nova taxa de aprendizagem e 0.000019
# Epoch: 004 - loss: 4.675 - acc: 68.910%: 100%|██████████| 5/5 [04:03<00:00, 48.75s/it]
# Epoch: 004 - val_loss: 4.634 - val_acc: 50.575%: 100%|██████████| 1/1 [00:11<00:00, 11.38s/it]
# BLEU-4: 16.083%
# Epoch: 005 - loss: 4.574 - acc: 70.841%: 100%|██████████| 5/5 [03:58<00:00, 47.62s/it]
# Epoch: 005 - val_loss: 4.559 - val_acc: 50.575%: 100%|██████████| 1/1 [00:11<00:00, 11.37s/it]
# BLEU-4: 17.206%
# Epoch: 006 - loss: 4.522 - acc: 72.365%: 100%|██████████| 5/5 [03:58<00:00, 47.79s/it]
# Epoch: 006 - val_loss: 4.457 - val_acc: 51.341%: 100%|██████████| 1/1 [00:16<00:00, 16.41s/it]
# BLEU-4: 19.140%
# Epoch: 007 - loss: 4.422 - acc: 76.090%: 100%|██████████| 5/5 [04:00<00:00, 48.09s/it]
# Epoch: 007 - val_loss: 4.556 - val_acc: 45.977%: 100%|██████████| 1/1 [00:11<00:00, 11.90s/it]
# BLEU-4: 21.885%
# Epoch: 008 - loss: 4.383 - acc: 77.311%: 100%|██████████| 5/5 [04:02<00:00, 48.51s/it]
# Epoch: 008 - val_loss: 4.505 - val_acc: 47.126%: 100%|██████████| 1/1 [00:11<00:00, 11.52s/it]
# BLEU-4: 20.077% - Last improvement since 1 epoch(s)
#
# Taxa de aprendizagem decrescente.
# A nova taxa de aprendizagem e 0.000015
# Epoch: 009 - loss: 4.370 - acc: 77.464%: 100%|██████████| 5/5 [03:56<00:00, 47.20s/it]
# Epoch: 009 - val_loss: 4.322 - val_acc: 47.893%: 100%|██████████| 1/1 [00:19<00:00, 19.48s/it]
# BLEU-4: 19.904% - Last improvement since 2 epoch(s)
#
# Taxa de aprendizagem decrescente.
# A nova taxa de aprendizagem e 0.000012
# Epoch: 010 - loss: 4.335 - acc: 75.258%: 100%|██████████| 5/5 [04:01<00:00, 48.27s/it]
# Epoch: 010 - val_loss: 4.245 - val_acc: 54.023%: 100%|██████████| 1/1 [00:11<00:00, 11.49s/it]
# BLEU-4: 20.349% - Last improvement since 3 epoch(s)
#
# Taxa de aprendizagem decrescente.
# A nova taxa de aprendizagem e 0.000010
# Epoch: 011 - loss: 4.289 - acc: 78.884%: 100%|██████████| 5/5 [03:55<00:00, 47.13s/it]
# Epoch: 011 - val_loss: 4.271 - val_acc: 49.042%: 100%|██████████| 1/1 [00:11<00:00, 11.19s/it]
# BLEU-4: 23.196%
# Epoch: 012 - loss: 4.305 - acc: 76.911%: 100%|██████████| 5/5 [03:57<00:00, 47.44s/it]
# Epoch: 012 - val_loss: 4.388 - val_acc: 43.678%: 100%|██████████| 1/1 [00:20<00:00, 20.45s/it]
# BLEU-4: 22.446% - Last improvement since 1 epoch(s)
#
# Taxa de aprendizagem decrescente.
# A nova taxa de aprendizagem e 0.000008
# Epoch: 013 - loss: 4.247 - acc: 77.907%: 100%|██████████| 5/5 [04:07<00:00, 49.51s/it]
# Epoch: 013 - val_loss: 4.349 - val_acc: 42.912%: 100%|██████████| 1/1 [00:12<00:00, 12.10s/it]
# BLEU-4: 24.152%
# Epoch: 014 - loss: 4.254 - acc: 78.576%: 100%|██████████| 5/5 [03:56<00:00, 47.26s/it]
# Epoch: 014 - val_loss: 4.182 - val_acc: 47.126%: 100%|██████████| 1/1 [00:11<00:00, 11.93s/it]
# BLEU-4: 20.670% - Last improvement since 1 epoch(s)
#
# Taxa de aprendizagem decrescente.
# A nova taxa de aprendizagem e 0.000006
# Epoch: 015 - loss: 4.220 - acc: 81.189%: 100%|██████████| 5/5 [03:56<00:00, 47.35s/it]
# Epoch: 015 - val_loss: 4.206 - val_acc: 50.575%: 100%|██████████| 1/1 [00:23<00:00, 23.00s/it]
# BLEU-4: 22.406% - Last improvement since 2 epoch(s)

# %%
# from PIL import Image
# import os

# diretorio_imagens = './data/Monumentos/'

# def verificar_imagens_corrompidas(diretorio):
#     imagens_corrompidas = []

#     for arquivo in os.listdir(diretorio):
#         caminho_arquivo = os.path.join(diretorio, arquivo)

#         try:
#             # Tenta abrir a imagem
#             Image.open(caminho_arquivo).verify()
#         except (IOError, SyntaxError, Image.DecompressionBombError, Image.UnidentifiedImageError):
#             # Captura exceções que indicam uma imagem corrompida
#             imagens_corrompidas.append(caminho_arquivo)

#     return imagens_corrompidas

# # Chamada da função para verificar imagens corrompidas
# imagens_corrompidas = verificar_imagens_corrompidas(diretorio_imagens)

# # Exibindo imagens corrompidas
# if imagens_corrompidas:
#     print("Imagens corrompidas encontradas:")
#     for img in imagens_corrompidas:
#         print(img)
# else:
#     print("Nenhuma imagem corrompida encontrada.")
# Out:
# Nenhuma imagem corrompida encontrada.

# %%
# import os
# from PIL import Image

# folder_path = './data/Monumentos/'
# extensions = []

# for fldr in os.listdir(folder_path):
#     sub_folder_path = os.path.join(folder_path, fldr)
    
#     # Verifica se o item é um diretório antes de tentar listar seu conteúdo
#     if os.path.isdir(sub_folder_path):
#         print(f'Processing folder: {sub_folder_path}')
        
#         for filee in os.listdir(sub_folder_path):
#             file_path = os.path.join(sub_folder_path, filee)
#             print('** Caminho: {}  **'.format(file_path), end="\r", flush=True)
            
#             try:
#                 im = Image.open(file_path)
#                 rgb_im = im.convert('RGB')
                
#                 # Use os.path.splitext para obter a extensão do arquivo
#                 _, file_extension = os.path.splitext(filee)
                
#                 if file_extension[1:] not in extensions:
#                     extensions.append(file_extension[1:])
#             except Exception as e:
#                 print(f'Error processing image {file_path}: {e}')

# if extensions:
#     print("Extensions found:", extensions)
# else:
#     print("No valid image files found.")
# Out:
# No valid image files found.

# %%
# import os
# from PIL import Image

# folder_path = './data/Monumentos/'
# extensions = []

# for fldr in os.listdir(folder_path):
#     sub_folder_path = os.path.join(folder_path, fldr)
    
#     # Verifica se o item é um diretório antes de tentar listar seu conteúdo
#     if os.path.isdir(sub_folder_path):
#         print(f'Processing folder: {sub_folder_path}')
        
#         for filee in os.listdir(sub_folder_path):
#             file_path = os.path.join(sub_folder_path, filee)
#             print('** Caminho: {}  **'.format(file_path), end="\r", flush=True)
            
#             try:
#                 im = Image.open(file_path)
#                 rgb_im = im.convert('RGB')
                
#                 # Use os.path.splitext para obter a extensão do arquivo
#                 _, file_extension = os.path.splitext(filee)
                
#                 if file_extension[1:] not in extensions:
#                     extensions.append(file_extension[1:])
#             except Exception as e:
#                 print(f'Error processing image {file_path}: {e}')

# print("Extensions found:", extensions)

# %%
# from PIL import Image

# im = Image.open('./data/Monumentos/90.png')

# im.show()

# %%
# import os

# caminho_img = './data/Monumentos/180.png'
# if os.path.exists(caminho_img):
#     print(f'O arquivo {caminho_img} existe.')
# else:
#     print(f'O arquivo {caminho_img} não foi encontrado.')
# Out:
# O arquivo ./data/Monumentos/180.png existe.

# %%
# diretorio = './data/Monumentos'
# conteudo_diretorio = os.listdir(diretorio)
# print(f'Conteúdo do diretório {diretorio}: {conteudo_diretorio}')
# Out:
# Conteúdo do diretório ./data/Monumentos: ['135.png', '127.png', '66.png', '102.png', '96.png', '93.png', '158.png', '44.png', '24.png', '130.png', '133.png', '27.png', '59.png', '169.png', '116.png', '16.png', '54.png', '157.png', '94.png', '26.png', '136.png', '30.png', '07.png', '150.png', '108.png', '92.png', '104.png', '99.png', '19.png', '43.png', '131.png', '14.png', '151.png', '74.png', '57.png', '88.png', '128.png', '95.png', '53.png', '146.png', '156.png', '100.png', '107.png', '41.png', '51.png', '46.png', '112.png', '167.png', '52.png', '110.png', '55.png', '39.png', '31.png', '63.png', '161.png', '83.png', '120.png', '168.png', '106.png', '145.png', '35.png', '89.png', '105.png', '159.png', '28.png', '142.png', '97.png', '79.png', '137.png', '153.png', '86.png', '170.png', '115.png', '113.png', '18.png', '147.png', '33.png', '32.png', '06.png', '82.png', '62.png', '119.png', '176.png', '91.png', '38.png', '71.png', '164.png', '90.png', '144.png', '118.png', '56.png', '12.png', '08.png', '04.png', '22.png', '67.png', '69.png', '125.png', '03.png', '58.png', '64.png', '42.png', '141.png', '21.png', '78.png', '80.png', '123.png', '174.png', '50.png', '134.png', '75.png', '49.png', '114.png', '85.png', '01.png', '20.png', '10.png', '124.png', '81.png', '84.png', '162.png', '166.png', '36.png', '29.png', '126.png', '163.png', '05.png', '48.png', '173.png', '87.png', '61.png', '143.png', '02.png', '172.png', '45.png', '68.png', '180.png', '47.png', '60.png', '179.png', '165.png', '65.png', '177.png', '09.png', '149.png', '121.png', '175.png', '23.png', '111.png', '77.png', '34.png', '101.png', '178.png', '25.png', '132.png', '129.png', '117.png', '140.png', '138.png', '17.png', '73.png', '154.png', '11.png', '155.png', '13.png', '40.png', '98.png', '171.png', '160.png', '72.png', '122.png', '109.png', '148.png', '139.png', '76.png', '37.png', '15.png', '103.png', '70.png', '152.png']

# %%
# !sudo apt-get install eog --yes
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   aspell aspell-en bubblewrap docbook-xml enchant-2 gir1.2-atk-1.0
#   gir1.2-freedesktop gir1.2-gdkpixbuf-2.0 gir1.2-gtk-3.0 gir1.2-pango-1.0
#   gir1.2-peas-1.0 gnome-desktop3-data gstreamer1.0-gl
#   gstreamer1.0-plugins-base gstreamer1.0-plugins-good gstreamer1.0-pulseaudio
#   gstreamer1.0-x libaa1 libaspell15 libcdparanoia0 libdv4 libegl-mesa0 libegl1
#   libenchant-2-2 libexempi8 libexif12 libgbm1 libgnome-desktop-3-19
#   libgraphene-1.0-0 libgstreamer-gl1.0-0 libgstreamer-plugins-base1.0-0
#   libgstreamer-plugins-good1.0-0 libgudev-1.0-0 libhyphen0
#   libjavascriptcoregtk-4.0-18 libopengl0 liborc-0.4-0 libpangoxft-1.0-0
#   libpeas-1.0-0 libpeas-common libsecret-1-0 libsecret-common libshout3
#   libtag1v5 libtag1v5-vanilla libv4l-0 libv4lconvert0 libvisual-0.4-0
#   libwayland-server0 libwebkit2gtk-4.0-37 libwebpdemux2 libwoff1 libxslt1.1
#   libyelp0 python3-distro sgml-base sgml-data xdg-dbus-proxy xml-core yelp
#   yelp-xsl
# Suggested packages:
#   aspell-doc spellutils docbook docbook-dsssl docbook-xsl docbook-defguide
#   eog-plugins gvfs libdv-bin oss-compat libenchant-2-voikko
#   libvisual-0.4-plugins gstreamer1.0-libav sgml-base-doc perlsgml w3-recs
#   opensp libxml2-utils debhelper
# The following NEW packages will be installed:
#   aspell aspell-en bubblewrap docbook-xml enchant-2 eog gir1.2-atk-1.0
#   gir1.2-freedesktop gir1.2-gdkpixbuf-2.0 gir1.2-gtk-3.0 gir1.2-pango-1.0
#   gir1.2-peas-1.0 gnome-desktop3-data gstreamer1.0-gl
#   gstreamer1.0-plugins-base gstreamer1.0-plugins-good gstreamer1.0-pulseaudio
#   gstreamer1.0-x libaa1 libaspell15 libcdparanoia0 libdv4 libegl-mesa0 libegl1
#   libenchant-2-2 libexempi8 libexif12 libgbm1 libgnome-desktop-3-19
#   libgraphene-1.0-0 libgstreamer-gl1.0-0 libgstreamer-plugins-base1.0-0
#   libgstreamer-plugins-good1.0-0 libgudev-1.0-0 libhyphen0
#   libjavascriptcoregtk-4.0-18 libopengl0 liborc-0.4-0 libpangoxft-1.0-0
#   libpeas-1.0-0 libpeas-common libsecret-1-0 libsecret-common libshout3
#   libtag1v5 libtag1v5-vanilla libv4l-0 libv4lconvert0 libvisual-0.4-0
#   libwayland-server0 libwebkit2gtk-4.0-37 libwebpdemux2 libwoff1 libxslt1.1
#   libyelp0 python3-distro sgml-base sgml-data xdg-dbus-proxy xml-core yelp
#   yelp-xsl
# 0 upgraded, 62 newly installed, 0 to remove and 41 not upgraded.
# Need to get 32.5 MB of archives.
# After this operation, 131 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/main amd64 sgml-base all 1.29.1 [12.4 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libaspell15 amd64 0.60.8-1ubuntu0.1 [328 kB]
# Get:3 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 aspell amd64 0.60.8-1ubuntu0.1 [88.4 kB]
# Get:4 http://archive.ubuntu.com/ubuntu focal/main amd64 aspell-en all 2018.04.16-0-1 [299 kB]
# Get:5 http://archive.ubuntu.com/ubuntu focal/main amd64 bubblewrap amd64 0.4.0-1ubuntu4 [35.4 kB]
# Get:6 http://archive.ubuntu.com/ubuntu focal/main amd64 xml-core all 0.18+nmu1 [21.6 kB]
# Get:7 http://archive.ubuntu.com/ubuntu focal/main amd64 sgml-data all 2.0.11 [171 kB]
# Get:8 http://archive.ubuntu.com/ubuntu focal/main amd64 docbook-xml all 4.5-9 [71.2 kB]
# Get:9 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libenchant-2-2 amd64 2.2.8-1ubuntu0.20.04.1 [45.6 kB]
# Get:10 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 enchant-2 amd64 2.2.8-1ubuntu0.20.04.1 [12.1 kB]
# Get:11 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libexempi8 amd64 2.5.1-1ubuntu0.1 [529 kB]
# Get:12 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libexif12 amd64 0.6.21-6ubuntu0.4 [78.6 kB]
# Get:13 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 gnome-desktop3-data all 3.36.8-0ubuntu1 [21.7 kB]
# Get:14 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libgnome-desktop-3-19 amd64 3.36.8-0ubuntu1 [115 kB]
# Get:15 http://archive.ubuntu.com/ubuntu focal/main amd64 libpeas-common all 1.26.0-2 [9976 B]
# Get:16 http://archive.ubuntu.com/ubuntu focal/main amd64 libpeas-1.0-0 amd64 1.26.0-2 [60.1 kB]
# Get:17 http://archive.ubuntu.com/ubuntu focal/main amd64 gir1.2-atk-1.0 amd64 2.35.1-1ubuntu2 [18.2 kB]
# Get:18 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 gir1.2-freedesktop amd64 1.64.1-1~ubuntu20.04.1 [19.2 kB]
# Get:19 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 gir1.2-gdkpixbuf-2.0 amd64 2.40.0+dfsg-3ubuntu0.4 [8272 B]
# Get:20 http://archive.ubuntu.com/ubuntu focal/main amd64 libpangoxft-1.0-0 amd64 1.44.7-2ubuntu4 [18.0 kB]
# Get:21 http://archive.ubuntu.com/ubuntu focal/main amd64 gir1.2-pango-1.0 amd64 1.44.7-2ubuntu4 [26.6 kB]
# Get:22 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 gir1.2-gtk-3.0 amd64 3.24.20-0ubuntu1.1 [196 kB]
# Get:23 http://archive.ubuntu.com/ubuntu focal/main amd64 gir1.2-peas-1.0 amd64 1.26.0-2 [5864 B]
# Get:24 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 eog amd64 3.36.3-0ubuntu1 [421 kB]
# Get:25 http://archive.ubuntu.com/ubuntu focal/main amd64 libgraphene-1.0-0 amd64 1.10.0-1build2 [42.9 kB]
# Get:26 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libwayland-server0 amd64 1.18.0-1ubuntu0.1 [31.3 kB]
# Get:27 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libgbm1 amd64 21.2.6-0ubuntu0.1~20.04.2 [29.2 kB]
# Get:28 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libegl-mesa0 amd64 21.2.6-0ubuntu0.1~20.04.2 [96.3 kB]
# Get:29 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libegl1 amd64 1.3.2-1~ubuntu0.20.04.2 [31.9 kB]
# Get:30 http://archive.ubuntu.com/ubuntu focal/main amd64 liborc-0.4-0 amd64 1:0.4.31-1 [188 kB]
# Get:31 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libgstreamer-plugins-base1.0-0 amd64 1.16.3-0ubuntu1.2 [741 kB]
# Get:32 http://archive.ubuntu.com/ubuntu focal/main amd64 libgudev-1.0-0 amd64 1:233-1 [14.0 kB]
# Get:33 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libgstreamer-gl1.0-0 amd64 1.16.3-0ubuntu1.2 [163 kB]
# Get:34 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 gstreamer1.0-gl amd64 1.16.3-0ubuntu1.2 [109 kB]
# Get:35 http://archive.ubuntu.com/ubuntu focal/main amd64 libcdparanoia0 amd64 3.10.2+debian-13 [46.7 kB]
# Get:36 http://archive.ubuntu.com/ubuntu focal/main amd64 libvisual-0.4-0 amd64 0.4.0-17 [99.8 kB]
# Get:37 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 gstreamer1.0-plugins-base amd64 1.16.3-0ubuntu1.2 [619 kB]
# Get:38 http://archive.ubuntu.com/ubuntu focal/main amd64 libaa1 amd64 1.4p5-46 [47.3 kB]
# Get:39 http://archive.ubuntu.com/ubuntu focal/main amd64 libdv4 amd64 1.0.0-12 [58.0 kB]
# Get:40 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libgstreamer-plugins-good1.0-0 amd64 1.16.3-0ubuntu1.2 [68.8 kB]
# Get:41 http://archive.ubuntu.com/ubuntu focal/main amd64 libshout3 amd64 2.4.3-1 [50.6 kB]
# Get:42 http://archive.ubuntu.com/ubuntu focal/main amd64 libtag1v5-vanilla amd64 1.11.1+dfsg.1-0.3ubuntu2 [280 kB]
# Get:43 http://archive.ubuntu.com/ubuntu focal/main amd64 libtag1v5 amd64 1.11.1+dfsg.1-0.3ubuntu2 [11.0 kB]
# Get:44 http://archive.ubuntu.com/ubuntu focal/main amd64 libv4lconvert0 amd64 1.18.0-2build1 [76.5 kB]
# Get:45 http://archive.ubuntu.com/ubuntu focal/main amd64 libv4l-0 amd64 1.18.0-2build1 [41.9 kB]
# Get:46 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 gstreamer1.0-plugins-good amd64 1.16.3-0ubuntu1.2 [1746 kB]
# Get:47 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 gstreamer1.0-pulseaudio amd64 1.16.3-0ubuntu1.2 [93.5 kB]
# Get:48 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 gstreamer1.0-x amd64 1.16.3-0ubuntu1.2 [74.9 kB]
# Get:49 http://archive.ubuntu.com/ubuntu focal/main amd64 libhyphen0 amd64 2.8.8-7 [27.0 kB]
# Get:50 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libjavascriptcoregtk-4.0-18 amd64 2.38.6-0ubuntu0.20.04.1 [6446 kB]
# Get:51 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libsecret-common all 0.20.4-0ubuntu1 [3940 B]
# Get:52 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libsecret-1-0 amd64 0.20.4-0ubuntu1 [110 kB]
# Get:53 http://archive.ubuntu.com/ubuntu focal/main amd64 xdg-dbus-proxy amd64 0.1.2-1 [23.0 kB]
# Get:54 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libopengl0 amd64 1.3.2-1~ubuntu0.20.04.2 [29.2 kB]
# Get:55 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libwebpdemux2 amd64 0.6.1-2ubuntu0.20.04.3 [9560 B]
# Get:56 http://archive.ubuntu.com/ubuntu focal/main amd64 libwoff1 amd64 1.0.2-1build2 [42.0 kB]
# Get:57 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libxslt1.1 amd64 1.1.34-4ubuntu0.20.04.1 [151 kB]
# Get:58 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libwebkit2gtk-4.0-37 amd64 2.38.6-0ubuntu0.20.04.1 [17.5 MB]
# Get:59 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libyelp0 amd64 3.36.2-0ubuntu1 [94.3 kB]
# Get:60 http://archive.ubuntu.com/ubuntu focal/main amd64 python3-distro all 1.4.0-1 [14.6 kB]
# Get:61 http://archive.ubuntu.com/ubuntu focal/main amd64 yelp-xsl all 3.36.0-1 [180 kB]
# Get:62 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 yelp amd64 3.36.2-0ubuntu1 [527 kB]
# Fetched 32.5 MB in 5s (6295 kB/s)
# Extracting templates from packages: 100%
# Selecting previously unselected package sgml-base.
# (Reading database ... 108782 files and directories currently installed.)
# Preparing to unpack .../00-sgml-base_1.29.1_all.deb ...
# Unpacking sgml-base (1.29.1) ...
# Selecting previously unselected package libaspell15:amd64.
# Preparing to unpack .../01-libaspell15_0.60.8-1ubuntu0.1_amd64.deb ...
# Unpacking libaspell15:amd64 (0.60.8-1ubuntu0.1) ...
# Selecting previously unselected package aspell.
# Preparing to unpack .../02-aspell_0.60.8-1ubuntu0.1_amd64.deb ...
# Unpacking aspell (0.60.8-1ubuntu0.1) ...
# Selecting previously unselected package aspell-en.
# Preparing to unpack .../03-aspell-en_2018.04.16-0-1_all.deb ...
# Unpacking aspell-en (2018.04.16-0-1) ...
# Selecting previously unselected package bubblewrap.
# Preparing to unpack .../04-bubblewrap_0.4.0-1ubuntu4_amd64.deb ...
# Unpacking bubblewrap (0.4.0-1ubuntu4) ...
# Selecting previously unselected package xml-core.
# Preparing to unpack .../05-xml-core_0.18+nmu1_all.deb ...
# Unpacking xml-core (0.18+nmu1) ...
# Selecting previously unselected package sgml-data.
# Preparing to unpack .../06-sgml-data_2.0.11_all.deb ...
# Unpacking sgml-data (2.0.11) ...
# Selecting previously unselected package docbook-xml.
# Preparing to unpack .../07-docbook-xml_4.5-9_all.deb ...
# Unpacking docbook-xml (4.5-9) ...
# Selecting previously unselected package libenchant-2-2:amd64.
# Preparing to unpack .../08-libenchant-2-2_2.2.8-1ubuntu0.20.04.1_amd64.deb ...
# Unpacking libenchant-2-2:amd64 (2.2.8-1ubuntu0.20.04.1) ...
# Selecting previously unselected package enchant-2.
# Preparing to unpack .../09-enchant-2_2.2.8-1ubuntu0.20.04.1_amd64.deb ...
# Unpacking enchant-2 (2.2.8-1ubuntu0.20.04.1) ...
# Selecting previously unselected package libexempi8:amd64.
# Preparing to unpack .../10-libexempi8_2.5.1-1ubuntu0.1_amd64.deb ...
# Unpacking libexempi8:amd64 (2.5.1-1ubuntu0.1) ...
# Selecting previously unselected package libexif12:amd64.
# Preparing to unpack .../11-libexif12_0.6.21-6ubuntu0.4_amd64.deb ...
# Unpacking libexif12:amd64 (0.6.21-6ubuntu0.4) ...
# Selecting previously unselected package gnome-desktop3-data.
# Preparing to unpack .../12-gnome-desktop3-data_3.36.8-0ubuntu1_all.deb ...
# Unpacking gnome-desktop3-data (3.36.8-0ubuntu1) ...
# Selecting previously unselected package libgnome-desktop-3-19:amd64.
# Preparing to unpack .../13-libgnome-desktop-3-19_3.36.8-0ubuntu1_amd64.deb ...
# Unpacking libgnome-desktop-3-19:amd64 (3.36.8-0ubuntu1) ...
# Selecting previously unselected package libpeas-common.
# Preparing to unpack .../14-libpeas-common_1.26.0-2_all.deb ...
# Unpacking libpeas-common (1.26.0-2) ...
# Selecting previously unselected package libpeas-1.0-0:amd64.
# Preparing to unpack .../15-libpeas-1.0-0_1.26.0-2_amd64.deb ...
# Unpacking libpeas-1.0-0:amd64 (1.26.0-2) ...
# Selecting previously unselected package gir1.2-atk-1.0:amd64.
# Preparing to unpack .../16-gir1.2-atk-1.0_2.35.1-1ubuntu2_amd64.deb ...
# Unpacking gir1.2-atk-1.0:amd64 (2.35.1-1ubuntu2) ...
# Selecting previously unselected package gir1.2-freedesktop:amd64.
# Preparing to unpack .../17-gir1.2-freedesktop_1.64.1-1~ubuntu20.04.1_amd64.deb ...
# Unpacking gir1.2-freedesktop:amd64 (1.64.1-1~ubuntu20.04.1) ...
# Selecting previously unselected package gir1.2-gdkpixbuf-2.0:amd64.
# Preparing to unpack .../18-gir1.2-gdkpixbuf-2.0_2.40.0+dfsg-3ubuntu0.4_amd64.deb ...
# Unpacking gir1.2-gdkpixbuf-2.0:amd64 (2.40.0+dfsg-3ubuntu0.4) ...
# Selecting previously unselected package libpangoxft-1.0-0:amd64.
# Preparing to unpack .../19-libpangoxft-1.0-0_1.44.7-2ubuntu4_amd64.deb ...
# Unpacking libpangoxft-1.0-0:amd64 (1.44.7-2ubuntu4) ...
# Selecting previously unselected package gir1.2-pango-1.0:amd64.
# Preparing to unpack .../20-gir1.2-pango-1.0_1.44.7-2ubuntu4_amd64.deb ...
# Unpacking gir1.2-pango-1.0:amd64 (1.44.7-2ubuntu4) ...
# Selecting previously unselected package gir1.2-gtk-3.0:amd64.
# Preparing to unpack .../21-gir1.2-gtk-3.0_3.24.20-0ubuntu1.1_amd64.deb ...
# Unpacking gir1.2-gtk-3.0:amd64 (3.24.20-0ubuntu1.1) ...
# Selecting previously unselected package gir1.2-peas-1.0:amd64.
# Preparing to unpack .../22-gir1.2-peas-1.0_1.26.0-2_amd64.deb ...
# Unpacking gir1.2-peas-1.0:amd64 (1.26.0-2) ...
# Selecting previously unselected package eog.
# Preparing to unpack .../23-eog_3.36.3-0ubuntu1_amd64.deb ...
# Unpacking eog (3.36.3-0ubuntu1) ...
# Selecting previously unselected package libgraphene-1.0-0:amd64.
# Preparing to unpack .../24-libgraphene-1.0-0_1.10.0-1build2_amd64.deb ...
# Unpacking libgraphene-1.0-0:amd64 (1.10.0-1build2) ...
# Selecting previously unselected package libwayland-server0:amd64.
# Preparing to unpack .../25-libwayland-server0_1.18.0-1ubuntu0.1_amd64.deb ...
# Unpacking libwayland-server0:amd64 (1.18.0-1ubuntu0.1) ...
# Selecting previously unselected package libgbm1:amd64.
# Preparing to unpack .../26-libgbm1_21.2.6-0ubuntu0.1~20.04.2_amd64.deb ...
# Unpacking libgbm1:amd64 (21.2.6-0ubuntu0.1~20.04.2) ...
# Selecting previously unselected package libegl-mesa0:amd64.
# Preparing to unpack .../27-libegl-mesa0_21.2.6-0ubuntu0.1~20.04.2_amd64.deb ...
# Unpacking libegl-mesa0:amd64 (21.2.6-0ubuntu0.1~20.04.2) ...
# Selecting previously unselected package libegl1:amd64.
# Preparing to unpack .../28-libegl1_1.3.2-1~ubuntu0.20.04.2_amd64.deb ...
# Unpacking libegl1:amd64 (1.3.2-1~ubuntu0.20.04.2) ...
# Selecting previously unselected package liborc-0.4-0:amd64.
# Preparing to unpack .../29-liborc-0.4-0_1%3a0.4.31-1_amd64.deb ...
# Unpacking liborc-0.4-0:amd64 (1:0.4.31-1) ...
# Selecting previously unselected package libgstreamer-plugins-base1.0-0:amd64.
# Preparing to unpack .../30-libgstreamer-plugins-base1.0-0_1.16.3-0ubuntu1.2_amd64.deb ...
# Unpacking libgstreamer-plugins-base1.0-0:amd64 (1.16.3-0ubuntu1.2) ...
# Selecting previously unselected package libgudev-1.0-0:amd64.
# Preparing to unpack .../31-libgudev-1.0-0_1%3a233-1_amd64.deb ...
# Unpacking libgudev-1.0-0:amd64 (1:233-1) ...
# Selecting previously unselected package libgstreamer-gl1.0-0:amd64.
# Preparing to unpack .../32-libgstreamer-gl1.0-0_1.16.3-0ubuntu1.2_amd64.deb ...
# Unpacking libgstreamer-gl1.0-0:amd64 (1.16.3-0ubuntu1.2) ...
# Selecting previously unselected package gstreamer1.0-gl:amd64.
# Preparing to unpack .../33-gstreamer1.0-gl_1.16.3-0ubuntu1.2_amd64.deb ...
# Unpacking gstreamer1.0-gl:amd64 (1.16.3-0ubuntu1.2) ...
# Selecting previously unselected package libcdparanoia0:amd64.
# Preparing to unpack .../34-libcdparanoia0_3.10.2+debian-13_amd64.deb ...
# Unpacking libcdparanoia0:amd64 (3.10.2+debian-13) ...
# Selecting previously unselected package libvisual-0.4-0:amd64.
# Preparing to unpack .../35-libvisual-0.4-0_0.4.0-17_amd64.deb ...
# Unpacking libvisual-0.4-0:amd64 (0.4.0-17) ...
# Selecting previously unselected package gstreamer1.0-plugins-base:amd64.
# Preparing to unpack .../36-gstreamer1.0-plugins-base_1.16.3-0ubuntu1.2_amd64.deb ...
# Unpacking gstreamer1.0-plugins-base:amd64 (1.16.3-0ubuntu1.2) ...
# Selecting previously unselected package libaa1:amd64.
# Preparing to unpack .../37-libaa1_1.4p5-46_amd64.deb ...
# Unpacking libaa1:amd64 (1.4p5-46) ...
# Selecting previously unselected package libdv4:amd64.
# Preparing to unpack .../38-libdv4_1.0.0-12_amd64.deb ...
# Unpacking libdv4:amd64 (1.0.0-12) ...
# Selecting previously unselected package libgstreamer-plugins-good1.0-0:amd64.
# Preparing to unpack .../39-libgstreamer-plugins-good1.0-0_1.16.3-0ubuntu1.2_amd64.deb ...
# Unpacking libgstreamer-plugins-good1.0-0:amd64 (1.16.3-0ubuntu1.2) ...
# Selecting previously unselected package libshout3:amd64.
# Preparing to unpack .../40-libshout3_2.4.3-1_amd64.deb ...
# Unpacking libshout3:amd64 (2.4.3-1) ...
# Selecting previously unselected package libtag1v5-vanilla:amd64.
# Preparing to unpack .../41-libtag1v5-vanilla_1.11.1+dfsg.1-0.3ubuntu2_amd64.deb ...
# Unpacking libtag1v5-vanilla:amd64 (1.11.1+dfsg.1-0.3ubuntu2) ...
# Selecting previously unselected package libtag1v5:amd64.
# Preparing to unpack .../42-libtag1v5_1.11.1+dfsg.1-0.3ubuntu2_amd64.deb ...
# Unpacking libtag1v5:amd64 (1.11.1+dfsg.1-0.3ubuntu2) ...
# Selecting previously unselected package libv4lconvert0:amd64.
# Preparing to unpack .../43-libv4lconvert0_1.18.0-2build1_amd64.deb ...
# Unpacking libv4lconvert0:amd64 (1.18.0-2build1) ...
# Selecting previously unselected package libv4l-0:amd64.
# Preparing to unpack .../44-libv4l-0_1.18.0-2build1_amd64.deb ...
# Unpacking libv4l-0:amd64 (1.18.0-2build1) ...
# Selecting previously unselected package gstreamer1.0-plugins-good:amd64.
# Preparing to unpack .../45-gstreamer1.0-plugins-good_1.16.3-0ubuntu1.2_amd64.deb ...
# Unpacking gstreamer1.0-plugins-good:amd64 (1.16.3-0ubuntu1.2) ...
# Selecting previously unselected package gstreamer1.0-pulseaudio:amd64.
# Preparing to unpack .../46-gstreamer1.0-pulseaudio_1.16.3-0ubuntu1.2_amd64.deb ...
# Unpacking gstreamer1.0-pulseaudio:amd64 (1.16.3-0ubuntu1.2) ...
# Selecting previously unselected package gstreamer1.0-x:amd64.
# Preparing to unpack .../47-gstreamer1.0-x_1.16.3-0ubuntu1.2_amd64.deb ...
# Unpacking gstreamer1.0-x:amd64 (1.16.3-0ubuntu1.2) ...
# Selecting previously unselected package libhyphen0:amd64.
# Preparing to unpack .../48-libhyphen0_2.8.8-7_amd64.deb ...
# Unpacking libhyphen0:amd64 (2.8.8-7) ...
# Selecting previously unselected package libjavascriptcoregtk-4.0-18:amd64.
# Preparing to unpack .../49-libjavascriptcoregtk-4.0-18_2.38.6-0ubuntu0.20.04.1_amd64.deb ...
# Unpacking libjavascriptcoregtk-4.0-18:amd64 (2.38.6-0ubuntu0.20.04.1) ...
# Selecting previously unselected package libsecret-common.
# Preparing to unpack .../50-libsecret-common_0.20.4-0ubuntu1_all.deb ...
# Unpacking libsecret-common (0.20.4-0ubuntu1) ...
# Selecting previously unselected package libsecret-1-0:amd64.
# Preparing to unpack .../51-libsecret-1-0_0.20.4-0ubuntu1_amd64.deb ...
# Unpacking libsecret-1-0:amd64 (0.20.4-0ubuntu1) ...
# Selecting previously unselected package xdg-dbus-proxy.
# Preparing to unpack .../52-xdg-dbus-proxy_0.1.2-1_amd64.deb ...
# Unpacking xdg-dbus-proxy (0.1.2-1) ...
# Selecting previously unselected package libopengl0:amd64.
# Preparing to unpack .../53-libopengl0_1.3.2-1~ubuntu0.20.04.2_amd64.deb ...
# Unpacking libopengl0:amd64 (1.3.2-1~ubuntu0.20.04.2) ...
# Selecting previously unselected package libwebpdemux2:amd64.
# Preparing to unpack .../54-libwebpdemux2_0.6.1-2ubuntu0.20.04.3_amd64.deb ...
# Unpacking libwebpdemux2:amd64 (0.6.1-2ubuntu0.20.04.3) ...
# Selecting previously unselected package libwoff1:amd64.
# Preparing to unpack .../55-libwoff1_1.0.2-1build2_amd64.deb ...
# Unpacking libwoff1:amd64 (1.0.2-1build2) ...
# Selecting previously unselected package libxslt1.1:amd64.
# Preparing to unpack .../56-libxslt1.1_1.1.34-4ubuntu0.20.04.1_amd64.deb ...
# Unpacking libxslt1.1:amd64 (1.1.34-4ubuntu0.20.04.1) ...
# Selecting previously unselected package libwebkit2gtk-4.0-37:amd64.
# Preparing to unpack .../57-libwebkit2gtk-4.0-37_2.38.6-0ubuntu0.20.04.1_amd64.deb ...
# Unpacking libwebkit2gtk-4.0-37:amd64 (2.38.6-0ubuntu0.20.04.1) ...
# Selecting previously unselected package libyelp0:amd64.
# Preparing to unpack .../58-libyelp0_3.36.2-0ubuntu1_amd64.deb ...
# Unpacking libyelp0:amd64 (3.36.2-0ubuntu1) ...
# Selecting previously unselected package python3-distro.
# Preparing to unpack .../59-python3-distro_1.4.0-1_all.deb ...
# Unpacking python3-distro (1.4.0-1) ...
# Selecting previously unselected package yelp-xsl.
# Preparing to unpack .../60-yelp-xsl_3.36.0-1_all.deb ...
# Unpacking yelp-xsl (3.36.0-1) ...
# Selecting previously unselected package yelp.
# Preparing to unpack .../61-yelp_3.36.2-0ubuntu1_amd64.deb ...
# Unpacking yelp (3.36.2-0ubuntu1) ...
# Setting up bubblewrap (0.4.0-1ubuntu4) ...
# Setting up libcdparanoia0:amd64 (3.10.2+debian-13) ...
# Setting up libwayland-server0:amd64 (1.18.0-1ubuntu0.1) ...
# Setting up gir1.2-freedesktop:amd64 (1.64.1-1~ubuntu20.04.1) ...
# Setting up libtag1v5-vanilla:amd64 (1.11.1+dfsg.1-0.3ubuntu2) ...
# Setting up libpangoxft-1.0-0:amd64 (1.44.7-2ubuntu4) ...
# Setting up python3-distro (1.4.0-1) ...
# Setting up libwoff1:amd64 (1.0.2-1build2) ...
# Setting up gir1.2-gdkpixbuf-2.0:amd64 (2.40.0+dfsg-3ubuntu0.4) ...
# Setting up libhyphen0:amd64 (2.8.8-7) ...
# Setting up libgbm1:amd64 (21.2.6-0ubuntu0.1~20.04.2) ...
# Setting up libvisual-0.4-0:amd64 (0.4.0-17) ...
# Setting up gir1.2-atk-1.0:amd64 (2.35.1-1ubuntu2) ...
# Setting up libaspell15:amd64 (0.60.8-1ubuntu0.1) ...
# Setting up libwebpdemux2:amd64 (0.6.1-2ubuntu0.20.04.3) ...
# Setting up libjavascriptcoregtk-4.0-18:amd64 (2.38.6-0ubuntu0.20.04.1) ...
# Setting up libexempi8:amd64 (2.5.1-1ubuntu0.1) ...
# Setting up libpeas-common (1.26.0-2) ...
# Setting up libopengl0:amd64 (1.3.2-1~ubuntu0.20.04.2) ...
# Setting up gnome-desktop3-data (3.36.8-0ubuntu1) ...
# Setting up gir1.2-pango-1.0:amd64 (1.44.7-2ubuntu4) ...
# Setting up libegl-mesa0:amd64 (21.2.6-0ubuntu0.1~20.04.2) ...
# Setting up libexif12:amd64 (0.6.21-6ubuntu0.4) ...
# Setting up libshout3:amd64 (2.4.3-1) ...
# Setting up liborc-0.4-0:amd64 (1:0.4.31-1) ...
# Setting up aspell (0.60.8-1ubuntu0.1) ...
# Setting up xdg-dbus-proxy (0.1.2-1) ...
# Setting up libtag1v5:amd64 (1.11.1+dfsg.1-0.3ubuntu2) ...
# Setting up libdv4:amd64 (1.0.0-12) ...
# Setting up libpeas-1.0-0:amd64 (1.26.0-2) ...
# Setting up libv4lconvert0:amd64 (1.18.0-2build1) ...
# Setting up libxslt1.1:amd64 (1.1.34-4ubuntu0.20.04.1) ...
# Setting up libegl1:amd64 (1.3.2-1~ubuntu0.20.04.2) ...
# Setting up sgml-base (1.29.1) ...
# Setting up libgnome-desktop-3-19:amd64 (3.36.8-0ubuntu1) ...
# Setting up libgudev-1.0-0:amd64 (1:233-1) ...
# Setting up libsecret-common (0.20.4-0ubuntu1) ...
# Setting up yelp-xsl (3.36.0-1) ...
# Setting up libgraphene-1.0-0:amd64 (1.10.0-1build2) ...
# Setting up libaa1:amd64 (1.4p5-46) ...
# Setting up libenchant-2-2:amd64 (2.2.8-1ubuntu0.20.04.1) ...
# Setting up gir1.2-gtk-3.0:amd64 (3.24.20-0ubuntu1.1) ...
# Setting up aspell-en (2018.04.16-0-1) ...
# Setting up enchant-2 (2.2.8-1ubuntu0.20.04.1) ...
# Setting up libgstreamer-plugins-base1.0-0:amd64 (1.16.3-0ubuntu1.2) ...
# Setting up gir1.2-peas-1.0:amd64 (1.26.0-2) ...
# Setting up libv4l-0:amd64 (1.18.0-2build1) ...
# Setting up libsecret-1-0:amd64 (0.20.4-0ubuntu1) ...
# Setting up libgstreamer-plugins-good1.0-0:amd64 (1.16.3-0ubuntu1.2) ...
# Setting up libgstreamer-gl1.0-0:amd64 (1.16.3-0ubuntu1.2) ...
# Setting up gstreamer1.0-plugins-base:amd64 (1.16.3-0ubuntu1.2) ...
# Setting up libwebkit2gtk-4.0-37:amd64 (2.38.6-0ubuntu0.20.04.1) ...
# Setting up xml-core (0.18+nmu1) ...
# Setting up gstreamer1.0-pulseaudio:amd64 (1.16.3-0ubuntu1.2) ...
# Setting up eog (3.36.3-0ubuntu1) ...
# Setting up gstreamer1.0-gl:amd64 (1.16.3-0ubuntu1.2) ...
# Setting up gstreamer1.0-x:amd64 (1.16.3-0ubuntu1.2) ...
# Setting up gstreamer1.0-plugins-good:amd64 (1.16.3-0ubuntu1.2) ...
# Setting up libyelp0:amd64 (3.36.2-0ubuntu1) ...
# Setting up yelp (3.36.2-0ubuntu1) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.9) ...
# Processing triggers for man-db (2.9.1-1) ...
# Processing triggers for mime-support (3.64ubuntu1) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for libglib2.0-0:amd64 (2.64.6-1~ubuntu20.04.6) ...
# Processing triggers for sgml-base (1.29.1) ...
# Setting up sgml-data (2.0.11) ...
# Processing triggers for sgml-base (1.29.1) ...
# Setting up docbook-xml (4.5-9) ...
# Processing triggers for dictionaries-common (1.28.1) ...
# aspell-autobuildhash: processing: en [en-common].
# aspell-autobuildhash: processing: en [en-variant_0].
# aspell-autobuildhash: processing: en [en-variant_1].
# aspell-autobuildhash: processing: en [en-variant_2].
# aspell-autobuildhash: processing: en [en-w_accents-only].
# aspell-autobuildhash: processing: en [en-wo_accents-only].
# aspell-autobuildhash: processing: en [en_AU-variant_0].
# aspell-autobuildhash: processing: en [en_AU-variant_1].
# aspell-autobuildhash: processing: en [en_AU-w_accents-only].
# aspell-autobuildhash: processing: en [en_AU-wo_accents-only].
# aspell-autobuildhash: processing: en [en_CA-variant_0].
# aspell-autobuildhash: processing: en [en_CA-variant_1].
# aspell-autobuildhash: processing: en [en_CA-w_accents-only].
# aspell-autobuildhash: processing: en [en_CA-wo_accents-only].
# aspell-autobuildhash: processing: en [en_GB-ise-w_accents-only].
# aspell-autobuildhash: processing: en [en_GB-ise-wo_accents-only].
# aspell-autobuildhash: processing: en [en_GB-ize-w_accents-only].
# aspell-autobuildhash: processing: en [en_GB-ize-wo_accents-only].
# aspell-autobuildhash: processing: en [en_GB-variant_0].
# aspell-autobuildhash: processing: en [en_GB-variant_1].
# aspell-autobuildhash: processing: en [en_US-w_accents-only].
# aspell-autobuildhash: processing: en [en_US-wo_accents-only].
# Processing triggers for sgml-base (1.29.1) ...

# %%
# !sudo apt-get install ImageMagick --yes
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# E: Unable to locate package ImageMagick

# %%
_, axes = plt.subplots(1, 2, figsize=(12, 5))
axes[0].plot(history['loss'], label='train')
axes[0].plot(history['val_loss'], label='valid')
axes[0].set_title('Loss history')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Loss')
axes[0].grid(True)
axes[1].plot(history['acc'], label='train')
axes[1].plot(history['val_acc'], label='valid')
axes[1].plot(np.array(history['bleu4']) * 100., label='BLEU-4')
axes[1].set_title('Accuracy & BLEU-4 history')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Accuracy & BLEU-4 (%)')
axes[1].grid(True)
plt.legend()
plt.show()

# %% [markdown]
# # 6. Evaluation

# %%
def evaluate(model, loader, beam_size, field, max_len, device):
    references, hypotheses = [], []
    model.eval()
    with torch.no_grad():
        pbar = tqdm.tqdm(enumerate(loader), total=len(loader))
        for i, (images, (target_sequences, sequence_lengths), (all_target_sequences, all_sequence_lengths)) in pbar:
            images = images.to(device)
            target_sequences = target_sequences.to(device)
            sequence_lengths = sequence_lengths.to(device)
            all_target_sequences = all_target_sequences.to(device)
            all_sequence_lengths = all_sequence_lengths.to(device)

            k = beam_size

            # Top k previous token indices at each step
            topk_prev_tokens = torch.LongTensor([[field.vocab.stoi[field.init_token]]] * k).to(device)  # [k, 1]

            # Top k sequences
            topk_sequences = topk_prev_tokens  # [k, 1]

            # Top k sequences' logps
            topk_logps = torch.zeros(k, 1).to(device)  # [k, 1]

            # Complete sequences and logps
            complete_sequences, complete_sequence_logps = [], []

            # Encoding
            image_features = model.encoder(images) # [1, 14, 14, hidden_size]
            image_features = image_features.view(1, -1, model.encoder.hidden_size) # [1, num_pixels, enc_hidden_size]
            image_features = image_features.expand(k, -1, -1) # [k, num_pixels, enc_hidden_size]

            # Init hidden and memory states
            mean_image_features = image_features.mean(dim=1) # [k, enc_hidden_size]
            h_state, c_state = model.init_h0(mean_image_features), model.init_c0(mean_image_features) # [k, dec_hidden_size]

            # Decoding
            step = 1
            while True:
                if len(h_state.shape) < 3:
                    h_state, c_state = h_state.unsqueeze(0), c_state.unsqueeze(0) # [1, k, dec_hidden_size]

                logit, h_state, c_state, _ = model.decoder(topk_prev_tokens.squeeze(1), h_state, c_state, image_features)

                # Get scores
                logp = F.log_softmax(logit, dim=1) # [k, vocab_size]

                # Extend
                logp = topk_logps.expand_as(logp) + logp  # [k, vocab_size]

                # At the 1st step, the score is 0
                if step == 1:
                    topk_logps, topk_tokens = logp[0].topk(k, 0, True, True)  # [k,]
                else:
                    # Unroll and find top logp, and their unrolled indices
                    topk_logps, topk_tokens = logp.view(-1).topk(k, 0, True, True)  # [k,]

                # Convert unrolled indices to actual indices of logp
                prev_tokens = torch.div(topk_tokens, model.decoder.vocab_size, rounding_mode='trunc')  # [k,]
                next_tokens = topk_tokens % model.decoder.vocab_size  #k

                # Add new indices to topk_sequences
                topk_sequences = torch.cat((topk_sequences[prev_tokens], next_tokens.unsqueeze(1)), dim=1) # [k, step + 1]
                # Get the complete and incomplete sequences
                incomplete_indices = [indice for indice, next_token in enumerate(next_tokens) if next_token != field.vocab.stoi[field.eos_token]]
                complete_indices = list(set(range(len(next_tokens))) - set(incomplete_indices))

                # Set aside complete sequences
                if len(complete_indices) > 0:
                    complete_sequences.extend(topk_sequences[complete_indices].tolist())
                    complete_sequence_logps.extend(topk_logps[complete_indices])

                # Reduce beam length accordingly
                k -= len(complete_indices)

                # Proceed with incomplete sequences
                if k == 0:
                    break

                topk_sequences = topk_sequences[incomplete_indices]
                h_state = h_state[:, prev_tokens[incomplete_indices], :]
                c_state = c_state[:, prev_tokens[incomplete_indices], :]
                image_features = image_features[prev_tokens[incomplete_indices]]
                topk_logps = topk_logps[incomplete_indices].unsqueeze(1)
                topk_prev_tokens = next_tokens[incomplete_indices].unsqueeze(1)

                # Break if things have been going on too long
                if step > max_len:
                    if len(complete_indices) == 0:
                        complete_sequences.extend(topk_sequences.tolist())
                        complete_sequence_logps.extend(topk_logps[incomplete_indices])
                    break

                # Update step
                step += 1

            i = complete_sequence_logps.index(max(complete_sequence_logps))
            sequence = complete_sequences[i]

            # Update references
            for j in range(all_target_sequences.size(0)):
                img_caps = all_target_sequences[j].t().tolist()
                img_caps = [*map(lambda caption: [field.vocab.itos[token] for token in caption
                                                  if token not in (field.vocab.stoi[field.init_token],
                                                                   field.vocab.stoi[field.pad_token])], img_caps)]
                references.append(img_caps)

            # Update hypotheses
            hypotheses.append([field.vocab.itos[token] for token in sequence if token not in
                               {field.vocab.stoi[field.init_token],
                                field.vocab.stoi[field.eos_token],
                                field.vocab.stoi[field.pad_token]}])

            assert len(references) == len(hypotheses)

        # Calculate BLEU-4 score
        bleu4 = bleu_score(hypotheses, references, max_n=4, weights=[0.25, 0.25, 0.25, 0.25])

    return hypotheses, references, bleu4

# %%
# def evaluate(model, loader, beam_size, field, max_len, device):
#     references, hypotheses = [], []
#     model.eval()
#     with torch.no_grad():
#         pbar = tqdm.tqdm(enumerate(loader), total=len(loader))
#         for i, (images, (target_sequences, sequence_lengths), (all_target_sequences, all_sequence_lengths)) in pbar:
#             images = images.to(device)
#             target_sequences = target_sequences.to(device)
#             sequence_lengths = sequence_lengths.to(device)
#             all_target_sequences = all_target_sequences.to(device)
#             all_sequence_lengths = all_sequence_lengths.to(device)

#             k = beam_size

#             # Top k previous token indices at each step
#             topk_prev_tokens = torch.LongTensor([[field.vocab.stoi[field.init_token]]] * k).to(device)  # [k, 1]

#             # Top k sequences
#             topk_sequences = topk_prev_tokens  # [k, 1]

#             # Top k sequences' logps
#             topk_logps = torch.zeros(k, 1).to(device)  # [k, 1]

#             # Complete sequences and logps
#             complete_sequences, complete_sequence_logps = [], []

#             # Encoding
#             image_features = model.encoder(images) # [1, 14, 14, hidden_size]
#             image_features = image_features.view(1, -1, model.encoder.hidden_size) # [1, num_pixels, enc_hidden_size]
#             image_features = image_features.expand(k, -1, -1) # [k, num_pixels, enc_hidden_size]

#             # Init hidden and memory states
#             mean_image_features = image_features.mean(dim=1) # [k, enc_hidden_size]
#             h_state, c_state = model.init_h0(mean_image_features), model.init_c0(mean_image_features) # [k, dec_hidden_size]

#             # Decoding
#             step = 1
#             while True:
#                 if len(h_state.shape) < 3:
#                     h_state, c_state = h_state.unsqueeze(0), c_state.unsqueeze(0) # [1, k, dec_hidden_size]

#                 logit, h_state, c_state, _ = model.decoder(topk_prev_tokens.squeeze(1), h_state, c_state, image_features)

#                 # Get scores
#                 logp = F.log_softmax(logit, dim=1) # [k, vocab_size]

#                 # Extend
#                 logp = topk_logps.expand_as(logp) + logp  # [k, vocab_size]

#                 # At the 1st step, the score is 0
#                 if step == 1:
#                     topk_logps, topk_tokens = logp[0].topk(k, 0, True, True)  # [k,]
#                 else:
#                     # Unroll and find top logp, and their unrolled indices
#                     topk_logps, topk_tokens = logp.view(-1).topk(k, 0, True, True)  # [k,]

#                 # Convert unrolled indices to actual indices of logp
#                 prev_tokens = topk_tokens // model.decoder.vocab_size  # [k,]
#                 next_tokens = topk_tokens % model.decoder.vocab_size  # [k,]

#                 # Add new indices to topk_sequences
#                 topk_sequences = torch.cat((topk_sequences[prev_tokens], next_tokens.unsqueeze(1)), dim=1) # [k, step + 1]

#                 # Get the complete and incomplete sequences
#                 incomplete_indices = [indice for indice, next_token in enumerate(next_tokens) if next_token != field.vocab.stoi[field.eos_token]]
#                 complete_indices = list(set(range(len(next_tokens))) - set(incomplete_indices))

#                 # Set aside complete sequences
#                 if len(complete_indices) > 0:
#                     complete_sequences.extend(topk_sequences[complete_indices].tolist())
#                     complete_sequence_logps.extend(topk_logps[complete_indices])

#                 # Reduce beam length accordingly
#                 k -= len(complete_indices)

#                 # Proceed with incomplete sequences
#                 if k == 0:
#                     break

#                 topk_sequences = topk_sequences[incomplete_indices]
#                 h_state = h_state[:, prev_tokens[incomplete_indices], :]
#                 c_state = c_state[:, prev_tokens[incomplete_indices], :]
#                 image_features = image_features[prev_tokens[incomplete_indices]]
#                 topk_logps = topk_logps[incomplete_indices].unsqueeze(1)
#                 topk_prev_tokens = next_tokens[incomplete_indices].unsqueeze(1)

#                 # Break if things have been going on too long
#                 if step > max_len:
#                     if len(complete_indices) == 0:
#                         complete_sequences.extend(topk_sequences.tolist())
#                         complete_sequence_logps.extend(topk_logps[incomplete_indices])
#                     break

#                 # Update step
#                 step += 1

#             i = complete_sequence_logps.index(max(complete_sequence_logps))
#             sequence = complete_sequences[i]

#             # Update references
#             for j in range(all_target_sequences.size(0)):
#                 img_caps = all_target_sequences[j].t().tolist()
#                 img_caps = [*map(lambda caption: [field.vocab.itos[token] for token in caption
#                                                   if token not in (field.vocab.stoi[field.init_token],
#                                                                    field.vocab.stoi[field.pad_token])], img_caps)]
#                 references.append(img_caps)

#             # Update hypotheses
#             hypotheses.append([field.vocab.itos[token] for token in sequence if token not in
#                                {field.vocab.stoi[field.init_token],
#                                 field.vocab.stoi[field.eos_token],
#                                 field.vocab.stoi[field.pad_token]}])

#             assert len(references) == len(hypotheses)

#         # Calculate BLEU-4 score
#         bleu4 = bleu_score(hypotheses, references, max_n=4, weights=[0.25, 0.25, 0.25, 0.25])

#     return hypotheses, references, bleu4

# %%
test_dataset = ImageCaptionDataset(data_path='./data/Monumentos/',
                                   img_captions=test_img_captions,
                                   split_set='TESTE',
                                   img_transform=img_transform,
                                   caption_transform=caption_transform)

test_loader = torch.utils.data.DataLoader(test_dataset,
                                          num_workers=N_WORKERS,
                                          batch_size=1,
                                          shuffle=True,
                                          pin_memory=True)

# %%
autoencoder.load_state_dict(torch.load('./checkpoint/BEST_Monumentos.pt').get('model'))
# Out:
# <All keys matched successfully>

# %%
# !pip install --upgrade ipython
# Out:
# Requirement already satisfied: ipython in /opt/conda/lib/python3.10/site-packages (8.14.0)
# Collecting ipython
#   Downloading ipython-8.18.1-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.10/site-packages (from ipython) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.10/site-packages (from ipython) (0.19.0)
# Requirement already satisfied: matplotlib-inline in /opt/conda/lib/python3.10/site-packages (from ipython) (0.1.6)
# Collecting prompt-toolkit<3.1.0,>=3.0.41 (from ipython)
#   Downloading prompt_toolkit-3.0.41-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: pygments>=2.4.0 in /opt/conda/lib/python3.10/site-packages (from ipython) (2.16.1)
# Requirement already satisfied: stack-data in /opt/conda/lib/python3.10/site-packages (from ipython) (0.6.2)
# Requirement already satisfied: traitlets>=5 in /opt/conda/lib/python3.10/site-packages (from ipython) (5.9.0)
# Requirement already satisfied: exceptiongroup in /opt/conda/lib/python3.10/site-packages (from ipython) (1.1.3)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.10/site-packages (from ipython) (4.8.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /opt/conda/lib/python3.10/site-packages (from jedi>=0.16->ipython) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.10/site-packages (from pexpect>4.3->ipython) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython) (0.2.6)
# Requirement already satisfied: executing>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython) (2.2.1)
# Requirement already satisfied: pure-eval in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython) (0.2.2)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from asttokens>=2.1.0->stack-data->ipython) (1.16.0)
# Downloading ipython-8.18.1-py3-none-any.whl (808 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 808.2/808.2 kB 8.7 MB/s eta 0:00:00:00:010:01
# Downloading prompt_toolkit-3.0.41-py3-none-any.whl (385 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 385.5/385.5 kB 16.9 MB/s eta 0:00:00
# Installing collected packages: prompt-toolkit, ipython
#   Attempting uninstall: prompt-toolkit
#     Found existing installation: prompt-toolkit 3.0.39
#     Uninstalling prompt-toolkit-3.0.39:
#       Successfully uninstalled prompt-toolkit-3.0.39
#   Attempting uninstall: ipython
#     Found existing installation: ipython 8.14.0
#     Uninstalling ipython-8.14.0:
#       Successfully uninstalled ipython-8.14.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jupyterlab-lsp 5.0.0 requires jupyterlab<5.0.0a0,>=4.0.6, but you have jupyterlab 4.0.5 which is incompatible.
# Successfully installed ipython-8.14.0 prompt-toolkit-3.0.39

# %%
# %%time
_, _, bleu4 = evaluate(autoencoder.to(DEVICE),
                       loader=test_loader,
                       beam_size=1,
                       field=PT,
                       max_len=MAX_LEN,
                       device=DEVICE)
print(f'BLEU-4: {bleu4*100:.3f}% with beam_size=1')
# Out:
# 100%|██████████| 18/18 [00:13<00:00,  1.34it/s]
# BLEU-4: 9.126% with beam_size=1
# CPU times: user 25.4 s, sys: 980 ms, total: 26.4 s
# Wall time: 14.1 s

# %%
# %%time
_, _, bleu4 = evaluate(autoencoder.to(DEVICE),
                       loader=test_loader,
                       beam_size=3,
                       field=PT,
                       max_len=MAX_LEN,
                       device=DEVICE)
print(f'BLEU-4: {bleu4*100:.3f}% with beam_size=3')
# Out:
# 100%|██████████| 18/18 [00:14<00:00,  1.25it/s]
# BLEU-4: 14.380% with beam_size=3
# CPU times: user 27.3 s, sys: 978 ms, total: 28.3 s
# Wall time: 15 s

# %%
# %%time
_, _, bleu4 = evaluate(autoencoder.to(DEVICE),
                       loader=test_loader,
                       beam_size=5,
                       field=PT,
                       max_len=MAX_LEN,
                       device=DEVICE)
print(f'BLEU-4: {bleu4*100:.3f}% with beam_size=5')
# Out:
# 100%|██████████| 18/18 [00:14<00:00,  1.22it/s]
# BLEU-4: 14.320% with beam_size=5
# CPU times: user 28.2 s, sys: 787 ms, total: 29 s
# Wall time: 15.4 s

# %% [markdown]
# # 7. Inference

# %%
def generate_caption(image_path, model, image_transform, beam_size, field, max_len, device, image_shape=(256, 256)):
    assert callable(image_transform)

    # Load the image
    image = Image.open(image_path).convert('RGB')
    image = image_transform(image.resize(image_shape))
    image = image.unsqueeze(0)

    model.eval()
    with torch.no_grad():
        image = image.to(device)

        k = beam_size

        # Top k previous token indices at each step
        topk_prev_tokens = torch.LongTensor([[field.vocab.stoi[field.init_token]]] * k).to(device)  # [k, 1]

        # Top k sequences
        topk_sequences = topk_prev_tokens  # [k, 1]

        # Top k sequences' logps
        topk_logps = torch.zeros(k, 1).to(device)  # [k, 1]

        # Complete sequences and logps
        complete_sequences, complete_sequence_logps = [], []

        # Encoding
        image_features = model.encoder(image) # [1, 14, 14, hidden_size]
        image_features = image_features.view(1, -1, model.encoder.hidden_size) # [1, num_pixels, enc_hidden_size]
        image_features = image_features.expand(k, -1, -1) # [k, num_pixels, enc_hidden_size]

        # Init hidden and memory states
        mean_image_features = image_features.mean(dim=1) # [k, enc_hidden_size]
        h_state, c_state = model.init_h0(mean_image_features), model.init_c0(mean_image_features) # [k, dec_hidden_size]

        # Decoding
        step = 1
        while True:
            if len(h_state.shape) < 3:
                h_state, c_state = h_state.unsqueeze(0), c_state.unsqueeze(0) # [1, k, dec_hidden_size]

            logit, h_state, c_state, _ = model.decoder(topk_prev_tokens.squeeze(1), h_state, c_state, image_features)

            # Get scores
            logp = F.log_softmax(logit, dim=1) # [k, vocab_size]

            # Extend
            logp = topk_logps.expand_as(logp) + logp  # [k, vocab_size]

            # At the 1st step, the score is 0
            if step == 1:
                topk_logps, topk_tokens = logp[0].topk(k, 0, True, True)  # [k,]
            else:
                # Unroll and find top logp, and their unrolled indices
                topk_logps, topk_tokens = logp.view(-1).topk(k, 0, True, True)  # [k,]

            # Convert unrolled indices to actual indices of logp
            prev_tokens = torch.div(topk_tokens, model.decoder.vocab_size, rounding_mode='trunc')  # [k,]
            next_tokens = topk_tokens % model.decoder.vocab_size  #k
            # Add new indices to topk_sequences
            topk_sequences = torch.cat((topk_sequences[prev_tokens], next_tokens.unsqueeze(1)), dim=1) # [k, step + 1]

            # Get the complete and incomplete sequences
            incomplete_indices = [indice for indice, next_token in enumerate(next_tokens) if next_token != field.vocab.stoi[field.eos_token]]
            complete_indices = list(set(range(len(next_tokens))) - set(incomplete_indices))

            # Set aside complete sequences
            if len(complete_indices) > 0:
                complete_sequences.extend(topk_sequences[complete_indices].tolist())
                complete_sequence_logps.extend(topk_logps[complete_indices])

            # Reduce beam length accordingly
            k -= len(complete_indices)

            # Proceed with incomplete sequences
            if k == 0:
                break

            topk_sequences = topk_sequences[incomplete_indices]
            h_state = h_state[:, prev_tokens[incomplete_indices], :]
            c_state = c_state[:, prev_tokens[incomplete_indices], :]
            image_features = image_features[prev_tokens[incomplete_indices]]
            topk_logps = topk_logps[incomplete_indices].unsqueeze(1)
            topk_prev_tokens = next_tokens[incomplete_indices].unsqueeze(1)

            # Break if things have been going on too long
            if step > max_len:
                if len(complete_indices) == 0:
                    complete_sequences.extend(topk_sequences.tolist())
                    complete_sequence_logps.extend(topk_logps[incomplete_indices])
                break

            # Update step
            step += 1

        i = complete_sequence_logps.index(max(complete_sequence_logps))
        sequence = complete_sequences[i]

        caption = ' '.join([field.vocab.itos[token] for token in sequence if token not in
                               {field.vocab.stoi[field.init_token],
                                field.vocab.stoi[field.eos_token],
                                field.vocab.stoi[field.pad_token]}])

    return caption

# %%
# def generate_caption(image_path, model, image_transform, beam_size, field, max_len, device, image_shape=(256, 256)):
#     assert callable(image_transform)

#     # Load the image
#     image = Image.open(image_path).convert('RGB')
#     image = image_transform(image.resize(image_shape))
#     image = image.unsqueeze(0)

#     model.eval()
#     with torch.no_grad():
#         image = image.to(device)

#         k = beam_size

#         # Top k previous token indices at each step
#         topk_prev_tokens = torch.LongTensor([[field.vocab.stoi[field.init_token]]] * k).to(device)  # [k, 1]

#         # Top k sequences
#         topk_sequences = topk_prev_tokens  # [k, 1]

#         # Top k sequences' logps
#         topk_logps = torch.zeros(k, 1).to(device)  # [k, 1]

#         # Complete sequences and logps
#         complete_sequences, complete_sequence_logps = [], []

#         # Encoding
#         image_features = model.encoder(image) # [1, 14, 14, hidden_size]
#         image_features = image_features.view(1, -1, model.encoder.hidden_size) # [1, num_pixels, enc_hidden_size]
#         image_features = image_features.expand(k, -1, -1) # [k, num_pixels, enc_hidden_size]

#         # Init hidden and memory states
#         mean_image_features = image_features.mean(dim=1) # [k, enc_hidden_size]
#         h_state, c_state = model.init_h0(mean_image_features), model.init_c0(mean_image_features) # [k, dec_hidden_size]

#         # Decoding
#         step = 1
#         while True:
#             if len(h_state.shape) < 3:
#                 h_state, c_state = h_state.unsqueeze(0), c_state.unsqueeze(0) # [1, k, dec_hidden_size]

#             logit, h_state, c_state, _ = model.decoder(topk_prev_tokens.squeeze(1), h_state, c_state, image_features)

#             # Get scores
#             logp = F.log_softmax(logit, dim=1) # [k, vocab_size]

#             # Extend
#             logp = topk_logps.expand_as(logp) + logp  # [k, vocab_size]

#             # At the 1st step, the score is 0
#             if step == 1:
#                 topk_logps, topk_tokens = logp[0].topk(k, 0, True, True)  # [k,]
#             else:
#                 # Unroll and find top logp, and their unrolled indices
#                 topk_logps, topk_tokens = logp.view(-1).topk(k, 0, True, True)  # [k,]

#             # Convert unrolled indices to actual indices of logp
#             prev_tokens = topk_tokens // model.decoder.vocab_size  # [k,]
#             next_tokens = topk_tokens % model.decoder.vocab_size  # [k,]
            
#             prev_tokens = torch.div(topk_tokens, model.decoder.vocab_size, rounding_mode='trunc')  # [k,]
#             next_tokens = topk_tokens % model.decoder.vocab_size  #k
#             # Add new indices to topk_sequences
#             topk_sequences = torch.cat((topk_sequences[prev_tokens], next_tokens.unsqueeze(1)), dim=1) # [k, step + 1]

#             # Get the complete and incomplete sequences
#             incomplete_indices = [indice for indice, next_token in enumerate(next_tokens) if next_token != field.vocab.stoi[field.eos_token]]
#             complete_indices = list(set(range(len(next_tokens))) - set(incomplete_indices))

#             # Set aside complete sequences
#             if len(complete_indices) > 0:
#                 complete_sequences.extend(topk_sequences[complete_indices].tolist())
#                 complete_sequence_logps.extend(topk_logps[complete_indices])

#             # Reduce beam length accordingly
#             k -= len(complete_indices)

#             # Proceed with incomplete sequences
#             if k == 0:
#                 break

#             topk_sequences = topk_sequences[incomplete_indices]
#             h_state = h_state[:, prev_tokens[incomplete_indices], :]
#             c_state = c_state[:, prev_tokens[incomplete_indices], :]
#             image_features = image_features[prev_tokens[incomplete_indices]]
#             topk_logps = topk_logps[incomplete_indices].unsqueeze(1)
#             topk_prev_tokens = next_tokens[incomplete_indices].unsqueeze(1)

#             # Break if things have been going on too long
#             if step > max_len:
#                 if len(complete_indices) == 0:
#                     complete_sequences.extend(topk_sequences.tolist())
#                     complete_sequence_logps.extend(topk_logps[incomplete_indices])
#                 break

#             # Update step
#             step += 1

#         i = complete_sequence_logps.index(max(complete_sequence_logps))
#         sequence = complete_sequences[i]

#         caption = ' '.join([field.vocab.itos[token] for token in sequence if token not in
#                                {field.vocab.stoi[field.init_token],
#                                 field.vocab.stoi[field.eos_token],
#                                 field.vocab.stoi[field.pad_token]}])

#     return caption

# %%
image_names = [*test_img_captions.keys()]

# %%
# default

# for _ in range(5):
#     img = image_names[np.random.randint(0, 1000)]

#     caption = generate_caption('./data/Flicker8k_Dataset/' + img,
#                                model=autoencoder.to(DEVICE),
#                                image_transform=img_transform,
#                                beam_size=3, field=EN, max_len=MAX_LEN,
#                                device=DEVICE, image_shape=(256, 256))

#     text = f'Predicted\n{caption}\n\n'
#     text += 'True captions\n'
#     text += '\n'.join(test_img_captions[img])

#     plt.imshow(plt.imread('./data/Flicker8k_Dataset/' + img))
#     plt.title(text)
#     plt.show()

# %%
import os

# Defina o diretório de saída onde deseja salvar as imagens
output_directory = './output_images/'

# Verifique se o diretório de saída existe ou crie-o se não existir
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

# Resto do seu código para salvar as imagens

# %%
# import numpy as np
# import matplotlib.pyplot as plt

# # Defina o diretório de saída onde deseja salvar as imagens
# output_directory = './output_images/'

# for _ in range(5):
#     img = image_names[np.random.randint(0, 17)]

#     caption = generate_caption('./data/Monumentos/' + img,
#                                model=autoencoder.to(DEVICE),
#                                image_transform=img_transform,
#                                beam_size=3, field=PT, max_len=MAX_LEN,
#                                device=DEVICE, image_shape=(256, 256))

#     text = f'Previsto\n{caption}\n\n'
#     text += 'Legendas verdadeiras\n'
#     text += '\n'.join(test_img_captions[img])

#     plt.imshow(plt.imread('./data/Monumentos/' + img))
#     plt.title(text)

#     # Ajuste o tamanho do gráfico antes de salvar
#     plt.tight_layout()

#     # Salve a figura em um arquivo
#     output_filename = f'{output_directory}/{img}_output.png'
#     plt.savefig(output_filename)

#     # Limpe a figura atual para a próxima iteração
#     plt.clf()

# # Certifique-se de fechar as figuras após o loop
# plt.close('all')

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch

# Defina o diretório de saída onde deseja salvar as imagens
output_directory = './output_images/'

for _ in range(5):
    img = image_names[np.random.randint(0, 17)]

    caption = generate_caption('./data/Monumentos/' + img,
                               model=autoencoder.to(DEVICE),
                               image_transform=img_transform,
                               beam_size=3, field=PT, max_len=MAX_LEN,
                               device=DEVICE, image_shape=(256, 256))

    text = f'Previsto\n{caption}\n\n'
    text += 'Legendas verdadeiras\n'
    text += '\n'.join(test_img_captions[img])

    plt.imshow(plt.imread('./data/Monumentos/' + img))
    plt.title(text)

    # Ajuste o tamanho do gráfico antes de salvar
    plt.tight_layout()

    # Salve a figura em um arquivo
    output_filename = f'{output_directory}/{img}_output.png'
    plt.savefig(output_filename)

    # Limpe a figura atual para a próxima iteração
    plt.clf()

# Certifique-se de fechar as figuras após o loop
plt.close('all')

# %%
# !zip -r /output_neural.zip /kaggle/working/output_images
# Out:
#   adding: kaggle/working/output_images/ (stored 0%)
#   adding: kaggle/working/output_images/156.png_output.png (deflated 5%)
#   adding: kaggle/working/output_images/144.png_output.png (deflated 3%)
#   adding: kaggle/working/output_images/151.png_output.png (deflated 4%)
#   adding: kaggle/working/output_images/147.png_output.png (deflated 4%)
#   adding: kaggle/working/output_images/150.png_output.png (deflated 5%)
#   adding: kaggle/working/output_images/157.png_output.png (deflated 4%)
#   adding: kaggle/working/output_images/160.png_output.png (deflated 3%)
#   adding: kaggle/working/output_images/159.png_output.png (deflated 4%)
#   adding: kaggle/working/output_images/152.png_output.png (deflated 5%)

# %%
# for _ in range(5):
#     img = image_names[np.random.randint(0, 1000)]

#     caption = generate_caption('/kaggle/input/dataset-monumentos/imagens/' + img,
#                                model=autoencoder.to(DEVICE),
#                                image_transform=img_transform,
#                                beam_size=3, field=EN, max_len=MAX_LEN,
#                                device=DEVICE, image_shape=(256, 256))

#     text = f'Predicted\n{caption}\n\n'
#     text += 'True captions\n'
#     text += '\n'.join(test_img_captions[img])

#     plt.imshow(plt.imread('/kaggle/input/dataset-monumentos/imagens/' + img))
#     plt.title(text)
#     plt.show()

# %%
# import os  # Import the os module to work with file paths

# # Define the directory path where the images are located
# image_directory = '/kaggle/input/dataset-monumentos/imagens/'

# # Check if the directory exists
# if not os.path.exists(image_directory):
#     raise FileNotFoundError(f"The directory '{image_directory}' does not exist.")

# for _ in range(5):
#     img = image_names[np.random.randint(0, 1000)]

#     # Construct the full path to the image
#     image_path = os.path.join(image_directory, img)

#     # Check if the image file exists
#     if not os.path.exists(image_path):
#         print(f"The image file '{img}' does not exist in '{image_directory}'. Skipping...")
#         continue

#     caption = generate_caption(image_path,
#                                model=autoencoder.to(DEVICE),
#                                image_transform=img_transform,
#                                beam_size=3, field=EN, max_len=MAX_LEN,
#                                device=DEVICE, image_shape=(256, 256))

#     text = f'Predicted\n{caption}\n\n'
#     text += 'True captions\n'
#     text += '\n'.join(test_img_captions[img])

#     plt.imshow(plt.imread(image_path))
#     plt.title(text)
#     plt.show()

# %%
# import matplotlib.pyplot as plt
# from PIL import Image

# # Define the path to the image
# image_path = '/kaggle/input/dataset-monumentos/imagens/08.png'

# # Check if the image file exists
# if not os.path.exists(image_path):
#     raise FileNotFoundError(f"The image file '{image_path}' does not exist.")

#     caption = generate_caption(image_path,
#                                model=autoencoder.to(DEVICE),
#                                image_transform=img_transform,
#                                beam_size=3, field=EN, max_len=MAX_LEN,
#                                device=DEVICE, image_shape=(256, 256))

#     text = f'Predicted\n{caption}\n\n'
#     text += 'True captions\n'
#     text += '\n'.join(test_img_captions[img])

#     plt.imshow(plt.imread(image_path))
#     plt.title(text)
#     plt.show()

# %%
# import requests
# import time

# def keep_alive(url, interval_seconds):
#     while True:
#         try:
#             response = requests.get(url)
#             if response.status_code == 200:
#                 print(f"Keep-alive successful at {time.ctime()}")
#             else:
#                 print(f"Keep-alive failed with status code {response.status_code} at {time.ctime()}")
#         except Exception as e:
#             print(f"Keep-alive failed with exception: {str(e)} at {time.ctime()}")

#         time.sleep(interval_seconds)

# if __name__ == "__main__":
#     # Defina a URL que deseja manter ativa e o intervalo em segundos
#     target_url = "https://www.kaggle.com/allinegomes/neural-image-caption/edit"
#     keep_alive_interval = 300  # 5 minutos

#     keep_alive(target_url, keep_alive_interval)

# %%
# img = Image.open("/kaggle/input/dataset-monumentos/imagens/16.png")
# newImg = img.resize((299,299), Image.BILINEAR).convert("RGB")
# data = np.array( newImg.getdata() )
# input=( data.reshape( (1, newImg.size[0], newImg.size[1], 3) ).astype( np.float32 )/255 ) - 1
# image= model_new.predict(input) # Get the encoding vector for the image
# x=plt.imread("/kaggle/input/dataset-monumentos/imagens/16.png")
# plt.imshow(x)
# plt.show()
# print("Beam:",beam_search_pred(image))
